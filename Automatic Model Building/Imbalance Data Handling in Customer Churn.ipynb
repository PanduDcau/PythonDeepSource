# %% [markdown]
# ### Handling imbalanced data in customer churn prediction

# %% [markdown]
# ***Customer churn prediction*** is to measure why customers are leaving a business. In this tutorial we will be looking at customer churn in telecom business. We will build a deep learning model to predict the churn and use precision,recall, f1-score to measure performance of our model. We will then handle imbalance in data using various techniques and improve f1-score

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("/Users/Asus/Documents/Atmel Studio/Customer_Churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5256  1527-SXDPN    Male              0     Yes        Yes      52
# 712   9661-JALZV  Female              0      No         No      58
# 2532  9825-YCXWZ  Female              1      No         No      41
# 3088  5751-USDBL    Male              0     Yes        Yes      46
# 5740  8882-TLVRW    Male              0     Yes        Yes      69
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 5256          Yes               Yes     Fiber optic                   No  ...
# 712           Yes               Yes              No  No internet service  ...
# 2532          Yes                No     Fiber optic                   No  ...
# 3088          Yes                No             DSL                  Yes  ...
# 5740           No  No phone service             DSL                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5256                  Yes                  Yes                   No
# 712   No internet service  No internet service  No internet service
# 2532                  Yes                  Yes                  Yes
# 3088                  Yes                  Yes                  Yes
# 5740                  Yes                  Yes                   No
#
#           StreamingMovies  Contract PaperlessBilling  \
# 5256                  Yes  Two year              Yes
# 712   No internet service  Two year              Yes
# 2532                  Yes  One year              Yes
# 3088                  Yes  Two year               No
# 5740                   No  Two year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 5256  Bank transfer (automatic)          96.25       4990.25   Yes
# 712     Credit card (automatic)          24.70          1519    No
# 2532  Bank transfer (automatic)         101.10        4016.2    No
# 3088               Mailed check          81.00       3846.35    No
# 5740               Mailed check          39.10        2779.5    No
#
# [5 rows x 21 columns]

# %%
df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
517400/df.shape[0]  #To get the Precentage
# Out:
# 73.46301292063042

# %% [markdown]
# ### First of all, drop customerID column as it is of no use

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# ***Quick glance*** at above makes me realize that TotalCharges should be float but it is an object. Let's check what's going on with this column

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [markdown]
# ### Convert String to Number

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488].TotalCharges
# Out:
# ' '

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (7032, 20)

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
df1[df1.Churn=='No']
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 3       Male              0      No         No      45           No
# 6       Male              0      No        Yes      22          Yes
# 7     Female              0      No         No      10           No
# ...      ...            ...     ...        ...     ...          ...
# 7037  Female              0      No         No      72          Yes
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# 1                   No             DSL                  Yes
# 3     No phone service             DSL                  Yes
# 6                  Yes     Fiber optic                   No
# 7     No phone service             DSL                  Yes
# ...                ...             ...                  ...
# 7037                No              No  No internet service
# 7038               Yes             DSL                  Yes
# 7039               Yes     Fiber optic                   No
# 7040  No phone service             DSL                  Yes
# 7042                No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                   No
# 1                      No                  Yes                   No
# 3                      No                  Yes                  Yes
# 6                     Yes                   No                   No
# 7                      No                   No                   No
# ...                   ...                  ...                  ...
# 7037  No internet service  No internet service  No internet service
# 7038                   No                  Yes                  Yes
# 7039                  Yes                  Yes                   No
# 7040                   No                   No                   No
# 7042                   No                  Yes                  Yes
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                      No                   No  Month-to-month
# 1                      No                   No        One year
# 3                      No                   No        One year
# 6                     Yes                   No  Month-to-month
# 7                      No                   No  Month-to-month
# ...                   ...                  ...             ...
# 7037  No internet service  No internet service        Two year
# 7038                  Yes                  Yes        One year
# 7039                  Yes                  Yes        One year
# 7040                   No                   No  Month-to-month
# 7042                  Yes                  Yes        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 0                 Yes           Electronic check           29.85
# 1                  No               Mailed check           56.95
# 3                  No  Bank transfer (automatic)           42.30
# 6                 Yes    Credit card (automatic)           89.10
# 7                  No               Mailed check           29.75
# ...               ...                        ...             ...
# 7037              Yes  Bank transfer (automatic)           21.15
# 7038              Yes               Mailed check           84.80
# 7039              Yes    Credit card (automatic)          103.20
# 7040              Yes           Electronic check           29.60
# 7042              Yes  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 3          1840.75    No
# 6          1949.40    No
# 7           301.90    No
# ...            ...   ...
# 7037       1419.40    No
# 7038       1990.50    No
# 7039       7362.90    No
# 7040        346.45    No
# 7042       6844.50    No
#
# [5163 rows x 20 columns]

# %% [markdown]
# ## Data Vizualization

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges      
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges      

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %% [markdown]
# ### Many of the columns are yes, no etc. Let's print unique values in object columns to see data values

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# ### Some of the columns have no internet service or no phone service, that can be replaced with a simple No

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# ## Convert Yes/No Columns into binary values

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ### One hot encoding for categorical columns

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5851       1              1        0           0      35             1
# 1496       0              0        0           0       3             1
# 1841       1              0        1           0      56             1
# 5063       0              0        0           0      21             1
# 675        0              1        0           0      65             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5851              1               1             1                 1  ...
# 1496              0               0             0                 0  ...
# 1841              1               0             0                 0  ...
# 5063              1               0             1                 0  ...
# 675               1               1             0                 1  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5851                    0                            1                   0
# 1496                    0                            0                   1
# 1841                    0                            0                   1
# 5063                    0                            1                   0
# 675                     0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5851                        0                  1                  0
# 1496                        1                  0                  0
# 1841                        0                  1                  0
# 5063                        1                  0                  0
# 675                         0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5851                                        1
# 1496                                        0
# 1841                                        0
# 5063                                        0
# 675                                         0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5851                                      0                               0
# 1496                                      0                               1
# 1841                                      0                               1
# 5063                                      0                               1
# 675                                       0                               1
#
#       PaymentMethod_Mailed check
# 5851                           0
# 1496                           0
# 1841                           0
# 5063                           0
# 675                            0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# ### Train Test Data

# %%
X = df2.drop('Churn',axis='columns')
y = testLabels = df2.Churn.astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0.0    4130
# 1.0    1495
# Name: Churn, dtype: int64

# %%
y.value_counts()
# Out:
# 0.0    5163
# 1.0    1869
# Name: Churn, dtype: int64

# %%
#Finfing Churn Ratio in Test Data
5163/1869
# Out:
# 2.7624398073836276

# %%
y_test.value_counts()
# Out:
# 0.0    1033
# 1.0     374
# Name: Churn, dtype: int64

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 684        1              0        0           0  0.000000             1
# 2446       1              0        0           0  0.239437             1
# 1680       0              0        1           1  0.774648             1
# 2220       0              0        1           0  1.000000             1
# 2842       1              0        0           0  0.042254             0
# 5131       1              0        1           0  0.605634             1
# 4372       0              0        1           1  0.000000             1
# 4687       0              0        1           0  0.295775             1
# 2385       1              0        0           1  0.028169             0
# 6773       0              1        1           0  0.507042             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 684               0               0             0                 0  ...
# 2446              1               0             1                 0  ...
# 1680              1               0             0                 0  ...
# 2220              0               1             1                 0  ...
# 2842              0               1             0                 1  ...
# 5131              1               0             0                 0  ...
# 4372              0               0             0                 0  ...
# 4687              0               0             0                 1  ...
# 2385              0               0             1                 0  ...
# 6773              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 684                     0                            1                   0
# 2446                    0                            1                   0
# 1680                    0                            0                   1
# 2220                    1                            0                   0
# 2842                    1                            0                   0
# 5131                    0                            1                   0
# 4372                    0                            0                   1
# 4687                    0                            1                   0
# 2385                    1                            0                   0
# 6773                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 684                         1                  0                  0
# 2446                        1                  0                  0
# 1680                        0                  1                  0
# 2220                        0                  0                  1
# 2842                        1                  0                  0
# 5131                        1                  0                  0
# 4372                        1                  0                  0
# 4687                        1                  0                  0
# 2385                        1                  0                  0
# 6773                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 684                                         0
# 2446                                        0
# 1680                                        0
# 2220                                        1
# 2842                                        0
# 5131                                        0
# 4372                                        1
# 4687                                        0
# 2385                                        0
# 6773                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 684                                       0                               0
# 2446                                      1                               0
# 1680                                      0                               0
# 2220                                      0                               0
# 2842                                      0                               0
# 5131                                      0                               1
# 4372                                      0                               0
# 4687                                      1                               0
# 2385                                      0                               0
# 6773                                      0                               1
#
#       PaymentMethod_Mailed check
# 684                            1
# 2446                           0
# 1680                           1
# 2220                           0
# 2842                           1
# 5131                           0
# 4372                           0
# 4687                           0
# 2385                           1
# 6773                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %% [markdown]
# ### Build a model (ANN) in tensorflow/keras

# %%
from tensorflow_addons import losses

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(26, input_dim=26, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=100)
    else:
        model.fit(X_train, y_train, epochs=100, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 7s 11ms/step - loss: 0.4899 - accuracy: 0.7648
# Epoch 2/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4269 - accuracy: 0.7941
# Epoch 3/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4197 - accuracy: 0.7982
# Epoch 4/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4148 - accuracy: 0.7986
# Epoch 5/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4123 - accuracy: 0.7980
# Epoch 6/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4097 - accuracy: 0.8021
# Epoch 7/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4077 - accuracy: 0.8025
# Epoch 8/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4066 - accuracy: 0.8032
# Epoch 9/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4060 - accuracy: 0.8053
# Epoch 10/100
# 176/176 [==============================] - 2s 10ms/step - loss: 0.4041 - accuracy: 0.8050
# Epoch 11/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4025 - accuracy: 0.8055
# Epoch 12/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4022 - accuracy: 0.8089
# Epoch 13/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4000 - accuracy: 0.8091
# Epoch 14/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.3990 - accuracy: 0.8062
# Epoch 15/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3983 - accuracy: 0.8114
# Epoch 16/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.3969 - accuracy: 0.8101
# Epoch 17/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3962 - accuracy: 0.8084
# Epoch 18/100
# 176/176 [==============================] - 2s 11ms/step - loss: 0.3955 - accuracy: 0.8110
# Epoch 19/100
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3941 - accuracy: 0.8123
# Epoch 20/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3929 - accuracy: 0.8121
# Epoch 21/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3918 - accuracy: 0.8128
# Epoch 22/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3905 - accuracy: 0.8142
# Epoch 23/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3900 - accuracy: 0.8144
# Epoch 24/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3887 - accuracy: 0.8172
# Epoch 25/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3884 - accuracy: 0.8149
# Epoch 26/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3879 - accuracy: 0.8140
# Epoch 27/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3852 - accuracy: 0.8148
# Epoch 28/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3854 - accuracy: 0.8171
# Epoch 29/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3842 - accuracy: 0.8158
# Epoch 30/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3822 - accuracy: 0.8188
# Epoch 31/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3827 - accuracy: 0.8164
# Epoch 32/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3801 - accuracy: 0.8199
# Epoch 33/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3810 - accuracy: 0.8187
# Epoch 34/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3787 - accuracy: 0.8206
# Epoch 35/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3785 - accuracy: 0.8171
# Epoch 36/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3766 - accuracy: 0.8194
# Epoch 37/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3759 - accuracy: 0.8183
# Epoch 38/100
# 176/176 [==============================] - 3s 17ms/step - loss: 0.3763 - accuracy: 0.8201
# Epoch 39/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3754 - accuracy: 0.8252
# Epoch 40/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3728 - accuracy: 0.8226
# Epoch 41/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3729 - accuracy: 0.8240 0s - loss: 0.375
# Epoch 42/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3725 - accuracy: 0.8244
# Epoch 43/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3713 - accuracy: 0.8244
# Epoch 44/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3716 - accuracy: 0.8245
# Epoch 45/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3695 - accuracy: 0.8284
# Epoch 46/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3687 - accuracy: 0.8281
# Epoch 47/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3677 - accuracy: 0.8260
# Epoch 48/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3675 - accuracy: 0.8265
# Epoch 49/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3663 - accuracy: 0.8260
# Epoch 50/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3651 - accuracy: 0.8292
# Epoch 51/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3651 - accuracy: 0.8283
# Epoch 52/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3643 - accuracy: 0.8277
# Epoch 53/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3641 - accuracy: 0.8276
# Epoch 54/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3630 - accuracy: 0.8290
# Epoch 55/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3620 - accuracy: 0.8261
# Epoch 56/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3628 - accuracy: 0.8267
# Epoch 57/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3615 - accuracy: 0.8267
# Epoch 58/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3611 - accuracy: 0.8279
# Epoch 59/100
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3606 - accuracy: 0.8320
# Epoch 60/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3593 - accuracy: 0.8297
# Epoch 61/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3592 - accuracy: 0.8300
# Epoch 62/100
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3587 - accuracy: 0.8311
# Epoch 63/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3576 - accuracy: 0.8311
# Epoch 64/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3584 - accuracy: 0.8315
# Epoch 65/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3566 - accuracy: 0.8309
# Epoch 66/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3560 - accuracy: 0.8313
# Epoch 67/100
# 176/176 [==============================] - 3s 17ms/step - loss: 0.3539 - accuracy: 0.8320
# Epoch 68/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3553 - accuracy: 0.8276
# Epoch 69/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3543 - accuracy: 0.8315
# Epoch 70/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3545 - accuracy: 0.8302
# Epoch 71/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3547 - accuracy: 0.8347
# Epoch 72/100
# 176/176 [==============================] - 2s 14ms/step - loss: 0.3525 - accuracy: 0.8325
# Epoch 73/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3518 - accuracy: 0.8324
# Epoch 74/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3526 - accuracy: 0.8316
# Epoch 75/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3519 - accuracy: 0.8313
# Epoch 76/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3505 - accuracy: 0.8354
# Epoch 77/100
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3510 - accuracy: 0.8324
# Epoch 78/100
# 176/176 [==============================] - 5s 28ms/step - loss: 0.3499 - accuracy: 0.8332
# Epoch 79/100
# 176/176 [==============================] - 13s 71ms/step - loss: 0.3487 - accuracy: 0.8313
# Epoch 80/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.3504 - accuracy: 0.83273s - l - ETA: 0s - loss: 0.3460 -
# Epoch 81/100
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3486 - accuracy: 0.8364
# Epoch 82/100
# 176/176 [==============================] - 1s 7ms/step - loss: 0.3485 - accuracy: 0.8334
# Epoch 83/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3477 - accuracy: 0.8334
# Epoch 84/100
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3460 - accuracy: 0.8377
# Epoch 85/100
# 176/176 [==============================] - 1s 7ms/step - loss: 0.3478 - accuracy: 0.8359
# Epoch 86/100
# 176/176 [==============================] - 2s 10ms/step - loss: 0.3464 - accuracy: 0.8352
# Epoch 87/100
# 176/176 [==============================] - 1s 7ms/step - loss: 0.3455 - accuracy: 0.8366
# Epoch 88/100
# 176/176 [==============================] - 2s 10ms/step - loss: 0.3456 - accuracy: 0.8375 0s - loss: 0.3454 - accuracy:
# Epoch 89/100
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3458 - accuracy: 0.8370
# Epoch 90/100
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3441 - accuracy: 0.8386
# Epoch 91/100
# 176/176 [==============================] - 3s 14ms/step - loss: 0.3443 - accuracy: 0.8368
# Epoch 92/100
# 176/176 [==============================] - 3s 15ms/step - loss: 0.3438 - accuracy: 0.8380
# Epoch 93/100
# 176/176 [==============================] - 2s 9ms/step - loss: 0.3430 - accuracy: 0.8373
# Epoch 94/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3438 - accuracy: 0.8373
# Epoch 95/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3420 - accuracy: 0.8373
# Epoch 96/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3425 - accuracy: 0.8388
# Epoch 97/100
# 176/176 [==============================] - 2s 9ms/step - loss: 0.3427 - accuracy: 0.8375
# Epoch 98/100
# 176/176 [==============================] - 2s 9ms/step - loss: 0.3410 - accuracy: 0.8372
# Epoch 99/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3412 - accuracy: 0.8380
# Epoch 100/100
# 176/176 [==============================] - 1s 8ms/step - loss: 0.3407 - accuracy: 0.8368
# 44/44 [==============================] - 0s 5ms/step - loss: 0.4848 - accuracy: 0.7925
# [0.4847753047943115, 0.7924662232398987]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.89      0.86      1033
#          1.0       0.63      0.52      0.57       374
#
#     accuracy                           0.79      1407
#    macro avg       0.74      0.70      0.72      1407
# weighted avg       0.78      0.79      0.79      1407

# %% [markdown]
# ## Mitigating Skewness

# %% [markdown]
# #### Method 1: Undersampling

# %% [markdown]
# **Reference:*** https://www.kaggle.com/rafjaa/resampling-strategies-for-imbalanced-datasets

# %%
# Class count
count_class_0, count_class_1 = df1.Churn.value_counts()

# Divide by class
df_class_0 = df2[df2['Churn'] == 0]
df_class_1 = df2[df2['Churn'] == 1]

# %%
# Undersample 0-class and concat the DataFrames of both class
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_test_under.Churn.value_counts())
# Out:
# Random under-sampling:
# 0    1869
# 1    1869
# Name: Churn, dtype: int64

# %%
X = df_test_under.drop('Churn',axis='columns')
y = df_test_under['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0    1495
# 1    1495
# Name: Churn, dtype: int64

# %% [markdown]
# ### Printing Classification in the last, Scroll down till the last epoch to watch the classification report

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.6514 - accuracy: 0.6435
# Epoch 2/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.5298 - accuracy: 0.7548
# Epoch 3/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4916 - accuracy: 0.7615
# Epoch 4/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4859 - accuracy: 0.7599
# Epoch 5/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4816 - accuracy: 0.7736
# Epoch 6/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4800 - accuracy: 0.7659
# Epoch 7/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4766 - accuracy: 0.7679
# Epoch 8/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4735 - accuracy: 0.7666
# Epoch 9/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4737 - accuracy: 0.7729
# Epoch 10/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4695 - accuracy: 0.7719
# Epoch 11/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4677 - accuracy: 0.7736
# Epoch 12/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4674 - accuracy: 0.7763
# Epoch 13/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4654 - accuracy: 0.7766
# Epoch 14/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4630 - accuracy: 0.7769
# Epoch 15/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4628 - accuracy: 0.7779
# Epoch 16/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4602 - accuracy: 0.7823
# Epoch 17/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4639 - accuracy: 0.7769
# Epoch 18/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4612 - accuracy: 0.7776
# Epoch 19/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4587 - accuracy: 0.7769
# Epoch 20/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4568 - accuracy: 0.7763
# Epoch 21/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4566 - accuracy: 0.7776
# Epoch 22/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4557 - accuracy: 0.7789
# Epoch 23/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4535 - accuracy: 0.7816
# Epoch 24/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.7749
# Epoch 25/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4542 - accuracy: 0.7813
# Epoch 26/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4522 - accuracy: 0.7803
# Epoch 27/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4507 - accuracy: 0.7816: 0s - loss: 0.4530 - accura
# Epoch 28/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.7863
# Epoch 29/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4489 - accuracy: 0.7819
# Epoch 30/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4493 - accuracy: 0.7819
# Epoch 31/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4479 - accuracy: 0.7883
# Epoch 32/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4477 - accuracy: 0.7860
# Epoch 33/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4464 - accuracy: 0.7819
# Epoch 34/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4465 - accuracy: 0.7816
# Epoch 35/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4454 - accuracy: 0.7856
# Epoch 36/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4457 - accuracy: 0.7886
# Epoch 37/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4435 - accuracy: 0.7849
# Epoch 38/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4421 - accuracy: 0.7839
# Epoch 39/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4433 - accuracy: 0.7910
# Epoch 40/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4423 - accuracy: 0.7880
# Epoch 41/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4401 - accuracy: 0.7890
# Epoch 42/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4382 - accuracy: 0.7900
# Epoch 43/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4390 - accuracy: 0.7853
# Epoch 44/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4384 - accuracy: 0.7876
# Epoch 45/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4380 - accuracy: 0.7846
# Epoch 46/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4362 - accuracy: 0.7896
# Epoch 47/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4360 - accuracy: 0.7900
# Epoch 48/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4337 - accuracy: 0.7920
# Epoch 49/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4334 - accuracy: 0.7896
# Epoch 50/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4318 - accuracy: 0.7910
# Epoch 51/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4328 - accuracy: 0.7890
# Epoch 52/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4294 - accuracy: 0.7940
# Epoch 53/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4307 - accuracy: 0.7930
# Epoch 54/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4291 - accuracy: 0.7943
# Epoch 55/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4289 - accuracy: 0.7930
# Epoch 56/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4286 - accuracy: 0.7936
# Epoch 57/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4262 - accuracy: 0.7910
# Epoch 58/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4246 - accuracy: 0.7940
# Epoch 59/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4238 - accuracy: 0.7987
# Epoch 60/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4249 - accuracy: 0.7946
# Epoch 61/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4228 - accuracy: 0.7943
# Epoch 62/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4227 - accuracy: 0.7983
# Epoch 63/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4219 - accuracy: 0.7960
# Epoch 64/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4211 - accuracy: 0.7970
# Epoch 65/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4197 - accuracy: 0.8003
# Epoch 66/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4181 - accuracy: 0.8020
# Epoch 67/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4176 - accuracy: 0.7983
# Epoch 68/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4158 - accuracy: 0.8027
# Epoch 69/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4150 - accuracy: 0.8020
# Epoch 70/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4152 - accuracy: 0.8037
# Epoch 71/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4138 - accuracy: 0.8060
# Epoch 72/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4155 - accuracy: 0.8027
# Epoch 73/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4131 - accuracy: 0.8074
# Epoch 74/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4131 - accuracy: 0.8040
# Epoch 75/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4095 - accuracy: 0.8054
# Epoch 76/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4095 - accuracy: 0.8074
# Epoch 77/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4095 - accuracy: 0.8077
# Epoch 78/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4083 - accuracy: 0.8050
# Epoch 79/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4096 - accuracy: 0.8077
# Epoch 80/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4071 - accuracy: 0.8064
# Epoch 81/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4049 - accuracy: 0.8087
# Epoch 82/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4071 - accuracy: 0.8124
# Epoch 83/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4041 - accuracy: 0.8137
# Epoch 84/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4037 - accuracy: 0.8137
# Epoch 85/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4028 - accuracy: 0.8130
# Epoch 86/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4012 - accuracy: 0.8114
# Epoch 87/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4006 - accuracy: 0.8151
# Epoch 88/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.3998 - accuracy: 0.8127
# Epoch 89/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4003 - accuracy: 0.8164
# Epoch 90/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3985 - accuracy: 0.8157
# Epoch 91/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3977 - accuracy: 0.8164
# Epoch 92/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3967 - accuracy: 0.8231
# Epoch 93/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3967 - accuracy: 0.8201
# Epoch 94/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3956 - accuracy: 0.8224
# Epoch 95/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3956 - accuracy: 0.8147
# Epoch 96/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3928 - accuracy: 0.8177
# Epoch 97/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.3934 - accuracy: 0.8201
# Epoch 98/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3935 - accuracy: 0.8161
# Epoch 99/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3917 - accuracy: 0.8217
# Epoch 100/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3905 - accuracy: 0.8191
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6053 - accuracy: 0.7326
# [0.6052931547164917, 0.7326202988624573]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.63      0.70       374
#            1       0.69      0.83      0.76       374
#
#     accuracy                           0.73       748
#    macro avg       0.74      0.73      0.73       748
# weighted avg       0.74      0.73      0.73       748

# %% [markdown]
# Check classification report above. f1-score for minority class 1 improved from **0.57 to 0.76.** Score for class 0 reduced to 0.75 from 0.85 but that's ok. We have more generalized classifier which classifies both classes with similar prediction score

# %% [markdown]
# ### Method2: Oversampling

# %%
# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.Churn.value_counts())
# Out:
# Random over-sampling:
# 0    5163
# 1    5163
# Name: Churn, dtype: int64

# %%
X = df_test_over.drop('Churn',axis='columns')
y = df_test_over['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 1    4130
# 0    4130
# Name: Churn, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.5630 - accuracy: 0.7081
# Epoch 2/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4979 - accuracy: 0.7548
# Epoch 3/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4895 - accuracy: 0.7607
# Epoch 4/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4854 - accuracy: 0.7608
# Epoch 5/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4793 - accuracy: 0.7650
# Epoch 6/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4769 - accuracy: 0.7699
# Epoch 7/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4733 - accuracy: 0.7714
# Epoch 8/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4702 - accuracy: 0.7719
# Epoch 9/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4680 - accuracy: 0.7735
# Epoch 10/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4651 - accuracy: 0.7754: 0s - loss: 0.4617 - accuracy
# Epoch 11/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4625 - accuracy: 0.7759: 0s - loss: 0.4
# Epoch 12/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4596 - accuracy: 0.7797
# Epoch 13/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4574 - accuracy: 0.7778
# Epoch 14/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4558 - accuracy: 0.7799
# Epoch 15/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.4543 - accuracy: 0.7812
# Epoch 16/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4531 - accuracy: 0.7827
# Epoch 17/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4495 - accuracy: 0.7873
# Epoch 18/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4479 - accuracy: 0.7866
# Epoch 19/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.4477 - accuracy: 0.7885
# Epoch 20/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4442 - accuracy: 0.7891
# Epoch 21/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4439 - accuracy: 0.7935
# Epoch 22/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4413 - accuracy: 0.7925
# Epoch 23/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4414 - accuracy: 0.7936
# Epoch 24/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4386 - accuracy: 0.7967
# Epoch 25/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4379 - accuracy: 0.7988
# Epoch 26/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4361 - accuracy: 0.7978
# Epoch 27/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4347 - accuracy: 0.7982
# Epoch 28/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4350 - accuracy: 0.7979
# Epoch 29/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4315 - accuracy: 0.8006
# Epoch 30/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4310 - accuracy: 0.8004: 0s - loss: 0.4300 -
# Epoch 31/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4312 - accuracy: 0.7994
# Epoch 32/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4273 - accuracy: 0.8024
# Epoch 33/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4262 - accuracy: 0.8070
# Epoch 34/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4250 - accuracy: 0.8070
# Epoch 35/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4245 - accuracy: 0.8057
# Epoch 36/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4234 - accuracy: 0.8061
# Epoch 37/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4229 - accuracy: 0.8045
# Epoch 38/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4209 - accuracy: 0.8071
# Epoch 39/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4190 - accuracy: 0.8076
# Epoch 40/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4181 - accuracy: 0.8052
# Epoch 41/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4179 - accuracy: 0.8068
# Epoch 42/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4170 - accuracy: 0.8070
# Epoch 43/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4146 - accuracy: 0.8103
# Epoch 44/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4142 - accuracy: 0.8079
# Epoch 45/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4138 - accuracy: 0.8115
# Epoch 46/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4131 - accuracy: 0.8103
# Epoch 47/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4108 - accuracy: 0.8143
# Epoch 48/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4108 - accuracy: 0.8136
# Epoch 49/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4099 - accuracy: 0.8090
# Epoch 50/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4086 - accuracy: 0.8104
# Epoch 51/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4081 - accuracy: 0.8127
# Epoch 52/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4068 - accuracy: 0.8140
# Epoch 53/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4054 - accuracy: 0.8128
# Epoch 54/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4041 - accuracy: 0.8180
# Epoch 55/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4028 - accuracy: 0.8142
# Epoch 56/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4027 - accuracy: 0.8160
# Epoch 57/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4026 - accuracy: 0.8166
# Epoch 58/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3998 - accuracy: 0.8184
# Epoch 59/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3993 - accuracy: 0.8172
# Epoch 60/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3991 - accuracy: 0.8163
# Epoch 61/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3982 - accuracy: 0.8223
# Epoch 62/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3967 - accuracy: 0.8172
# Epoch 63/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3966 - accuracy: 0.8199
# Epoch 64/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3957 - accuracy: 0.8217
# Epoch 65/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3946 - accuracy: 0.8202
# Epoch 66/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3928 - accuracy: 0.8218
# Epoch 67/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3931 - accuracy: 0.8215
# Epoch 68/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3926 - accuracy: 0.8218
# Epoch 69/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3900 - accuracy: 0.8238
# Epoch 70/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3891 - accuracy: 0.8241
# Epoch 71/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3896 - accuracy: 0.8205
# Epoch 72/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3883 - accuracy: 0.8208
# Epoch 73/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3884 - accuracy: 0.8270
# Epoch 74/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3888 - accuracy: 0.8265
# Epoch 75/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3878 - accuracy: 0.8253
# Epoch 76/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3862 - accuracy: 0.8253
# Epoch 77/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3856 - accuracy: 0.8258
# Epoch 78/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3845 - accuracy: 0.8278
# Epoch 79/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3844 - accuracy: 0.8272
# Epoch 80/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3837 - accuracy: 0.8268
# Epoch 81/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3817 - accuracy: 0.8260
# Epoch 82/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3812 - accuracy: 0.8282
# Epoch 83/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3807 - accuracy: 0.8283
# Epoch 84/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3806 - accuracy: 0.8286
# Epoch 85/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.3798 - accuracy: 0.8301
# Epoch 86/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3798 - accuracy: 0.8288
# Epoch 87/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3792 - accuracy: 0.8276
# Epoch 88/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3773 - accuracy: 0.8331
# Epoch 89/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3784 - accuracy: 0.8301
# Epoch 90/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3771 - accuracy: 0.8322
# Epoch 91/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3769 - accuracy: 0.8309
# Epoch 92/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3759 - accuracy: 0.8312
# Epoch 93/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3749 - accuracy: 0.8339
# Epoch 94/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3739 - accuracy: 0.8316
# Epoch 95/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3727 - accuracy: 0.8327
# Epoch 96/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3727 - accuracy: 0.8340
# Epoch 97/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3723 - accuracy: 0.8368
# Epoch 98/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3712 - accuracy: 0.8369
# Epoch 99/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3712 - accuracy: 0.8357
# Epoch 100/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3710 - accuracy: 0.8383
# 65/65 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.7865
# [0.4764042794704437, 0.7865440249443054]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.68      0.76      1033
#            1       0.74      0.89      0.81      1033
#
#     accuracy                           0.79      2066
#    macro avg       0.80      0.79      0.78      2066
# weighted avg       0.80      0.79      0.78      2066

# %% [markdown]
# Check classification report above. f1-score for minority class 1 improved from 0.57 to 0.76. Score for class 0 reduced to **0.75 from 0.85** but that's ok. We have more generalized classifier which classifies both classes with similar prediction score

# %% [markdown]
# ### Method3: SMOTE

# %% [markdown]
# To install imbalanced-learn library use **pip install imbalanced-learn** command

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X, y)

y_sm.value_counts()
# Out:
# 0    5163
# 1    5163
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 1    4130
# 0    4130
# Name: Churn, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.5381 - accuracy: 0.7237
# Epoch 2/100
# 259/259 [==============================] - 1s 6ms/step - loss: 0.4683 - accuracy: 0.7753
# Epoch 3/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4600 - accuracy: 0.7799
# Epoch 4/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4550 - accuracy: 0.7863
# Epoch 5/100
# 259/259 [==============================] - 1s 6ms/step - loss: 0.4496 - accuracy: 0.7914
# Epoch 6/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.4448 - accuracy: 0.7923
# Epoch 7/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4409 - accuracy: 0.7937
# Epoch 8/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4377 - accuracy: 0.7961
# Epoch 9/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4343 - accuracy: 0.7988
# Epoch 10/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4324 - accuracy: 0.8007
# Epoch 11/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4282 - accuracy: 0.8021
# Epoch 12/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4253 - accuracy: 0.8042
# Epoch 13/100
# 259/259 [==============================] - 1s 6ms/step - loss: 0.4226 - accuracy: 0.8042
# Epoch 14/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4213 - accuracy: 0.8068
# Epoch 15/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4176 - accuracy: 0.8093
# Epoch 16/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4159 - accuracy: 0.8092: 0s - loss: 0.409
# Epoch 17/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4137 - accuracy: 0.8120
# Epoch 18/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.4107 - accuracy: 0.8098
# Epoch 19/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4085 - accuracy: 0.8139
# Epoch 20/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4066 - accuracy: 0.8171
# Epoch 21/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4066 - accuracy: 0.8155
# Epoch 22/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4033 - accuracy: 0.8197
# Epoch 23/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.4020 - accuracy: 0.8180
# Epoch 24/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3993 - accuracy: 0.8203
# Epoch 25/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3964 - accuracy: 0.8206
# Epoch 26/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3960 - accuracy: 0.8197
# Epoch 27/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3958 - accuracy: 0.8238
# Epoch 28/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3927 - accuracy: 0.8236
# Epoch 29/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3907 - accuracy: 0.8252
# Epoch 30/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3903 - accuracy: 0.8283
# Epoch 31/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3881 - accuracy: 0.8260
# Epoch 32/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3858 - accuracy: 0.8282
# Epoch 33/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3858 - accuracy: 0.8272
# Epoch 34/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3836 - accuracy: 0.8292
# Epoch 35/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3834 - accuracy: 0.8276
# Epoch 36/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3831 - accuracy: 0.8291
# Epoch 37/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3805 - accuracy: 0.8340
# Epoch 38/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.3783 - accuracy: 0.8315
# Epoch 39/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3778 - accuracy: 0.8301
# Epoch 40/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.3775 - accuracy: 0.8335
# Epoch 41/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3755 - accuracy: 0.8337
# Epoch 42/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3762 - accuracy: 0.8363
# Epoch 43/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.3734 - accuracy: 0.8356
# Epoch 44/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3720 - accuracy: 0.8366
# Epoch 45/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3724 - accuracy: 0.8369
# Epoch 46/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3713 - accuracy: 0.8352
# Epoch 47/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3699 - accuracy: 0.8385
# Epoch 48/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3688 - accuracy: 0.8368
# Epoch 49/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3682 - accuracy: 0.8381
# Epoch 50/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3667 - accuracy: 0.8364
# Epoch 51/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3659 - accuracy: 0.8373
# Epoch 52/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3649 - accuracy: 0.8421
# Epoch 53/100
# 259/259 [==============================] - 2s 9ms/step - loss: 0.3644 - accuracy: 0.8384
# Epoch 54/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3654 - accuracy: 0.8367
# Epoch 55/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3639 - accuracy: 0.8407: 0s - loss: 0.3612 - accuracy
# Epoch 56/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3643 - accuracy: 0.8395
# Epoch 57/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3606 - accuracy: 0.8418
# Epoch 58/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3596 - accuracy: 0.8424
# Epoch 59/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3594 - accuracy: 0.8418
# Epoch 60/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3610 - accuracy: 0.8419: 0s - loss: 0.3606 - accuracy: 0.
# Epoch 61/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3609 - accuracy: 0.8406
# Epoch 62/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3569 - accuracy: 0.8446
# Epoch 63/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3571 - accuracy: 0.8441
# Epoch 64/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3567 - accuracy: 0.8448
# Epoch 65/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3527 - accuracy: 0.8469
# Epoch 66/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3545 - accuracy: 0.8456
# Epoch 67/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3521 - accuracy: 0.8438
# Epoch 68/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3519 - accuracy: 0.8489
# Epoch 69/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3543 - accuracy: 0.8461
# Epoch 70/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3510 - accuracy: 0.8476
# Epoch 71/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3497 - accuracy: 0.8465
# Epoch 72/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3483 - accuracy: 0.8449
# Epoch 73/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3483 - accuracy: 0.8466: 0s - los
# Epoch 74/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3471 - accuracy: 0.8492
# Epoch 75/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3494 - accuracy: 0.8461
# Epoch 76/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3462 - accuracy: 0.8489
# Epoch 77/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3469 - accuracy: 0.8481
# Epoch 78/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3466 - accuracy: 0.8488
# Epoch 79/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3437 - accuracy: 0.8518
# Epoch 80/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3436 - accuracy: 0.8506
# Epoch 81/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3430 - accuracy: 0.8530
# Epoch 82/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3433 - accuracy: 0.8479
# Epoch 83/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3429 - accuracy: 0.8517
# Epoch 84/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3427 - accuracy: 0.8540
# Epoch 85/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3442 - accuracy: 0.8535
# Epoch 86/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3390 - accuracy: 0.8518
# Epoch 87/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3397 - accuracy: 0.8517
# Epoch 88/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3365 - accuracy: 0.8562
# Epoch 89/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3355 - accuracy: 0.8561
# Epoch 90/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3388 - accuracy: 0.8548
# Epoch 91/100
# 259/259 [==============================] - 2s 8ms/step - loss: 0.3379 - accuracy: 0.8531
# Epoch 92/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3382 - accuracy: 0.8535: 0s - loss: 0.3
# Epoch 93/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3360 - accuracy: 0.8536
# Epoch 94/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3356 - accuracy: 0.8556: 0s - loss: 0.3
# Epoch 95/100
# 259/259 [==============================] - 1s 6ms/step - loss: 0.3354 - accuracy: 0.8539
# Epoch 96/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3379 - accuracy: 0.8528
# Epoch 97/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3356 - accuracy: 0.8571
# Epoch 98/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3357 - accuracy: 0.8542
# Epoch 99/100
# 259/259 [==============================] - 2s 6ms/step - loss: 0.3319 - accuracy: 0.8563
# Epoch 100/100
# 259/259 [==============================] - 2s 7ms/step - loss: 0.3362 - accuracy: 0.8515
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4483 - accuracy: 0.7928
# [0.44831547141075134, 0.7928364276885986]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.72      0.78      1033
#            1       0.76      0.87      0.81      1033
#
#     accuracy                           0.79      2066
#    macro avg       0.80      0.79      0.79      2066
# weighted avg       0.80      0.79      0.79      2066

# %% [markdown]
# SMOT Oversampling increases f1 score of minority class 1 from **0.57 to 0.81** (huge improvement) Also over all accuracy improves from 0.78 to 0.80

# %% [markdown]
# ### Method4: Use of Ensemble with undersampling

# %%
df2.Churn.value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
# Regain Original features and labels
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0    4130
# 1    1495
# Name: Churn, dtype: int64

# %%
df3 = X_train.copy()
df3['Churn'] = y_train

# %%
df3.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 684        1              0        0           0  0.000000             1
# 2446       1              0        0           0  0.239437             1
# 1680       0              0        1           1  0.774648             1
# 2220       0              0        1           0  1.000000             1
# 2842       1              0        0           0  0.042254             0
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 684               0               0             0                 0  ...
# 2446              1               0             1                 0  ...
# 1680              1               0             0                 0  ...
# 2220              0               1             1                 0  ...
# 2842              0               1             0                 1  ...
#
#       InternetService_Fiber optic  InternetService_No  \
# 684                             1                   0
# 2446                            1                   0
# 1680                            0                   1
# 2220                            0                   0
# 2842                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 684                         1                  0                  0
# 2446                        1                  0                  0
# 1680                        0                  1                  0
# 2220                        0                  0                  1
# 2842                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 684                                         0
# 2446                                        0
# 1680                                        0
# 2220                                        1
# 2842                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 684                                       0                               0
# 2446                                      1                               0
# 1680                                      0                               0
# 2220                                      0                               0
# 2842                                      0                               0
#
#       PaymentMethod_Mailed check  Churn
# 684                            1      0
# 2446                           0      1
# 1680                           1      0
# 2220                           0      0
# 2842                           1      0
#
# [5 rows x 27 columns]

# %%
df3_class0 = df3[df3.Churn==0]
df3_class1 = df3[df3.Churn==1]

# %%
def get_train_batch(df_majority, df_minority, start, end):
    df_train = pd.concat([df_majority[start:end], df_minority], axis=0)

    X_train = df_train.drop('Churn', axis='columns')
    y_train = df_train.Churn
    return X_train, y_train

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 0, 1495)

y_pred1 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.5973 - accuracy: 0.7064
# Epoch 2/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.5124 - accuracy: 0.7595
# Epoch 3/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4981 - accuracy: 0.7639
# Epoch 4/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4923 - accuracy: 0.7659
# Epoch 5/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4878 - accuracy: 0.7666
# Epoch 6/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4851 - accuracy: 0.7676
# Epoch 7/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4850 - accuracy: 0.7692
# Epoch 8/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4795 - accuracy: 0.7696
# Epoch 9/100
# 94/94 [==============================] - 1s 15ms/step - loss: 0.4778 - accuracy: 0.7726 0s - los
# Epoch 10/100
# 94/94 [==============================] - 1s 13ms/step - loss: 0.4777 - accuracy: 0.7732
# Epoch 11/100
# 94/94 [==============================] - 1s 15ms/step - loss: 0.4760 - accuracy: 0.7736
# Epoch 12/100
# 94/94 [==============================] - 1s 12ms/step - loss: 0.4739 - accuracy: 0.7776
# Epoch 13/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4733 - accuracy: 0.7749
# Epoch 14/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4722 - accuracy: 0.7753
# Epoch 15/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4699 - accuracy: 0.7793
# Epoch 16/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4681 - accuracy: 0.7833
# Epoch 17/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4664 - accuracy: 0.7766
# Epoch 18/100
# 94/94 [==============================] - 1s 10ms/step - loss: 0.4657 - accuracy: 0.7799
# Epoch 19/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4644 - accuracy: 0.7813
# Epoch 20/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4637 - accuracy: 0.7806
# Epoch 21/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4633 - accuracy: 0.7813
# Epoch 22/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4588 - accuracy: 0.7839
# Epoch 23/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4610 - accuracy: 0.7860
# Epoch 24/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4587 - accuracy: 0.7860
# Epoch 25/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4570 - accuracy: 0.7883
# Epoch 26/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4572 - accuracy: 0.7920
# Epoch 27/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4553 - accuracy: 0.7873
# Epoch 28/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4540 - accuracy: 0.7906
# Epoch 29/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4529 - accuracy: 0.7866
# Epoch 30/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4523 - accuracy: 0.7903
# Epoch 31/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4523 - accuracy: 0.7880
# Epoch 32/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4502 - accuracy: 0.7903
# Epoch 33/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4503 - accuracy: 0.7893
# Epoch 34/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4490 - accuracy: 0.7886
# Epoch 35/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4475 - accuracy: 0.7890
# Epoch 36/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4449 - accuracy: 0.7946
# Epoch 37/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4448 - accuracy: 0.7920
# Epoch 38/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4443 - accuracy: 0.7967
# Epoch 39/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4459 - accuracy: 0.7920
# Epoch 40/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4422 - accuracy: 0.7973
# Epoch 41/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4405 - accuracy: 0.7970
# Epoch 42/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4402 - accuracy: 0.8010
# Epoch 43/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4386 - accuracy: 0.7977
# Epoch 44/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4371 - accuracy: 0.7970
# Epoch 45/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4364 - accuracy: 0.8027
# Epoch 46/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4373 - accuracy: 0.7987
# Epoch 47/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4350 - accuracy: 0.7970
# Epoch 48/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4327 - accuracy: 0.8003
# Epoch 49/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4331 - accuracy: 0.8003: 0s - loss: 0.4
# Epoch 50/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4325 - accuracy: 0.8047
# Epoch 51/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4311 - accuracy: 0.7997
# Epoch 52/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4302 - accuracy: 0.8020
# Epoch 53/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4300 - accuracy: 0.8033
# Epoch 54/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4282 - accuracy: 0.8060
# Epoch 55/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4275 - accuracy: 0.8080
# Epoch 56/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4262 - accuracy: 0.8064
# Epoch 57/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4251 - accuracy: 0.8030
# Epoch 58/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4239 - accuracy: 0.8080
# Epoch 59/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4244 - accuracy: 0.8087
# Epoch 60/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4221 - accuracy: 0.8107
# Epoch 61/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4218 - accuracy: 0.8104
# Epoch 62/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4220 - accuracy: 0.8077
# Epoch 63/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4205 - accuracy: 0.8080
# Epoch 64/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4189 - accuracy: 0.8124
# Epoch 65/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4192 - accuracy: 0.8094
# Epoch 66/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4175 - accuracy: 0.8090
# Epoch 67/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4166 - accuracy: 0.8104
# Epoch 68/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4160 - accuracy: 0.8137
# Epoch 69/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4146 - accuracy: 0.8104
# Epoch 70/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4139 - accuracy: 0.8124
# Epoch 71/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4135 - accuracy: 0.8127
# Epoch 72/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4121 - accuracy: 0.8144
# Epoch 73/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4128 - accuracy: 0.8110
# Epoch 74/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4116 - accuracy: 0.8154
# Epoch 75/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4084 - accuracy: 0.8177
# Epoch 76/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4098 - accuracy: 0.8151
# Epoch 77/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4094 - accuracy: 0.8130
# Epoch 78/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4072 - accuracy: 0.8164
# Epoch 79/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4077 - accuracy: 0.8140
# Epoch 80/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4081 - accuracy: 0.8104
# Epoch 81/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4063 - accuracy: 0.8130
# Epoch 82/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4072 - accuracy: 0.8144
# Epoch 83/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4065 - accuracy: 0.8137
# Epoch 84/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4040 - accuracy: 0.8201
# Epoch 85/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4043 - accuracy: 0.8104
# Epoch 86/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4044 - accuracy: 0.8197
# Epoch 87/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4017 - accuracy: 0.8191
# Epoch 88/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4033 - accuracy: 0.8177
# Epoch 89/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4004 - accuracy: 0.8197
# Epoch 90/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4009 - accuracy: 0.8191
# Epoch 91/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4011 - accuracy: 0.8174
# Epoch 92/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3980 - accuracy: 0.8194
# Epoch 93/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4010 - accuracy: 0.8161
# Epoch 94/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3968 - accuracy: 0.8191
# Epoch 95/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3970 - accuracy: 0.8241
# Epoch 96/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3961 - accuracy: 0.8217
# Epoch 97/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3955 - accuracy: 0.8221
# Epoch 98/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3956 - accuracy: 0.8204
# Epoch 99/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.3959 - accuracy: 0.8151
# Epoch 100/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3928 - accuracy: 0.8258
# 44/44 [==============================] - 0s 4ms/step - loss: 0.5890 - accuracy: 0.7129
# [0.5889663696289062, 0.7128642797470093]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.70      0.78      1033
#            1       0.47      0.76      0.59       374
#
#     accuracy                           0.71      1407
#    macro avg       0.68      0.73      0.68      1407
# weighted avg       0.78      0.71      0.73      1407

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 1495, 2990)

y_pred2 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.5886 - accuracy: 0.6856
# Epoch 2/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.5109 - accuracy: 0.7562
# Epoch 3/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4945 - accuracy: 0.7649
# Epoch 4/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4893 - accuracy: 0.7602
# Epoch 5/100
# 94/94 [==============================] - 0s 5ms/step - loss: 0.4854 - accuracy: 0.7619
# Epoch 6/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4815 - accuracy: 0.7649
# Epoch 7/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4794 - accuracy: 0.7656
# Epoch 8/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4763 - accuracy: 0.7682
# Epoch 9/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4742 - accuracy: 0.7652
# Epoch 10/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4723 - accuracy: 0.7686
# Epoch 11/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4710 - accuracy: 0.7635
# Epoch 12/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4700 - accuracy: 0.7666
# Epoch 13/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4673 - accuracy: 0.7716
# Epoch 14/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4674 - accuracy: 0.7722
# Epoch 15/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4647 - accuracy: 0.7719
# Epoch 16/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4631 - accuracy: 0.7753
# Epoch 17/100
# 94/94 [==============================] - 1s 10ms/step - loss: 0.4621 - accuracy: 0.7759
# Epoch 18/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4597 - accuracy: 0.7726
# Epoch 19/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4585 - accuracy: 0.7773
# Epoch 20/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4580 - accuracy: 0.7813
# Epoch 21/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4568 - accuracy: 0.7803
# Epoch 22/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4543 - accuracy: 0.7813
# Epoch 23/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4531 - accuracy: 0.7809
# Epoch 24/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4521 - accuracy: 0.7849
# Epoch 25/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4515 - accuracy: 0.7873
# Epoch 26/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4510 - accuracy: 0.7856
# Epoch 27/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4486 - accuracy: 0.7893
# Epoch 28/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4470 - accuracy: 0.7866
# Epoch 29/100
# 94/94 [==============================] - 1s 12ms/step - loss: 0.4472 - accuracy: 0.7906
# Epoch 30/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4458 - accuracy: 0.7890
# Epoch 31/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4445 - accuracy: 0.7863
# Epoch 32/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4418 - accuracy: 0.7926
# Epoch 33/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4419 - accuracy: 0.7910
# Epoch 34/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4415 - accuracy: 0.7916
# Epoch 35/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4391 - accuracy: 0.7913
# Epoch 36/100
# 94/94 [==============================] - ETA: 0s - loss: 0.4421 - accuracy: 0.78 - 1s 5ms/step - loss: 0.4385 - accuracy: 0.7926
# Epoch 37/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4375 - accuracy: 0.7953
# Epoch 38/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4372 - accuracy: 0.7946
# Epoch 39/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4342 - accuracy: 0.7916
# Epoch 40/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4342 - accuracy: 0.7946
# Epoch 41/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4321 - accuracy: 0.7973
# Epoch 42/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4332 - accuracy: 0.7936
# Epoch 43/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4289 - accuracy: 0.7930
# Epoch 44/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4313 - accuracy: 0.7950
# Epoch 45/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4297 - accuracy: 0.7983
# Epoch 46/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4278 - accuracy: 0.7970
# Epoch 47/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4273 - accuracy: 0.7977
# Epoch 48/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4262 - accuracy: 0.7987
# Epoch 49/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4253 - accuracy: 0.8017
# Epoch 50/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4241 - accuracy: 0.8037
# Epoch 51/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4235 - accuracy: 0.7983
# Epoch 52/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4249 - accuracy: 0.8013
# Epoch 53/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4216 - accuracy: 0.8007
# Epoch 54/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4219 - accuracy: 0.8033
# Epoch 55/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4223 - accuracy: 0.8037
# Epoch 56/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4185 - accuracy: 0.8017
# Epoch 57/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4184 - accuracy: 0.8027
# Epoch 58/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4174 - accuracy: 0.8077
# Epoch 59/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4186 - accuracy: 0.8070
# Epoch 60/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4162 - accuracy: 0.8097
# Epoch 61/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4152 - accuracy: 0.8057
# Epoch 62/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4153 - accuracy: 0.8104
# Epoch 63/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4128 - accuracy: 0.8117
# Epoch 64/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4135 - accuracy: 0.8074
# Epoch 65/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4118 - accuracy: 0.8067
# Epoch 66/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4110 - accuracy: 0.8097
# Epoch 67/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4111 - accuracy: 0.8094
# Epoch 68/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4099 - accuracy: 0.8120
# Epoch 69/100
# 94/94 [==============================] - 1s 11ms/step - loss: 0.4107 - accuracy: 0.8084
# Epoch 70/100
# 94/94 [==============================] - 1s 9ms/step - loss: 0.4090 - accuracy: 0.8074
# Epoch 71/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4091 - accuracy: 0.8067
# Epoch 72/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4073 - accuracy: 0.8117
# Epoch 73/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4072 - accuracy: 0.8137
# Epoch 74/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4076 - accuracy: 0.8097
# Epoch 75/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4057 - accuracy: 0.8100
# Epoch 76/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4053 - accuracy: 0.8114
# Epoch 77/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4038 - accuracy: 0.8074
# Epoch 78/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4056 - accuracy: 0.8094
# Epoch 79/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4045 - accuracy: 0.8097
# Epoch 80/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4009 - accuracy: 0.8130
# Epoch 81/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4029 - accuracy: 0.8137
# Epoch 82/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4014 - accuracy: 0.8107
# Epoch 83/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4015 - accuracy: 0.8154
# Epoch 84/100
# 94/94 [==============================] - 1s 8ms/step - loss: 0.4025 - accuracy: 0.8120
# Epoch 85/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4010 - accuracy: 0.8161
# Epoch 86/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3990 - accuracy: 0.8157
# Epoch 87/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3987 - accuracy: 0.8167
# Epoch 88/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3968 - accuracy: 0.8177
# Epoch 89/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3955 - accuracy: 0.8217
# Epoch 90/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3962 - accuracy: 0.8174
# Epoch 91/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3958 - accuracy: 0.8194
# Epoch 92/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3960 - accuracy: 0.8171
# Epoch 93/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3943 - accuracy: 0.8151
# Epoch 94/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3961 - accuracy: 0.8127
# Epoch 95/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3931 - accuracy: 0.8147
# Epoch 96/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3962 - accuracy: 0.8137
# Epoch 97/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3942 - accuracy: 0.8137
# Epoch 98/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3931 - accuracy: 0.8171
# Epoch 99/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3915 - accuracy: 0.8127
# Epoch 100/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.3918 - accuracy: 0.8134
# 44/44 [==============================] - 0s 5ms/step - loss: 0.5577 - accuracy: 0.7349
# [0.557671308517456, 0.7348969578742981]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80      1033
#            1       0.50      0.74      0.60       374
#
#     accuracy                           0.73      1407
#    macro avg       0.69      0.74      0.70      1407
# weighted avg       0.78      0.73      0.75      1407

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 2990, 4130)

y_pred3 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 83/83 [==============================] - 1s 6ms/step - loss: 0.6298 - accuracy: 0.6467
# Epoch 2/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.5265 - accuracy: 0.7564
# Epoch 3/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4935 - accuracy: 0.7700
# Epoch 4/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4816 - accuracy: 0.7769
# Epoch 5/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.7787
# Epoch 6/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4709 - accuracy: 0.7795
# Epoch 7/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4680 - accuracy: 0.7810
# Epoch 8/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4660 - accuracy: 0.7825
# Epoch 9/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4626 - accuracy: 0.7875
# Epoch 10/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4621 - accuracy: 0.7867
# Epoch 11/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4584 - accuracy: 0.7871
# Epoch 12/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4558 - accuracy: 0.7856
# Epoch 13/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4537 - accuracy: 0.7909
# Epoch 14/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4522 - accuracy: 0.7905: 0s - loss: 0.4541 - accuracy: 0.78
# Epoch 15/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4506 - accuracy: 0.7882
# Epoch 16/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4498 - accuracy: 0.7917
# Epoch 17/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4483 - accuracy: 0.7954
# Epoch 18/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4479 - accuracy: 0.7939
# Epoch 19/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4445 - accuracy: 0.7924
# Epoch 20/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4418 - accuracy: 0.8008
# Epoch 21/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4410 - accuracy: 0.7996
# Epoch 22/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4394 - accuracy: 0.7966
# Epoch 23/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4376 - accuracy: 0.7996
# Epoch 24/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4362 - accuracy: 0.8011
# Epoch 25/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4355 - accuracy: 0.8038
# Epoch 26/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4342 - accuracy: 0.8042
# Epoch 27/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4319 - accuracy: 0.8061
# Epoch 28/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4303 - accuracy: 0.8027
# Epoch 29/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4295 - accuracy: 0.8046
# Epoch 30/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4270 - accuracy: 0.8065
# Epoch 31/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4269 - accuracy: 0.8099
# Epoch 32/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4250 - accuracy: 0.8129
# Epoch 33/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4234 - accuracy: 0.8095: 0s - loss: 0.4185 - accu
# Epoch 34/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4217 - accuracy: 0.8125
# Epoch 35/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4206 - accuracy: 0.8091
# Epoch 36/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4180 - accuracy: 0.8095
# Epoch 37/100
# 83/83 [==============================] - 0s 5ms/step - loss: 0.4169 - accuracy: 0.8114
# Epoch 38/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4155 - accuracy: 0.8125
# Epoch 39/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4146 - accuracy: 0.8087
# Epoch 40/100
# 83/83 [==============================] - 1s 6ms/step - loss: 0.4133 - accuracy: 0.8106
# Epoch 41/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4133 - accuracy: 0.8114
# Epoch 42/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4104 - accuracy: 0.8099
# Epoch 43/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4097 - accuracy: 0.8133
# Epoch 44/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4095 - accuracy: 0.8152
# Epoch 45/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.4059 - accuracy: 0.8209
# Epoch 46/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.4059 - accuracy: 0.8175
# Epoch 47/100
# 83/83 [==============================] - 0s 6ms/step - loss: 0.4039 - accuracy: 0.8159
# Epoch 48/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.4030 - accuracy: 0.8216
# Epoch 49/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.4017 - accuracy: 0.8182
# Epoch 50/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.4011 - accuracy: 0.8186
# Epoch 51/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.4020 - accuracy: 0.8178
# Epoch 52/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3974 - accuracy: 0.8224
# Epoch 53/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3979 - accuracy: 0.8228
# Epoch 54/100
# 83/83 [==============================] - 1s 11ms/step - loss: 0.3955 - accuracy: 0.8205
# Epoch 55/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3975 - accuracy: 0.8216
# Epoch 56/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3949 - accuracy: 0.8228
# Epoch 57/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3932 - accuracy: 0.8243
# Epoch 58/100
# 83/83 [==============================] - 1s 10ms/step - loss: 0.3939 - accuracy: 0.8216 0s - l
# Epoch 59/100
# 83/83 [==============================] - 1s 10ms/step - loss: 0.3924 - accuracy: 0.8231
# Epoch 60/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3901 - accuracy: 0.8231
# Epoch 61/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3889 - accuracy: 0.8224
# Epoch 62/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3874 - accuracy: 0.8258
# Epoch 63/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3859 - accuracy: 0.8266
# Epoch 64/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3868 - accuracy: 0.8319
# Epoch 65/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3851 - accuracy: 0.8205
# Epoch 66/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3846 - accuracy: 0.8254
# Epoch 67/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3832 - accuracy: 0.8228
# Epoch 68/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3821 - accuracy: 0.8300
# Epoch 69/100
# 83/83 [==============================] - 1s 11ms/step - loss: 0.3803 - accuracy: 0.8292
# Epoch 70/100
# 83/83 [==============================] - 1s 10ms/step - loss: 0.3813 - accuracy: 0.8285
# Epoch 71/100
# 83/83 [==============================] - 1s 13ms/step - loss: 0.3818 - accuracy: 0.8239
# Epoch 72/100
# 83/83 [==============================] - 1s 12ms/step - loss: 0.3771 - accuracy: 0.8304
# Epoch 73/100
# 83/83 [==============================] - 1s 9ms/step - loss: 0.3772 - accuracy: 0.8326
# Epoch 74/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3774 - accuracy: 0.8292
# Epoch 75/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3752 - accuracy: 0.8338
# Epoch 76/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3758 - accuracy: 0.8311
# Epoch 77/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3757 - accuracy: 0.8380
# Epoch 78/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3738 - accuracy: 0.8326
# Epoch 79/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3751 - accuracy: 0.8300
# Epoch 80/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3721 - accuracy: 0.8323
# Epoch 81/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3707 - accuracy: 0.8323
# Epoch 82/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3700 - accuracy: 0.8353
# Epoch 83/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3707 - accuracy: 0.8323
# Epoch 84/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3680 - accuracy: 0.8349
# Epoch 85/100
# 83/83 [==============================] - 1s 11ms/step - loss: 0.3665 - accuracy: 0.8338
# Epoch 86/100
# 83/83 [==============================] - 2s 22ms/step - loss: 0.3669 - accuracy: 0.8342
# Epoch 87/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3660 - accuracy: 0.8372
# Epoch 88/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3653 - accuracy: 0.8361
# Epoch 89/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3665 - accuracy: 0.8383
# Epoch 90/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3632 - accuracy: 0.8338
# Epoch 91/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3620 - accuracy: 0.8368
# Epoch 92/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3638 - accuracy: 0.8353
# Epoch 93/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3616 - accuracy: 0.8406
# Epoch 94/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3605 - accuracy: 0.8376
# Epoch 95/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3595 - accuracy: 0.8414
# Epoch 96/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3571 - accuracy: 0.8425
# Epoch 97/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3578 - accuracy: 0.8410
# Epoch 98/100
# 83/83 [==============================] - 1s 8ms/step - loss: 0.3571 - accuracy: 0.8398
# Epoch 99/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3554 - accuracy: 0.8414
# Epoch 100/100
# 83/83 [==============================] - 1s 7ms/step - loss: 0.3544 - accuracy: 0.8440
# 44/44 [==============================] - 0s 5ms/step - loss: 0.6490 - accuracy: 0.6965
# [0.6489760875701904, 0.6965174078941345]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      1033
#            1       0.46      0.82      0.59       374
#
#     accuracy                           0.70      1407
#    macro avg       0.68      0.73      0.67      1407
# weighted avg       0.79      0.70      0.71      1407

# %%
len(y_pred1)
# Out:
# 1407

# %%
y_pred_final = y_pred1.copy()
for i in range(len(y_pred1)):
    n_ones = y_pred1[i] + y_pred2[i] + y_pred3[i]
    if n_ones>1:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
cl_rep = classification_report(y_test, y_pred_final)
print(cl_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79      1033
#            1       0.49      0.79      0.60       374
#
#     accuracy                           0.73      1407
#    macro avg       0.70      0.75      0.70      1407
# weighted avg       0.79      0.73      0.74      1407

# %% [markdown]
# f1-score for minority class 1 improved to **0.62 from 0.57**. The score for majority class 0 is suffering and reduced to 0.80 from 0.85 but at least there is some balance in terms of prediction accuracy across two classes

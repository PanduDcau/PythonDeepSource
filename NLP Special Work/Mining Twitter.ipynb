# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %%
pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\user\anaconda3\lib\site-packages (1.19.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'MnOZufTf403NLdcAlHoNx6xbW'
CONSUMER_SECRET ='XnDkE3JDbS5AAVJSfhgnSYl9il8Pr069i4uZK8rLi7Jz2v3Bfd'
OAUTH_TOKEN = '1559778637897175040-RrSGBRoXqCZKsZ822NWD76zxKr2B6M'
OAUTH_TOKEN_SECRET = 'dC1XKcpKruVjG2F6soUQJhtnU2AvDSNiFVqJQG7rrd1Wo'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000190A5322C18>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print (world_trends)
print
print (us_trends)
# Out:
# [{'trends': [{'name': '#모일수록_완벽한_드림6주년', 'url': 'http://twitter.com/search?q=%23%EB%AA%A8%EC%9D%BC%EC%88%98%EB%A1%9D_%EC%99%84%EB%B2%BD%ED%95%9C_%EB%93%9C%EB%A6%BC6%EC%A3%BC%EB%85%84', 'promoted_content': None, 'query': '%23%EB%AA%A8%EC%9D%BC%EC%88%98%EB%A1%9D_%EC%99%84%EB%B2%BD%ED%95%9C_%EB%93%9C%EB%A6%BC6%EC%A3%BC%EB%85%84', 'tweet_volume': 106479}, {'name': '#6rowingUpWith7DREAM', 'url': 'http://twitter.com/search?q=%236rowingUpWith7DREAM', 'promoted_content': None, 'query': '%236rowingUpWith7DREAM', 'tweet_volume': 105973}, {'name': '#VEMP', 'url': 'http://twitter.com/search?q=%23VEMP', 'promoted_content': None, 'query': '%23VEMP', 'tweet_volume': None}, {'name': '#ドミノピザ', 'url': 'http://twitter.com/search?q=%23%E3%83%89%E3%83%9F%E3%83%8E%E3%83%94%E3%82%B6', 'promoted_content': None, 'query': '%23%E3%83%89%E3%83%9F%E3%83%8E%E3%83%94%E3%82%B6', 'tweet_volume': 16813}, {'name': '#チーズファンタジーIQ', 'url': 'http://twitter.com/search?q=%23%E3%83%81%E3%83%BC%E3%82%BA%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BCIQ', 'promoted_content': None, 'query': '%23%E3%83%81%E3%83%BC%E3%82%BA%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BCIQ', 'tweet_volume': 15388}, {'name': 'ピザ無料券', 'url': 'http://twitter.com/search?q=%E3%83%94%E3%82%B6%E7%84%A1%E6%96%99%E5%88%B8', 'promoted_content': None, 'query': '%E3%83%94%E3%82%B6%E7%84%A1%E6%96%99%E5%88%B8', 'tweet_volume': 15991}, {'name': 'ドミノの投稿', 'url': 'http://twitter.com/search?q=%E3%83%89%E3%83%9F%E3%83%8E%E3%81%AE%E6%8A%95%E7%A8%BF', 'promoted_content': None, 'query': '%E3%83%89%E3%83%9F%E3%83%8E%E3%81%AE%E6%8A%95%E7%A8%BF', 'tweet_volume': 15698}, {'name': 'McLaren', 'url': 'http://twitter.com/search?q=McLaren', 'promoted_content': None, 'query': 'McLaren', 'tweet_volume': 39251}, {'name': 'Isak', 'url': 'http://twitter.com/search?q=Isak', 'promoted_content': None, 'query': 'Isak', 'tweet_volume': 43019}, {'name': 'NCT DREAM 6TH ANNIVERSARY', 'url': 'http://twitter.com/search?q=%22NCT+DREAM+6TH+ANNIVERSARY%22', 'promoted_content': None, 'query': '%22NCT+DREAM+6TH+ANNIVERSARY%22', 'tweet_volume': 111878}, {'name': '自分のIQ', 'url': 'http://twitter.com/search?q=%E8%87%AA%E5%88%86%E3%81%AEIQ', 'promoted_content': None, 'query': '%E8%87%AA%E5%88%86%E3%81%AEIQ', 'tweet_volume': None}, {'name': 'CHENLE', 'url': 'http://twitter.com/search?q=CHENLE', 'promoted_content': None, 'query': 'CHENLE', 'tweet_volume': 156474}, {'name': '通信障害', 'url': 'http://twitter.com/search?q=%E9%80%9A%E4%BF%A1%E9%9A%9C%E5%AE%B3', 'promoted_content': None, 'query': '%E9%80%9A%E4%BF%A1%E9%9A%9C%E5%AE%B3', 'tweet_volume': 13302}, {'name': 'Daniel Ricciardo', 'url': 'http://twitter.com/search?q=%22Daniel+Ricciardo%22', 'promoted_content': None, 'query': '%22Daniel+Ricciardo%22', 'tweet_volume': 20450}, {'name': 'Len Dawson', 'url': 'http://twitter.com/search?q=%22Len+Dawson%22', 'promoted_content': None, 'query': '%22Len+Dawson%22', 'tweet_volume': 12627}, {'name': 'KDDI', 'url': 'http://twitter.com/search?q=KDDI', 'promoted_content': None, 'query': 'KDDI', 'tweet_volume': 16680}, {'name': '坂本くん', 'url': 'http://twitter.com/search?q=%E5%9D%82%E6%9C%AC%E3%81%8F%E3%82%93', 'promoted_content': None, 'query': '%E5%9D%82%E6%9C%AC%E3%81%8F%E3%82%93', 'tweet_volume': None}, {'name': 'Alpine', 'url': 'http://twitter.com/search?q=Alpine', 'promoted_content': None, 'query': 'Alpine', 'tweet_volume': None}, {'name': 'Piastri', 'url': 'http://twitter.com/search?q=Piastri', 'promoted_content': None, 'query': 'Piastri', 'tweet_volume': None}, {'name': 'Kwesta', 'url': 'http://twitter.com/search?q=Kwesta', 'promoted_content': None, 'query': 'Kwesta', 'tweet_volume': None}, {'name': 'Paqueta', 'url': 'http://twitter.com/search?q=Paqueta', 'promoted_content': None, 'query': 'Paqueta', 'tweet_volume': 14474}, {'name': 'au圏外', 'url': 'http://twitter.com/search?q=au%E5%9C%8F%E5%A4%96', 'promoted_content': None, 'query': 'au%E5%9C%8F%E5%A4%96', 'tweet_volume': None}, {'name': 'Danny Ric', 'url': 'http://twitter.com/search?q=%22Danny+R ...
# [{'trends': [{'name': 'Len Dawson', 'url': 'http://twitter.com/search?q=%22Len+Dawson%22', 'promoted_content': None, 'query': '%22Len+Dawson%22', 'tweet_volume': 12614}, {'name': '#VEMP', 'url': 'http://twitter.com/search?q=%23VEMP', 'promoted_content': None, 'query': '%23VEMP', 'tweet_volume': None}, {'name': '#wednesdaythought', 'url': 'http://twitter.com/search?q=%23wednesdaythought', 'promoted_content': None, 'query': '%23wednesdaythought', 'tweet_volume': 13452}, {'name': '#VenmoMe', 'url': 'http://twitter.com/search?q=%23VenmoMe', 'promoted_content': None, 'query': '%23VenmoMe', 'tweet_volume': 15770}, {'name': '#studentloanforgiveness', 'url': 'http://twitter.com/search?q=%23studentloanforgiveness', 'promoted_content': None, 'query': '%23studentloanforgiveness', 'tweet_volume': None}, {'name': 'Inside the NFL', 'url': 'http://twitter.com/search?q=%22Inside+the+NFL%22', 'promoted_content': None, 'query': '%22Inside+the+NFL%22', 'tweet_volume': None}, {'name': 'McLaren', 'url': 'http://twitter.com/search?q=McLaren', 'promoted_content': None, 'query': 'McLaren', 'tweet_volume': 39502}, {'name': '#NationalWaffleDay', 'url': 'http://twitter.com/search?q=%23NationalWaffleDay', 'promoted_content': None, 'query': '%23NationalWaffleDay', 'tweet_volume': None}, {'name': 'Fresca', 'url': 'http://twitter.com/search?q=Fresca', 'promoted_content': None, 'query': 'Fresca', 'tweet_volume': None}, {'name': 'Gesicki', 'url': 'http://twitter.com/search?q=Gesicki', 'promoted_content': None, 'query': 'Gesicki', 'tweet_volume': None}, {'name': 'Irv Gotti', 'url': 'http://twitter.com/search?q=%22Irv+Gotti%22', 'promoted_content': None, 'query': '%22Irv+Gotti%22', 'tweet_volume': None}, {'name': 'Isak', 'url': 'http://twitter.com/search?q=Isak', 'promoted_content': None, 'query': 'Isak', 'tweet_volume': 42936}, {'name': 'Swatted', 'url': 'http://twitter.com/search?q=Swatted', 'promoted_content': None, 'query': 'Swatted', 'tweet_volume': None}, {'name': 'Danny Ric', 'url': 'http://twitter.com/search?q=%22Danny+Ric%22', 'promoted_content': None, 'query': '%22Danny+Ric%22', 'tweet_volume': None}, {'name': 'Daily Quordle 212', 'url': 'http://twitter.com/search?q=%22Daily+Quordle+212%22', 'promoted_content': None, 'query': '%22Daily+Quordle+212%22', 'tweet_volume': None}, {'name': 'Ashanti', 'url': 'http://twitter.com/search?q=Ashanti', 'promoted_content': None, 'query': 'Ashanti', 'tweet_volume': None}, {'name': 'Hump Day', 'url': 'http://twitter.com/search?q=%22Hump+Day%22', 'promoted_content': None, 'query': '%22Hump+Day%22', 'tweet_volume': 21059}, {'name': 'Ricciardo', 'url': 'http://twitter.com/search?q=Ricciardo', 'promoted_content': None, 'query': 'Ricciardo', 'tweet_volume': 25222}, {'name': 'chenle', 'url': 'http://twitter.com/search?q=chenle', 'promoted_content': None, 'query': 'chenle', 'tweet_volume': 156809}, {'name': 'Independence Day', 'url': 'http://twitter.com/search?q=%22Independence+Day%22', 'promoted_content': None, 'query': '%22Independence+Day%22', 'tweet_volume': 148964}, {'name': 'Hurricane Andrew', 'url': 'http://twitter.com/search?q=%22Hurricane+Andrew%22', 'promoted_content': None, 'query': '%22Hurricane+Andrew%22', 'tweet_volume': None}, {'name': 'Don Coryell', 'url': 'http://twitter.com/search?q=%22Don+Coryell%22', 'promoted_content': None, 'query': '%22Don+Coryell%22', 'tweet_volume': None}, {'name': 'Good Wednesday', 'url': 'http://twitter.com/search?q=%22Good+Wednesday%22', 'promoted_content': None, 'query': '%22Good+Wednesday%22', 'tweet_volume': 27635}, {'name': 'Happy Hump', 'url': 'http://twitter.com/search?q=%22Happy+Hump%22', 'promoted_content': None, 'query': '%22Happy+Hump%22', 'tweet_volume': 12108}, {'name': 'Sam Mendes', 'url': 'http://twitter.com/search?q=%22Sam+Mendes%22', 'promoted_content': None, 'query': '%22Sam+Mendes%22', 'tweet_volume': None}, {'name': 'Jay Monahan', 'url': 'http://twitter.com/search?q=%22Jay+Monahan%22', 'promoted_content': None, 'query': '%22Jay+Monahan%22', 'tweet_volume': None ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print (json.dumps(world_trends, indent=1))
print
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#\ubaa8\uc77c\uc218\ub85d_\uc644\ubcbd\ud55c_\ub4dc\ub9bc6\uc8fc\ub144",
#     "url": "http://twitter.com/search?q=%23%EB%AA%A8%EC%9D%BC%EC%88%98%EB%A1%9D_%EC%99%84%EB%B2%BD%ED%95%9C_%EB%93%9C%EB%A6%BC6%EC%A3%BC%EB%85%84",
#     "promoted_content": null,
#     "query": "%23%EB%AA%A8%EC%9D%BC%EC%88%98%EB%A1%9D_%EC%99%84%EB%B2%BD%ED%95%9C_%EB%93%9C%EB%A6%BC6%EC%A3%BC%EB%85%84",
#     "tweet_volume": 106479
#    },
#    {
#     "name": "#6rowingUpWith7DREAM",
#     "url": "http://twitter.com/search?q=%236rowingUpWith7DREAM",
#     "promoted_content": null,
#     "query": "%236rowingUpWith7DREAM",
#     "tweet_volume": 105973
#    },
#    {
#     "name": "#VEMP",
#     "url": "http://twitter.com/search?q=%23VEMP",
#     "promoted_content": null,
#     "query": "%23VEMP",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u30c9\u30df\u30ce\u30d4\u30b6",
#     "url": "http://twitter.com/search?q=%23%E3%83%89%E3%83%9F%E3%83%8E%E3%83%94%E3%82%B6",
#     "promoted_content": null,
#     "query": "%23%E3%83%89%E3%83%9F%E3%83%8E%E3%83%94%E3%82%B6",
#     "tweet_volume": 16813
#    },
#    {
#     "name": "#\u30c1\u30fc\u30ba\u30d5\u30a1\u30f3\u30bf\u30b8\u30fcIQ",
#     "url": "http://twitter.com/search?q=%23%E3%83%81%E3%83%BC%E3%82%BA%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BCIQ",
#     "promoted_content": null,
#     "query": "%23%E3%83%81%E3%83%BC%E3%82%BA%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BCIQ",
#     "tweet_volume": 15388
#    },
#    {
#     "name": "\u30d4\u30b6\u7121\u6599\u5238",
#     "url": "http://twitter.com/search?q=%E3%83%94%E3%82%B6%E7%84%A1%E6%96%99%E5%88%B8",
#     "promoted_content": null,
#     "query": "%E3%83%94%E3%82%B6%E7%84%A1%E6%96%99%E5%88%B8",
#     "tweet_volume": 15991
#    },
#    {
#     "name": "\u30c9\u30df\u30ce\u306e\u6295\u7a3f",
#     "url": "http://twitter.com/search?q=%E3%83%89%E3%83%9F%E3%83%8E%E3%81%AE%E6%8A%95%E7%A8%BF",
#     "promoted_content": null,
#     "query": "%E3%83%89%E3%83%9F%E3%83%8E%E3%81%AE%E6%8A%95%E7%A8%BF",
#     "tweet_volume": 15698
#    },
#    {
#     "name": "McLaren",
#     "url": "http://twitter.com/search?q=McLaren",
#     "promoted_content": null,
#     "query": "McLaren",
#     "tweet_volume": 39251
#    },
#    {
#     "name": "Isak",
#     "url": "http://twitter.com/search?q=Isak",
#     "promoted_content": null,
#     "query": "Isak",
#     "tweet_volume": 43019
#    },
#    {
#     "name": "NCT DREAM 6TH ANNIVERSARY",
#     "url": "http://twitter.com/search?q=%22NCT+DREAM+6TH+ANNIVERSARY%22",
#     "promoted_content": null,
#     "query": "%22NCT+DREAM+6TH+ANNIVERSARY%22",
#     "tweet_volume": 111878
#    },
#    {
#     "name": "\u81ea\u5206\u306eIQ",
#     "url": "http://twitter.com/search?q=%E8%87%AA%E5%88%86%E3%81%AEIQ",
#     "promoted_content": null,
#     "query": "%E8%87%AA%E5%88%86%E3%81%AEIQ",
#     "tweet_volume": null
#    },
#    {
#     "name": "CHENLE",
#     "url": "http://twitter.com/search?q=CHENLE",
#     "promoted_content": null,
#     "query": "CHENLE",
#     "tweet_volume": 156474
#    },
#    {
#     "name": "\u901a\u4fe1\u969c\u5bb3",
#     "url": "http://twitter.com/search?q=%E9%80%9A%E4%BF%A1%E9%9A%9C%E5%AE%B3",
#     "promoted_content": null,
#     "query": "%E9%80%9A%E4%BF%A1%E9%9A%9C%E5%AE%B3",
#     "tweet_volume": 13302
#    },
#    {
#     "name": "Daniel Ricciardo",
#     "url": "http://twitter.com/search?q=%22Daniel+Ricciardo%22",
#     "promoted_content": null,
#     "query": "%22Daniel+Ricciardo%22",
#     "tweet_volume": 20450
#    },
#    {
#     "name": "Len Dawson",
#     "url": "http://twitter.com/search?q=%22Len+Dawson%22",
#     "promoted_content": null,
#     "query": "%22Len+Dawson%22",
#     "tweet_volume": 12627
#    },
#    {
#     "name": "KDDI",
#     "url": "http://twitter.com/search?q=KDDI",
#     "promoted_content": null,
#     "query": "KDDI",
#     "tweet_volume": 16680
#    },
#    {
#     "name": "\u5742\u672c\u304f\u3093",
#     "url": "http://twitter.com/search?q=%E5%9D%82%E6%9C%AC%E3%81%8F%E3%82%93",
#     "promoted_content": null,
#     "query": "%E5%9D%82%E6%9C%AC%E3%81%8F%E3%82%93",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alpine",
#     "url": "http://twitter.com/search?q=Alpine",
#     "promoted_content": null,
#     "query": "Alpine",
#     "tweet_volume": null
#    },
#    {
#     "name": "Piastri",
#     "url": "http://twitter.com/search?q=Piastri",
#     "promoted_content": null,
#     "query": "Piastri",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kwesta",
#     "url": "http://twitter.com/search?q=Kwesta",
#     "promoted_content": null,
#     "query": "Kwesta",
#     "tweet_volume": null
#    },
#    {
#     "name": "Paqueta",
#     "url": "http://twitter.com/search?q=Paqueta",
#     "promoted_content": null,
#     "query": "Paqueta",
#     "tweet_volume": 14474
#    },
#    {
#     "name": "au\u570f\u5916",
#     "url": "http://twitter.com/search?q=au%E5%9C%8F%E5%A4%96",
#     "promoted_content": null,
#     "query": "au%E5%9C%8F%E5%A4%96",
#     "tweet_volume": null
#    },
#    {
#     "name": "Danny Ric",
#     "url": "http://twitter.com/search?q=%22Danny+Ric%22",
#     "promoted_content": null,
#     "query": "%22Danny+Ric%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u307e\u308a\u307b\u30fc",
#     "url": "http://twitter.com/search?q=%E3%81%BE%E3%82%8A%E3%81%BB%E3%83%BC",
#     "promoted_content": null,
#     "query": "%E3%81%BE%E3%82%8A%E3%81%BB%E3%83%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "SB19 On PepsiTambahay",
#     "url": "http://twitter.com/search?q=%22SB19+On+PepsiTambahay%22",
#     "promoted_content": null,
#     "query": "%22SB19+On+PepsiTambahay%22",
#     "tweet_volume": 78013
#    },
#    {
#     "name": "\u65b0\u30b7\u30ca\u30ea\u30aa",
#     "url": "http://twitter.com/search?q=%E6%96%B0%E3%82%B7%E3%83%8A%E3%83%AA%E3%82%AA",
#     "promoted_content": null,
#     "query": "%E6%96%B0%E3%82%B7%E3%83%8A%E3%83%AA%E3%82%AA",
#     "tweet_volume": 67016
#    },
#    {
#     "name": "\u305f\u304b\u307b\u30fc",
#     "url": "http://twitter.com/search?q=%E3%81%9F%E3%81%8B%E3%81%BB%E3%83%BC",
#     "promoted_content": null,
#     "query": "%E3%81%9F%E3%81%8B%E3%81%BB%E3%83%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "Min Yoongi",
#     "url": "http://twitter.com/search?q=%22Min+Yoongi%22",
#     "promoted_content": null,
#     "query": "%22Min+Yoongi%22",
#     "tweet_volume": 53463
#    },
#    {
#     "name": "Dele Alli",
#     "url": "http://twitter.com/search?q=%22Dele+Alli%22",
#     "promoted_content": null,
#     "query": "%22Dele+Alli%22",
#     "tweet_volume": 14243
#    },
#    {
#     "name": "\u5fa9\u6d3b\u306e\u30b3\u30a2\u30e1\u30c0\u30eb",
#     "url": "http://twitter.com/search?q=%E5%BE%A9%E6%B4%BB%E3%81%AE%E3%82%B3%E3%82%A2%E3%83%A1%E3%83%80%E3%83%AB",
#     "promoted_content": null,
#     "query": "%E5%BE%A9%E6%B4%BB%E3%81%AE%E3%82%B3%E3%82%A2%E3%83%A1%E3%83%80%E3%83%AB",
#     "tweet_volume": 15582
#    },
#    {
#     "name": "TalkThatTalk MV Teaser2",
#     "url": "http://twitter.com/search?q=%22TalkThatTalk+MV+Teaser2%22",
#     "promoted_content": null,
#     "query": "%22TalkThatTalk+MV+Teaser2%22",
#     "tweet_volume": 29797
#    },
#    {
#     "name": "\u5996\u602a\u5a18\u5316",
#     "url": "http://twitter.com/search?q=%E5%A6%96%E6%80%AA%E5%A8%98%E5%8C%96",
#     "promoted_content": null,
#     "query": "%E5%A6%96%E6%80%AA%E5%A8%98%E5%8C%96",
#     "tweet_volume": null
#    },
#    {
#     "name": "VMARMY SWIPE FOR BTS",
#     "url": "http://twitter.com/search?q=%22VMARMY+SWIPE+FOR+BTS%22",
#     "promoted_content": null,
#     "query": "%22VMARMY+SWIPE+FOR+BTS%22",
#     "tweet_volume": 50706
#    },
#    {
#     "name": "\u9996\u4f4d\u596a\u9084",
#     "url": "http://twitter.com/search?q=%E9%A6%96%E4%BD%8D%E5%A5%AA%E9%82%84",
#     "promoted_content": null,
#     "query": "%E9%A6%96%E4%BD%8D%E5%A5%AA%E9%82%84",
#     "tweet_volume": null
#    },
#    {
#     "name": "GIRLS' LEGEND U",
#     "url": "http://twitter.com/search?q=%22GIRLS%27+LEGEND+U%22",
#     "promoted_content": null,
#     "query": "%22GIRLS%27+LEGEND+U%22",
#     "tweet_volume": 10786
#    },
#    {
#     "name": "\u30e4\u30b9\u30a2\u30ad",
#     "url": "http://twitter.com/search?q=%E3%83%A4%E3%82%B9%E3%82%A2%E3%82%AD",
#     "promoted_content": null,
#     "query": "%E3%83%A4%E3%82%B9%E3%82%A2%E3%82%AD",
#     "tweet_volume": null
#    },
#    {
#     "name": "Arctic Monkeys",
#     "url": "http://twitter.com/search?q=%22Arctic+Monkeys%22",
#     "promoted_content": null,
#     "query": "%22Arctic+Monkeys%22",
#     "tweet_volume": 45405
#    },
#    {
#     "name": "\u3059\u308f\u307b\u30fc",
#     "url": "http://twitter.com/search?q=%E3%81%99%E3%82%8F%E3%81%BB%E3%83%BC",
#     "promoted_content": null,
#     "query": "%E3%81%99%E3%82%8F%E3%81%BB%E3%83%BC",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Car",
#     "url": "http://twitter.com/search?q=%22The+Car%22",
#     "promoted_content": null,
#     "query": "%22The+Car%22",
#     "tweet_volume": 183343
#    },
#    {
#     "name": "\uc0b0\ub9ac\uc624 \uc7a0\uc637",
#     "url": "http://twitter.com/search?q=%22%EC%82%B0%EB%A6%AC%EC%98%A4+%EC%9E%A0%EC%98%B7%22",
#     "promoted_content": null,
#     "query": "%22%EC%82%B0%EB%A6%AC%EC%98%A4+%EC%9E%A0%EC%98%B7%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u677e\u6c5f\u9ad8\u5c02",
#     "url": "http://twitter.com/search?q=%E6%9D%BE%E6%B1%9F%E9%AB%98%E5%B0%82",
#     "promoted_content": null,
#     "query": "%E6%9D%BE%E6%B1%9F%E9%AB%98%E5%B0%82",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u30ea\u30ab\u30eb\u30c9",
#     "url": "http://twitter.com/search?q=%E3%83%AA%E3%82%AB%E3%83%AB%E3%83%89",
#     "promoted_content": null,
#     "query": "%E3%83%AA%E3%82%AB%E3%83%AB%E3%83%89",
#     "tweet_volume": null
#    },
#    {
#     "name": "Anne Marie",
#     "url": "http://twitter.com/search?q=%22Anne+Marie%22",
#     "promoted_content": null,
#     "query": "%22Anne+Marie%22",
#     "tweet_volume": 93710
#    },
#    {
#     "name": "#TOKIO\u30ab\u30b1\u30eb",
#     "url": "http://twitter.com/search?q=%23TOKIO%E3%82%AB%E3%82%B1%E3%83%AB",
#     "promoted_content": null,
#     "query": "%23TOKIO%E3%82%AB%E3%82%B1%E3%83%AB",
#     "tweet_volume": 11180
#    },
#    {
#     "name": "#DragRacePH",
#     "url": "http://twitter.com/search?q=%23DragRacePH",
#     "promoted_content": null,
#     "query": "%23DragRacePH",
#     "tweet_volume": 22972
#    },
#    {
#     "name": "#\u6c34\u66dc\u65e5\u306e\u30c0\u30a6\u30f3\u30bf\u30a6\u30f3",
#     "url": "http://twitter.com/search?q=%23%E6%B0%B4%E6%9B%9C%E6%97%A5%E3%81%AE%E3%83%80%E3%82%A6%E3%83%B3%E3%82%BF%E3%82%A6%E3%83%B3",
#     "promoted_content": null,
#     "query": "%23%E6%B0%B4%E6%9B%9C%E6%97%A5%E3%81%AE%E3%83%80%E3%82%A6%E3%83%B3%E3%82%BF%E3%82%A6%E3%83%B3",
#     "tweet_volume": 10625
#    },
#    {
#     "name": "#\u795d_CALL119_MV1000\u4e07\u56de",
#     "url": "http://twitter.com/search?q=%23%E7%A5%9D_CALL119_MV1000%E4%B8%87%E5%9B%9E",
#     "promoted_content": null,
#     "query": "%23%E7%A5%9D_CALL119_MV1000%E4%B8%87%E5%9B%9E",
#     "tweet_volume": 21602
#    },
#    {
#     "name": "#A\u3047\u30e4\u30f3\u30bf\u30f3",
#     "url": "http://twitter.com/search?q=%23A%E3%81%87%E3%83%A4%E3%83%B3%E3%82%BF%E3%83%B3",
#     "promoted_content": null,
#     "query": "%23A%E3%81%87%E3%83%A4%E3%83%B3%E3%82%BF%E3%83%B3",
#     "tweet_volume": 40903
#    },
#    {
#     "name": "#JO1\u304a\u304b\u3048\u308a",
#     "url": "http://twitter.com/search?q=%23JO1%E3%81%8A%E3%81%8B%E3%81%88%E3%82%8A",
#     "promoted_content": null,
#     "query": "%23JO1%E3%81%8A%E3%81%8B%E3%81%88%E3%82%8A",
#     "tweet_volume": null
#    },
#    {
#     "name": "#stayselcaday",
#     "url": "http://twitter.com/search?q=%23stayselcaday",
#     "promoted_content": null,
#     "query": "%23stayselcaday",
#     "tweet_volume": 17790
#    }
#   ],
#   "as_of": "2022-08-24T14:43:57Z",
#   "created_at": "2022-08-23T10:36:17Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "Len Dawson",
#     "url": "http://twitter.com/search?q=%22Len+Dawson%22",
#     "promoted_content": null,
#     "query": "%22Len+Dawson%22",
#     "tweet_volume": 12614
#    },
#    {
#     "name": "#VEMP",
#     "url": "http://twitter.com/search?q=%23VEMP",
#     "promoted_content": null,
#     "query": "%23VEMP",
#     "tweet_volume": null
#    },
#    {
#     "name": "#wednesdaythought",
#     "url": "http://twitter.com/search?q=%23wednesdaythought",
#     "promoted_content": null,
#     "query": "%23wednesdaythought",
#     "tweet_volume": 13452
#    },
#    {
#     "name": "#VenmoMe",
#     "url": "http://twitter.com/search?q=%23VenmoMe",
#     "promoted_content": null,
#     "query": "%23VenmoMe",
#     "tweet_volume": 15770
#    },
#    {
#     "name": "#studentloanforgiveness",
#     "url": "http://twitter.com/search?q=%23studentloanforgiveness",
#     "promoted_content": null,
#     "query": "%23studentloanforgiveness",
#     "tweet_volume": null
#    },
#    {
#     "name": "Inside the NFL",
#     "url": "http://twitter.com/search?q=%22Inside+the+NFL%22",
#     "promoted_content": null,
#     "query": "%22Inside+the+NFL%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "McLaren",
#     "url": "http://twitter.com/search?q=McLaren",
#     "promoted_content": null,
#     "query": "McLaren",
#     "tweet_volume": 39502
#    },
#    {
#     "name": "#NationalWaffleDay",
#     "url": "http://twitter.com/search?q=%23NationalWaffleDay",
#     "promoted_content": null,
#     "query": "%23NationalWaffleDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fresca",
#     "url": "http://twitter.com/search?q=Fresca",
#     "promoted_content": null,
#     "query": "Fresca",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gesicki",
#     "url": "http://twitter.com/search?q=Gesicki",
#     "promoted_content": null,
#     "query": "Gesicki",
#     "tweet_volume": null
#    },
#    {
#     "name": "Irv Gotti",
#     "url": "http://twitter.com/search?q=%22Irv+Gotti%22",
#     "promoted_content": null,
#     "query": "%22Irv+Gotti%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Isak",
#     "url": "http://twitter.com/search?q=Isak",
#     "promoted_content": null,
#     "query": "Isak",
#     "tweet_volume": 42936
#    },
#    {
#     "name": "Swatted",
#     "url": "http://twitter.com/search?q=Swatted",
#     "promoted_content": null,
#     "query": "Swatted",
#     "tweet_volume": null
#    },
#    {
#     "name": "Danny Ric",
#     "url": "http://twitter.com/search?q=%22Danny+Ric%22",
#     "promoted_content": null,
#     "query": "%22Danny+Ric%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Daily Quordle 212",
#     "url": "http://twitter.com/search?q=%22Daily+Quordle+212%22",
#     "promoted_content": null,
#     "query": "%22Daily+Quordle+212%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ashanti",
#     "url": "http://twitter.com/search?q=Ashanti",
#     "promoted_content": null,
#     "query": "Ashanti",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hump Day",
#     "url": "http://twitter.com/search?q=%22Hump+Day%22",
#     "promoted_content": null,
#     "query": "%22Hump+Day%22",
#     "tweet_volume": 21059
#    },
#    {
#     "name": "Ricciardo",
#     "url": "http://twitter.com/search?q=Ricciardo",
#     "promoted_content": null,
#     "query": "Ricciardo",
#     "tweet_volume": 25222
#    },
#    {
#     "name": "chenle",
#     "url": "http://twitter.com/search?q=chenle",
#     "promoted_content": null,
#     "query": "chenle",
#     "tweet_volume": 156809
#    },
#    {
#     "name": "Independence Day",
#     "url": "http://twitter.com/search?q=%22Independence+Day%22",
#     "promoted_content": null,
#     "query": "%22Independence+Day%22",
#     "tweet_volume": 148964
#    },
#    {
#     "name": "Hurricane Andrew",
#     "url": "http://twitter.com/search?q=%22Hurricane+Andrew%22",
#     "promoted_content": null,
#     "query": "%22Hurricane+Andrew%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Don Coryell",
#     "url": "http://twitter.com/search?q=%22Don+Coryell%22",
#     "promoted_content": null,
#     "query": "%22Don+Coryell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Good Wednesday",
#     "url": "http://twitter.com/search?q=%22Good+Wednesday%22",
#     "promoted_content": null,
#     "query": "%22Good+Wednesday%22",
#     "tweet_volume": 27635
#    },
#    {
#     "name": "Happy Hump",
#     "url": "http://twitter.com/search?q=%22Happy+Hump%22",
#     "promoted_content": null,
#     "query": "%22Happy+Hump%22",
#     "tweet_volume": 12108
#    },
#    {
#     "name": "Sam Mendes",
#     "url": "http://twitter.com/search?q=%22Sam+Mendes%22",
#     "promoted_content": null,
#     "query": "%22Sam+Mendes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jay Monahan",
#     "url": "http://twitter.com/search?q=%22Jay+Monahan%22",
#     "promoted_content": null,
#     "query": "%22Jay+Monahan%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Paqueta",
#     "url": "http://twitter.com/search?q=Paqueta",
#     "promoted_content": null,
#     "query": "Paqueta",
#     "tweet_volume": 14490
#    },
#    {
#     "name": "yoongis",
#     "url": "http://twitter.com/search?q=yoongis",
#     "promoted_content": null,
#     "query": "yoongis",
#     "tweet_volume": null
#    },
#    {
#     "name": "Regina",
#     "url": "http://twitter.com/search?q=Regina",
#     "promoted_content": null,
#     "query": "Regina",
#     "tweet_volume": 17912
#    },
#    {
#     "name": "Kedon Slovis",
#     "url": "http://twitter.com/search?q=%22Kedon+Slovis%22",
#     "promoted_content": null,
#     "query": "%22Kedon+Slovis%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Castration",
#     "url": "http://twitter.com/search?q=Castration",
#     "promoted_content": null,
#     "query": "Castration",
#     "tweet_volume": null
#    },
#    {
#     "name": "Empire of Light",
#     "url": "http://twitter.com/search?q=%22Empire+of+Light%22",
#     "promoted_content": null,
#     "query": "%22Empire+of+Light%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Iggy",
#     "url": "http://twitter.com/search?q=Iggy",
#     "promoted_content": null,
#     "query": "Iggy",
#     "tweet_volume": null
#    },
#    {
#     "name": "$PTON",
#     "url": "http://twitter.com/search?q=%24PTON",
#     "promoted_content": null,
#     "query": "%24PTON",
#     "tweet_volume": null
#    },
#    {
#     "name": "Charlie Crist",
#     "url": "http://twitter.com/search?q=%22Charlie+Crist%22",
#     "promoted_content": null,
#     "query": "%22Charlie+Crist%22",
#     "tweet_volume": 60138
#    },
#    {
#     "name": "Janis",
#     "url": "http://twitter.com/search?q=Janis",
#     "promoted_content": null,
#     "query": "Janis",
#     "tweet_volume": 17211
#    },
#    {
#     "name": "Gabbie Hanna",
#     "url": "http://twitter.com/search?q=%22Gabbie+Hanna%22",
#     "promoted_content": null,
#     "query": "%22Gabbie+Hanna%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Happy Kobe",
#     "url": "http://twitter.com/search?q=%22Happy+Kobe%22",
#     "promoted_content": null,
#     "query": "%22Happy+Kobe%22",
#     "tweet_volume": 61591
#    },
#    {
#     "name": "Arctic Monkeys",
#     "url": "http://twitter.com/search?q=%22Arctic+Monkeys%22",
#     "promoted_content": null,
#     "query": "%22Arctic+Monkeys%22",
#     "tweet_volume": 45386
#    },
#    {
#     "name": "Pell Grant",
#     "url": "http://twitter.com/search?q=%22Pell+Grant%22",
#     "promoted_content": null,
#     "query": "%22Pell+Grant%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cady",
#     "url": "http://twitter.com/search?q=Cady",
#     "promoted_content": null,
#     "query": "Cady",
#     "tweet_volume": null
#    },
#    {
#     "name": "berta soy yo",
#     "url": "http://twitter.com/search?q=%22berta+soy+yo%22",
#     "promoted_content": null,
#     "query": "%22berta+soy+yo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kansas City Chiefs",
#     "url": "http://twitter.com/search?q=%22Kansas+City+Chiefs%22",
#     "promoted_content": null,
#     "query": "%22Kansas+City+Chiefs%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "GI Bill",
#     "url": "http://twitter.com/search?q=%22GI+Bill%22",
#     "promoted_content": null,
#     "query": "%22GI+Bill%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Car",
#     "url": "http://twitter.com/search?q=%22The+Car%22",
#     "promoted_content": null,
#     "query": "%22The+Car%22",
#     "tweet_volume": 183393
#    },
#    {
#     "name": "Min Yoongi",
#     "url": "http://twitter.com/search?q=%22Min+Yoongi%22",
#     "promoted_content": null,
#     "query": "%22Min+Yoongi%22",
#     "tweet_volume": 53575
#    },
#    {
#     "name": "Gaetz",
#     "url": "http://twitter.com/search?q=Gaetz",
#     "promoted_content": null,
#     "query": "Gaetz",
#     "tweet_volume": 63111
#    },
#    {
#     "name": "Naomi Watts",
#     "url": "http://twitter.com/search?q=%22Naomi+Watts%22",
#     "promoted_content": null,
#     "query": "%22Naomi+Watts%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rebekah Jones",
#     "url": "http://twitter.com/search?q=%22Rebekah+Jones%22",
#     "promoted_content": null,
#     "query": "%22Rebekah+Jones%22",
#     "tweet_volume": 24523
#    },
#    {
#     "name": "Haas",
#     "url": "http://twitter.com/search?q=Haas",
#     "promoted_content": null,
#     "query": "Haas",
#     "tweet_volume": 10551
#    }
#   ],
#   "as_of": "2022-08-24T14:43:58Z",
#   "created_at": "2022-08-23T10:36:17Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print (common_trends)
# Out:
# {'The Car', 'Arctic Monkeys', 'Isak', '#VEMP', 'Min Yoongi', 'Paqueta', 'Danny Ric', 'McLaren', 'Len Dawson'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
from urllib.parse import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = 'Sports' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 500
# {
#  "created_at": "Wed Aug 24 17:33:17 +0000 2022",
#  "id": 1562493258433196036,
#  "id_str": "1562493258433196036",
#  "text": "RT @Retro_Utd: In 2020, Nemanja Vidi\u0107 was voted the best defender in the history of the Premier League after a poll was carried out by Sky\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "Retro_Utd",
#     "name": "\ud83c\uddfe\ud83c\uddea\ud83d\udd30",
#     "id": 3153038158,
#     "id_str": "3153038158",
#     "indices": [
#      3,
#      13
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1253786431643881473,
#   "id_str": "1253786431643881473",
#   "name": "Sergio Anthony Davies \ud83c\uddec\ud83c\udded\ud83d\udc51",
#   "screen_name": "davie_sergio",
#   "location": "Sunyani",
#   "description": "Words that we said that we didn't mean \ud83d\ude14The words that we meant that we didn't say \ud83d\ude0cThe ones that we thought that we shoulda said\ud83d\ude14",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 1455,
#   "friends_count": 2144,
#   "listed_count": 0,
#   "created_at": "Fri Apr 24 20:42:56 +0000 2020",
#   "favourites_count": 170479,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 22836,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1298349575669981184/9UjeDzio_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1298349575669981184/9UjeDzio_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1253786431643881473/1617459311",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "withheld_in_countries": []
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Wed Aug 24 09:07:05 +0000 2022",
#   "id": 1562365872374779904,
#   "id_str": "1562365872374779904",
#   "text": "In 2020, Nemanja Vidi\u0107 was voted the best defender in the history of the Premier League after a poll was carried ou\u2026 https://t.co/6kEZshUP6P",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/6kEZshUP6P",
#      "expanded_url": "https://twitter.com/i/web/status/1562365872374779904",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 3153038158,
#    "id_str": "3153038158",
#    "name": "\ud83c\uddfe\ud83c\uddea\ud83d\udd30",
#    "screen_name": "Retro_Utd",
#    "location": "United Kingdom. ",
#    "description": "\ud835\udde0\ud835\uddee\ud835\uddfb\ud835\uddf0\ud835\uddf5\ud835\uddf2\ud835\ude00\ud835\ude01\ud835\uddf2\ud835\uddff \ud835\udde8\ud835\uddfb\ud835\uddf6\ud835\ude01\ud835\uddf2\ud835\uddf1. \ud83c\uddfe\ud83c\uddea #GlazersOut.\ud83d\udd30 Business Enquiries \ud83d\udc49 DM.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 435277,
#    "friends_count": 396,
#    "listed_count": 943,
#    "created_at": "Thu Apr 09 23:25:36 +0000 2015",
#    "favourites_count": 221720,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 68399,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1531676034076131330/OwybDRws_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1531676034076131330/OwybDRws_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/3153038158/1644687757",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none",
#    "withheld_in_countries": []
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 705,
#   "favorite_count": 10596,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 705,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print (t['retweet_count'])
print (t['retweeted_status'])

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-e606ecd79080> in <module>
#       1 import json
# ----> 2 statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())
#       3
#       4 # The result of the list comprehension is a list with only one element that
#       5 # can be accessed by its index and set to the variable t
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/ch01-twitter/data/MentionSomeoneImportantForYou.json'

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1))
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @Retro_Utd: In 2020, Nemanja Vidi\u0107 was voted the best defender in the history of the Premier League after a poll was carried out by Sky\u2026",
#  "@TonysCards @sports_sell @MDRANSOM1 Aaron\u2019s Donald fire emoji SP $50. Tlaw lot $85. Wilson lot $35. Bengals lot $35\u2026 https://t.co/XIMIBnE3KD",
#  "@GilesW7 @wrongthinkorg @PaulEmbery No,we don\u2019t..u &amp; this teacher hv no right to force ur cult \nDress how the fk u\u2026 https://t.co/03uIqFVg9s",
#  "RT @Felix_Sicard: Trevor Zegras is the first player in Ducks franchise history to grace the cover of an EA Sports NHL game in North America.",
#  "RT @leedsrhinos: Rohan Smith has named his starting line up to face Huddersfield Giants tonight at Headingley with Fusitu'a and Dwyer comin\u2026"
# ]
# [
#  "Retro_Utd",
#  "TonysCards",
#  "sports_sell",
#  "MDRANSOM1",
#  "GilesW7"
# ]
# [
#  "F122game",
#  "InvestigateLouTaylor",
#  "MLB",
#  "sportsnews",
#  "Mixcloud"
# ]
# [
#  "RT",
#  "@Retro_Utd:",
#  "In",
#  "2020,",
#  "Nemanja"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10])
# Out:
# [('the', 360), ('RT', 339), ('to', 201), ('and', 182), ('in', 158), ('of', 141), ('for', 112), ('a', 94), ('sports', 94), ('are', 73)]
# [('sports_sell', 44), ('CardboardEchoes', 32), ('Hobby_Connect', 27), ('Nx3sportscards', 25), ('Kings_Gorge', 22), ('PeterObi', 13), ('sec_council', 13), ('WFP', 12), ('keung', 11), ('Yogapetz', 11)]
# [('GlazersOut', 28), ('sports', 6), ('SportzChain', 5), ('Engage2Earn', 5), ('NFLTwitter', 3), ('NBATwitter', 3), ('girls', 3), ('Tennis', 3), ('Browns', 3), ('WackyWednesday', 3)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print (pt)
# Out:
# +--------+-------+
# | Word   | Count |
# +--------+-------+
# | the    |   360 |
# | RT     |   339 |
# | to     |   201 |
# | and    |   182 |
# | in     |   158 |
# | of     |   141 |
# | for    |   112 |
# | a      |    94 |
# | sports |    94 |
# | are    |    73 |
# +--------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | sports_sell     |    44 |
# | CardboardEchoes |    32 |
# | Hobby_Connect   |    27 |
# | Nx3sportscards  |    25 |
# | Kings_Gorge     |    22 |
# | PeterObi        |    13 |
# | sec_council     |    13 |
# | WFP             |    12 |
# | keung           |    11 |
# | Yogapetz        |    11 |
# +-----------------+-------+
# +----------------+-------+
# | Hashtag        | Count |
# +----------------+-------+
# | GlazersOut     |    28 |
# | sports         |     6 |
# | SportzChain    |     5 |
# | Engage2Earn    |     5 |
# | NFLTwitter     |     3 |
# | NBATwitter     |     3 |
# | girls          |     3 |
# | Tennis         |     3 |
# | Browns         |     3 |
# | WackyWednesday |     3 |
# +----------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print (lexical_diversity(words))
print (lexical_diversity(screen_names))
print (lexical_diversity(hashtags))
print (average_words(status_texts))
# Out:
# 0.4122970455150386
# 0.5013123359580053
# 0.6975806451612904
# 18.785

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if status.__contains__('retweeted_status')
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print (pt)
# Out:
# +-------+-----------------+----------------------------------------------------+
# | Count | Screen Name     | Text                                               |
# +-------+-----------------+----------------------------------------------------+
# | 10179 | blueroseroyalty | RT @blueroseroyalty: Gay people love to sit        |
# |       |                 | together and watch music videos like they’re       |
# |       |                 | sports                                             |
# | 10179 | blueroseroyalty | RT @blueroseroyalty: Gay people love to sit        |
# |       |                 | together and watch music videos like they’re       |
# |       |                 | sports                                             |
# | 10179 | blueroseroyalty | RT @blueroseroyalty: Gay people love to sit        |
# |       |                 | together and watch music videos like they’re       |
# |       |                 | sports                                             |
# | 10179 | blueroseroyalty | RT @blueroseroyalty: Gay people love to sit        |
# |       |                 | together and watch music videos like they’re       |
# |       |                 | sports                                             |
# | 10179 | blueroseroyalty | RT @blueroseroyalty: Gay people love to sit        |
# |       |                 | together and watch music videos like they’re       |
# |       |                 | sports                                             |
# +-------+-----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print ([r['user']['screen_name'] for r in _retweets])
# Out:
# ['jyeee', 'Ceejaynatics', 'LoveKyana18', 'kidamgos', 'asdfghjbl']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
import matplotlib.pyplot as plt

word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5, 0, 'Word Rank')

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print (counts)
# Out:
# [705, 2, 3, 79, 3572, 4, 1238, 2, 184, 1, 233, 2, 2, 103, 1, 2, 1, 12, 193, 1, 705, 846, 171, 1, 88, 37, 3572, 1, 3, 6506, 29, 1, 23, 62, 4, 2, 2, 19, 14, 2, 3, 2, 8, 1338, 7, 6, 1, 1, 1, 2, 4, 10179, 3572, 3, 1, 1, 1, 356, 6, 8, 1, 64, 846, 27, 130, 124, 15, 189, 103, 7, 3, 846, 92, 846, 187, 305, 8, 43, 52, 2799, 101, 8, 193, 189, 1, 1239, 10179, 199, 1, 19, 103, 3, 1, 8, 808, 19, 136, 97, 808, 3, 130, 109, 62, 808, 3, 37, 4, 107, 1, 1239, 233, 165, 18, 4, 1, 3573, 178, 429, 1, 692, 3, 4, 107, 5, 233, 2285, 18, 10179, 71, 1, 5, 7, 2, 198, 1, 1239, 1, 109, 1239, 47, 45, 846, 5, 18, 1, 4, 71, 2285, 1, 3573, 320, 2, 3, 2285, 1, 8, 846, 347, 29, 2, 3, 1, 5, 352, 38, 3573, 74, 1, 1, 1, 1, 2, 13, 11, 2, 1, 1, 4, 808, 10179, 6, 1, 3, 1, 18, 4, 1, 15, 43, 23, 101, 140, 40, 91, 100, 13, 92, 1, 1, 233, 91, 92, 2, 100, 21, 156, 1, 2, 2, 101, 2, 140, 5, 10, 129, 3574, 11, 846, 6, 1, 2, 6, 1, 1, 3, 53, 2, 1, 846, 6, 159, 160, 4, 808, 43, 3, 1, 583, 3, 2, 14, 109, 705, 808, 15, 2, 4, 233, 1, 5, 3575, 9, 107, 7, 4, 3, 1, 233, 4, 846, 2, 3, 8, 1, 1, 1, 2, 4, 178, 1, 1, 42, 6, 1, 1, 3, 1, 8, 94, 3575, 1, 1, 2, 38, 3, 1, 173, 20, 1, 2, 2, 10179, 45, 177, 1, 6, 100, 1, 106, 3, 2, 3, 50, 808, 178, 3, 8, 3575, 1, 23, 2, 4, 568, 107, 72, 3, 28, 846, 198, 10, 178, 31, 5, 2, 109, 57, 3, 1, 3575, 3, 101, 2, 2, 15, 134]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
from math import log
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

countslog = [math.log10(num) for num in counts]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(countslog)
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print (countslog)
# Out:
# [2.848189116991399, 0.3010299956639812, 0.47712125471966244, 1.8976270912904414, 3.552911450216509, 0.6020599913279624, 3.0927206446840994, 0.3010299956639812, 2.2648178230095364, 0.0, 2.367355921026019, 0.3010299956639812, 0.3010299956639812, 2.012837224705172, 0.0, 0.3010299956639812, 0.0, 1.0791812460476249, 2.285557309007774, 0.0, 2.848189116991399, 2.9273703630390235, 2.2329961103921536, 0.0, 1.9444826721501687, 1.568201724066995, 3.552911450216509, 0.0, 0.47712125471966244, 3.813314058945835, 1.462397997898956, 0.0, 1.3617278360175928, 1.792391689498254, 0.6020599913279624, 0.3010299956639812, 0.3010299956639812, 1.2787536009528289, 1.146128035678238, 0.3010299956639812, 0.47712125471966244, 0.3010299956639812, 0.9030899869919435, 3.1264561134318045, 0.8450980400142568, 0.7781512503836436, 0.0, 0.0, 0.0, 0.3010299956639812, 0.6020599913279624, 4.00770511436478, 3.552911450216509, 0.47712125471966244, 0.0, 0.0, 0.0, 2.5514499979728753, 0.7781512503836436, 0.9030899869919435, 0.0, 1.806179973983887, 2.9273703630390235, 1.4313637641589874, 2.113943352306837, 2.093421685162235, 1.1760912590556813, 2.2764618041732443, 2.012837224705172, 0.8450980400142568, 0.47712125471966244, 2.9273703630390235, 1.9637878273455553, 2.9273703630390235, 2.271841606536499, 2.484299839346786, 0.9030899869919435, 1.6334684555795864, 1.7160033436347992, 3.4470028984661623, 2.0043213737826426, 0.9030899869919435, 2.285557309007774, 2.2764618041732443, 0.0, 3.0930713063760633, 4.00770511436478, 2.298853076409707, 0.0, 1.2787536009528289, 2.012837224705172, 0.47712125471966244, 0.0, 0.9030899869919435, 2.907411360774586, 1.2787536009528289, 2.1335389083702174, 1.9867717342662448, 2.907411360774586, 0.47712125471966244, 2.113943352306837, 2.037426497940624, 1.792391689498254, 2.907411360774586, 0.47712125471966244, 1.568201724066995, 0.6020599913279624, 2.0293837776852097, 0.0, 3.0930713063760633, 2.367355921026019, 2.2174839442139063, 1.255272505103306, 0.6020599913279624, 0.0, 3.55303301620244, 2.250420002308894, 2.6324572921847245, 0.0, 2.840106094456758, 0.47712125471966244, 0.6020599913279624, 2.0293837776852097, 0.6989700043360189, 2.367355921026019, 3.358886204405869, 1.255272505103306, 4.00770511436478, 1.8512583487190752, 0.0, 0.6989700043360189, 0.8450980400142568, 0.3010299956639812, 2.296665190261531, 0.0, 3.0930713063760633, 0.0, 2.037426497940624, 3.0930713063760633, 1.6720978579357175, 1.6532125137753437, 2.9273703630390235, 0.6989700043360189, 1.255272505103306, 0.0, 0.6020599913279624, 1.8512583487190752, 3.358886204405869, 0.0, 3.55303301620244, 2.505149978319906, 0.3010299956639812, 0.47712125471966244, 3.358886204405869, 0.0, 0.9030899869919435, 2.9273703630390235, 2.5403294747908736, 1.462397997898956, 0.3010299956639812, 0.47712125471966244, 0.0, 0.6989700043360189, 2.546542663478131, 1.5797835966168101, 3.55303301620244, 1.8692317197309762, 0.0, 0.0, 0.0, 0.0, 0.3010299956639812, 1.1139433523068367, 1.0413926851582251, 0.3010299956639812, 0.0, 0.0, 0.6020599913279624, 2.907411360774586, 4.00770511436478, 0.7781512503836436, 0.0, 0.47712125471966244, 0.0, 1.255272505103306, 0.6020599913279624, 0.0, 1.1760912590556813, 1.6334684555795864, 1.3617278360175928, 2.0043213737826426, 2.146128035678238, 1.6020599913279623, 1.9590413923210936, 2.0, 1.1139433523068367, 1.9637878273455553, 0.0, 0.0, 2.367355921026019, 1.9590413923210936, 1.9637878273455553, 0.3010299956639812, 2.0, 1.3222192947339193, 2.1931245983544616, 0.0, 0.3010299956639812, 0.3010299956639812, 2.0043213737826426, 0.3010299956639812, 2.146128035678238, 0.6989700043360189, 1.0, 2.110589710299249, 3.5531545481696254, 1.0413926851582251, 2.9273703630390235, 0.7781512503836436, 0.0, 0.3010299956639812, 0.7781512503836436, 0.0, 0.0, 0.47712125471966244, 1.724275869600789, 0.3010299956639812, 0.0, 2.9273703630390235, 0.7781512503836436, 2.2013971243204513, 2.2041199826559246, 0.6020599913279624, 2.907411360774586, 1.6334684555795864, 0.47712125471966244, 0.0, 2.76566855475901 ...

# %% [markdown]
# # Labsheet 8 task - 18001981

# %% [markdown]
# ### utils

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# We improve our feature matrix builder with 3 additional optional parameters
# This allows us to extract not only word features, but also n-gram features
# We can also set the minimum and maximum frequencies to be considered as valid
# NB: All these are simply passed on to sklearn's Vectorizer classes
def build_feature_matrix(documents, feature_type='frequency',
                         ngram_range=(1, 1), min_df=0.0, max_df=1.0):

    feature_type = feature_type.lower().strip()  
    
    if feature_type == 'binary':
        vectorizer = CountVectorizer(binary=True, min_df=min_df,
                                     max_df=max_df, ngram_range=ngram_range)
    elif feature_type == 'frequency':
        vectorizer = CountVectorizer(binary=False, min_df=min_df,
                                     max_df=max_df, ngram_range=ngram_range)
    elif feature_type == 'tfidf':
        vectorizer = TfidfVectorizer(min_df=min_df, max_df=max_df, 
                                     ngram_range=ngram_range)
    else:
        raise Exception("Wrong feature type entered. Possible values: 'binary', 'frequency', 'tfidf'")

    feature_matrix = vectorizer.fit_transform(documents).astype(float)
    
    return vectorizer, feature_matrix

# %% [markdown]
# ### contractions

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %% [markdown]
# ### normalization

# %%
import re
import nltk
import string
from nltk.stem import WordNetLemmatizer
from html.parser import HTMLParser
import unicodedata
import html

stopword_list = nltk.corpus.stopwords.words('english')
# We need to extend the stopword list for the domain we are working with
stopword_list = stopword_list + ['mr', 'mrs', 'come', 'go', 'get',
                                 'tell', 'listen', 'one', 'two', 'three',
                                 'four', 'five', 'six', 'seven', 'eight',
                                 'nine', 'zero', 'join', 'find', 'make',
                                 'say', 'ask', 'tell', 'see', 'try', 'back',
                                 'also']
wnl = WordNetLemmatizer()

def tokenize_text(text):
    tokens = nltk.word_tokenize(text) 
    tokens = [token.strip() for token in tokens]
    return tokens

def expand_contractions(text, contraction_mapping):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text
    
    
# from pattern.en import tag (if using python 2.x only)
from nltk.corpus import wordnet as wn

# Annotate text tokens with POS tags
def pos_tag_text(text):
    
    def penn_to_wn_tags(pos_tag):
        if pos_tag.startswith('J'):
            return wn.ADJ
        elif pos_tag.startswith('V'):
            return wn.VERB
        elif pos_tag.startswith('N'):
            return wn.NOUN
        elif pos_tag.startswith('R'):
            return wn.ADV
        else:
            return None

    tokens = nltk.word_tokenize(text)
    tagged_text = nltk.pos_tag(tokens)

#    tagged_text = tag(text) # If using pattern.en in python 2.x only
    tagged_lower_text = [(word.lower(), penn_to_wn_tags(pos_tag))
                         for word, pos_tag in
                         tagged_text]
    return tagged_lower_text
    
# lemmatize text based on POS tags    
def lemmatize_text(text):
    
    pos_tagged_text = pos_tag_text(text)
    lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
                         else word                     
                         for word, pos_tag in pos_tagged_text]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text
    

def remove_special_characters(text):
    tokens = tokenize_text(text)
    pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
    filtered_tokens = filter(None, [pattern.sub(' ', token) for token in tokens])
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text
    
    
def remove_stopwords(text):
    tokens = tokenize_text(text)
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

def keep_text_characters(text):
    filtered_tokens = []
    tokens = tokenize_text(text)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# We generalize our normalize function to be able to focus on text tokens alone - 3rd parameter
def normalize_corpus(corpus, lemmatize=True, only_text_chars=False, tokenize=False):
    
    normalized_corpus = []    
    for text in corpus:
        text = html.unescape(text)
        text = expand_contractions(text, CONTRACTION_MAP)
        if lemmatize:
            text = lemmatize_text(text)
        else:
            text = text.lower()
        text = remove_special_characters(text)
        text = remove_stopwords(text)
        # In case we only need to consider text tokens - ignoring numerical tokens for instance
        if only_text_chars:
            text = keep_text_characters(text) 
        
        if tokenize:
            text = tokenize_text(text)
            normalized_corpus.append(text)
        else:
            normalized_corpus.append(text)
            
    return normalized_corpus

# %%
import numpy as np

def compute_cosine_similarity(doc_features, corpus_features,
                              top_n=3):
    # Get document vectors
    doc_features = doc_features[0]
    # Compute similarities by calling dot.product on transposed corpus feature vector
    similarity = np.dot(doc_features, 
                        corpus_features.T)
    similarity = similarity.toarray()[0]
    # Get docs with highest similarity scores
    top_docs = similarity.argsort()[::-1][:top_n]
    top_docs_with_score = [(index, round(similarity[index], 3))
                            for index in top_docs]
    return top_docs_with_score

# %%
def getMovieTitle(movie_data,synopsis):
    return movie_data[movie_data.eq(synopsis).any(1)].iloc[0]["Title"]

# %% [markdown]
# ### Finding top 3 closest movie titles for each movie synopsis

# %%
import pandas as pd

movie_data = pd.read_csv('movie_data.csv')
print(movie_data.head())
# Out:
#                       Title                                           Synopsis
# 0             The Godfather  In late summer 1945, guests are gathered for t...
# 1  The Shawshank Redemption  In 1947, Andy Dufresne (Tim Robbins), a banker...
# 2          Schindler's List  The relocation of Polish Jews from surrounding...
# 3               Raging Bull  The film opens in 1964, where an older and fat...
# 4                Casablanca  In the early years of World War II, December 1...

# %%
corpus = normalize_corpus(movie_data["Synopsis"], lemmatize=True)

tfidf_vectorizer, tfidf_features = build_feature_matrix(corpus,
                                                        feature_type='tfidf',
                                                        ngram_range=(1, 1), 
                                                        min_df=0.0, max_df=1.0)

movie_tfidfs = tfidf_vectorizer.transform(corpus)

# %% [markdown]
# ### Similarity Analysis Using Cosine Similarity

# %%
print('Similarity analysis using Cosine similarity')
print('='*60)
for index, synopsis in enumerate(movie_data["Synopsis"]):

    tfidf = movie_tfidfs[index]
    top_similar_titles = compute_cosine_similarity(tfidf,
                                               tfidf_features,
                                               top_n=3)

    print('Synopsis',index+1 ,':', synopsis[:100],"...")
    original_title = getMovieTitle(movie_data,synopsis)
    print('Original title: ', original_title,'\n')
    print('Top', len(top_similar_titles), 'similar titles:')
    print('-'*40)
    for movie_index, sim_score in top_similar_titles:
        sim_title = movie_data.iloc[movie_index]["Title"]
        print('Movie num: {} Similarity Score: {}\nTitle: {}'.format(movie_index+1,
                                                                 sim_score,
                                                                 sim_title))
        print('-'*40)    
    print()
    print()
    print()
# Out:
# Similarity analysis using Cosine similarity
# ============================================================
# Synopsis 1 : In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter C ...
# Original title:  The Godfather
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 1 Similarity Score: 1.0
# Title: The Godfather
# ----------------------------------------
# Movie num: 12 Similarity Score: 0.577
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 76 Similarity Score: 0.288
# Title: Tootsie
# ----------------------------------------
#
#
#
# Synopsis 2 : In 1947, Andy Dufresne (Tim Robbins), a banker in Maine, is convicted of murdering his wife and her  ...
# Original title:  The Shawshank Redemption
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 2 Similarity Score: 1.0
# Title: The Shawshank Redemption
# ----------------------------------------
# Movie num: 36 Similarity Score: 0.081
# Title: From Here to Eternity
# ----------------------------------------
# Movie num: 60 Similarity Score: 0.069
# Title: Goodfellas
# ----------------------------------------
#
#
#
# Synopsis 3 : The relocation of Polish Jews from surrounding areas to Krakow begins in late 1939, shortly after th ...
# Original title:  Schindler's List
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 3 Similarity Score: 1.0
# Title: Schindler's List
# ----------------------------------------
# Movie num: 59 Similarity Score: 0.192
# Title: The Pianist
# ----------------------------------------
# Movie num: 39 Similarity Score: 0.059
# Title: Raiders of the Lost Ark
# ----------------------------------------
#
#
#
# Synopsis 4 : The film opens in 1964, where an older and fatter Jake LaMotta (Robert De Niro) practices his stand- ...
# Original title:  Raging Bull
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 4 Similarity Score: 1.0
# Title: Raging Bull
# ----------------------------------------
# Movie num: 24 Similarity Score: 0.288
# Title: Chinatown
# ----------------------------------------
# Movie num: 80 Similarity Score: 0.091
# Title: Shane
# ----------------------------------------
#
#
#
# Synopsis 5 : In the early years of World War II, December 1941, the Moroccan coastal city of Casablanca attracts  ...
# Original title:  Casablanca
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 5 Similarity Score: 1.0
# Title: Casablanca
# ----------------------------------------
# Movie num: 59 Similarity Score: 0.066
# Title: The Pianist
# ----------------------------------------
# Movie num: 3 Similarity Score: 0.056
# Title: Schindler's List
# ----------------------------------------
#
#
#
# Synopsis 6 : In 1963 Oregon, Randle Patrick McMurphy (Nicholson), a criminal who has been sentenced to a fairly s ...
# Original title:  One Flew Over the Cuckoo's Nest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 6 Similarity Score: 1.0
# Title: One Flew Over the Cuckoo's Nest
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.046
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.034
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 7 : The film opens in Tara, a cotton plantation owned by the proud Gerald O'Hara (Thomas Mitchell), a se ...
# Original title:  Gone with the Wind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 7 Similarity Score: 1.0
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.044
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 75 Similarity Score: 0.038
# Title: Terms of Endearment
# ----------------------------------------
#
#
#
# Synopsis 8 : It's 1941, and newspaper tycoon Charles Foster Kane (Orson Welles, who also directed and co-wrote th ...
# Original title:  Citizen Kane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 8 Similarity Score: 1.0
# Title: Citizen Kane
# ----------------------------------------
# Movie num: 57 Similarity Score: 0.441
# Title: High Noon
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.083
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 9 : Dorothy Gale (Judy Garland) is an orphaned teenager who lives with her Auntie Em (Clara Blandick) an ...
# Original title:  The Wizard of Oz
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 9 Similarity Score: 1.0
# Title: The Wizard of Oz
# ----------------------------------------
# Movie num: 76 Similarity Score: 0.397
# Title: Tootsie
# ----------------------------------------
# Movie num: 34 Similarity Score: 0.049
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
#
#
#
# Synopsis 10 : In 1996, treasure hunter Brock Lovett and his team aboard the research vessel Keldysh search the wre ...
# Original title:  Titanic
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 10 Similarity Score: 1.0
# Title: Titanic
# ----------------------------------------
# Movie num: 88 Similarity Score: 0.238
# Title: The African Queen
# ----------------------------------------
# Movie num: 3 Similarity Score: 0.047
# Title: Schindler's List
# ----------------------------------------
#
#
#
# Synopsis 11 : In 1935, T. E. Lawrence (Peter O'Toole) is killed in a motorcycle accident. At his memorial service  ...
# Original title:  Lawrence of Arabia
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 11 Similarity Score: 1.0
# Title: Lawrence of Arabia
# ----------------------------------------
# Movie num: 25 Similarity Score: 0.064
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 33 Similarity Score: 0.06
# Title: Gandhi
# ----------------------------------------
#
#
#
# Synopsis 12 : The Godfather Part II presents two parallel storylines. One involves Mafia chief Michael Corleone in ...
# Original title:  The Godfather: Part II
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 12 Similarity Score: 1.0
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 1 Similarity Score: 0.577
# Title: The Godfather
# ----------------------------------------
# Movie num: 76 Similarity Score: 0.354
# Title: Tootsie
# ----------------------------------------
#
#
#
# Synopsis 13 : In a Phoenix hotel room on a Friday afternoon, Marion Crane (Janet Leigh) and her out-of-town lover  ...
# Original title:  Psycho
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 13 Similarity Score: 1.0
# Title: Psycho
# ----------------------------------------
# Movie num: 39 Similarity Score: 0.124
# Title: Raiders of the Lost Ark
# ----------------------------------------
# Movie num: 34 Similarity Score: 0.078
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
#
#
#
# Synopsis 14 : The film opens with the camera tracking down Sunset Boulevard in Los Angeles, California as police c ...
# Original title:  Sunset Blvd.
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 14 Similarity Score: 1.0
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 28 Similarity Score: 0.209
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 69 Similarity Score: 0.114
# Title: Midnight Cowboy
# ----------------------------------------
#
#
#
# Synopsis 15 : A woman's face gives way to a kaleidoscope of credits, signalling the start of Alfred Hitchcock's Ve ...
# Original title:  Vertigo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 15 Similarity Score: 1.0
# Title: Vertigo
# ----------------------------------------
# Movie num: 96 Similarity Score: 0.046
# Title: Rebel Without a Cause
# ----------------------------------------
# Movie num: 84 Similarity Score: 0.031
# Title: Nashville
# ----------------------------------------
#
#
#
# Synopsis 16 : Terry Malloy (Marlon Brando) once dreamt of being a great prize fighter, but now works at the docks  ...
# Original title:  On the Waterfront
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 16 Similarity Score: 1.0
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 86 Similarity Score: 0.318
# Title: American Graffiti
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.081
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 17 : The film begins with a feather falling to the feet of Forrest Gump who is sitting at a bus stop in S ...
# Original title:  Forrest Gump
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 17 Similarity Score: 1.0
# Title: Forrest Gump
# ----------------------------------------
# Movie num: 67 Similarity Score: 0.049
# Title: It Happened One Night
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.045
# Title: It's a Wonderful Life
# ----------------------------------------
#
#
#
# Synopsis 18 : The widowed, retired Austrian naval officer, Captain Von Trapp (Christopher Plummer) has made his Au ...
# Original title:  The Sound of Music
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 18 Similarity Score: 1.0
# Title: The Sound of Music
# ----------------------------------------
# Movie num: 19 Similarity Score: 0.244
# Title: West Side Story
# ----------------------------------------
# Movie num: 45 Similarity Score: 0.053
# Title: The Best Years of Our Lives
# ----------------------------------------
#
#
#
# Synopsis 19 : A fight set to music between an American gang, the Jets, and a rival gang, the Sharks, who have move ...
# Original title:  West Side Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 19 Similarity Score: 1.0
# Title: West Side Story
# ----------------------------------------
# Movie num: 18 Similarity Score: 0.244
# Title: The Sound of Music
# ----------------------------------------
# Movie num: 50 Similarity Score: 0.13
# Title: Jaws
# ----------------------------------------
#
#
#
# Synopsis 20 : Note: Italicized paragraphs denote scenes added for the film's 1997 special edition and updated for  ...
# Original title:  Star Wars
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 20 Similarity Score: 1.0
# Title: Star Wars
# ----------------------------------------
# Movie num: 22 Similarity Score: 0.063
# Title: 2001: A Space Odyssey
# ----------------------------------------
# Movie num: 89 Similarity Score: 0.056
# Title: Stagecoach
# ----------------------------------------
#
#
#
# Synopsis 21 : In a forested area overlooking a sprawling suburban neighborhood, an alien spacecraft has landed. Th ...
# Original title:  E.T. the Extra-Terrestrial
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 21 Similarity Score: 1.0
# Title: E.T. the Extra-Terrestrial
# ----------------------------------------
# Movie num: 12 Similarity Score: 0.148
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 76 Similarity Score: 0.132
# Title: Tootsie
# ----------------------------------------
#
#
#
# Synopsis 22 : To Richard Strauss' tone poem "Thus Spake Zarathustra," the title sequence shows the sun rising behi ...
# Original title:  2001: A Space Odyssey
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 22 Similarity Score: 1.0
# Title: 2001: A Space Odyssey
# ----------------------------------------
# Movie num: 20 Similarity Score: 0.063
# Title: Star Wars
# ----------------------------------------
# Movie num: 81 Similarity Score: 0.054
# Title: The Green Mile
# ----------------------------------------
#
#
#
# Synopsis 23 : Promising FBI Academy student Clarice Starling is pulled from her training at the FBI Training Facil ...
# Original title:  The Silence of the Lambs
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 23 Similarity Score: 1.0
# Title: The Silence of the Lambs
# ----------------------------------------
# Movie num: 38 Similarity Score: 0.061
# Title: Unforgiven
# ----------------------------------------
# Movie num: 70 Similarity Score: 0.042
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
#
#
#
# Synopsis 24 : Set in 1937 Los Angeles, a private investigator named Jake "J.J." Gittes (Nicholson) is hired to spy ...
# Original title:  Chinatown
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 24 Similarity Score: 1.0
# Title: Chinatown
# ----------------------------------------
# Movie num: 4 Similarity Score: 0.288
# Title: Raging Bull
# ----------------------------------------
# Movie num: 50 Similarity Score: 0.051
# Title: Jaws
# ----------------------------------------
#
#
#
# Synopsis 25 : [this synopsis is primarily from the wikipedia article The_Bridge_on_the_River_Kwai]Two prisoners of ...
# Original title:  The Bridge on the River Kwai
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 25 Similarity Score: 1.0
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 36 Similarity Score: 0.083
# Title: From Here to Eternity
# ----------------------------------------
# Movie num: 33 Similarity Score: 0.076
# Title: Gandhi
# ----------------------------------------
#
#
#
# Synopsis 26 : Don Lockwood (Gene Kelly) is a popular silent film star with humble roots as a singer, dancer and st ...
# Original title:  Singin' in the Rain
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 26 Similarity Score: 1.0
# Title: Singin' in the Rain
# ----------------------------------------
# Movie num: 84 Similarity Score: 0.072
# Title: Nashville
# ----------------------------------------
# Movie num: 100 Similarity Score: 0.053
# Title: Yankee Doodle Dandy
# ----------------------------------------
#
#
#
# Synopsis 27 : This movie is about a divine intervention by a guardian angel, to help a man in distress. It opens w ...
# Original title:  It's a Wonderful Life
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 27 Similarity Score: 1.0
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 68 Similarity Score: 0.383
# Title: A Place in the Sun
# ----------------------------------------
# Movie num: 66 Similarity Score: 0.094
# Title: The King's Speech
# ----------------------------------------
#
#
#
# Synopsis 28 : Joe and Jerry, a saxophonist and bassist, respectively, are two working-class musicians, working in  ...
# Original title:  Some Like It Hot
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 28 Similarity Score: 1.0
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.343
# Title: Fargo
# ----------------------------------------
# Movie num: 44 Similarity Score: 0.282
# Title: An American in Paris
# ----------------------------------------
#
#
#
# Synopsis 29 : A teenaged Hispanic boy has just been tried for the murder of his father, and the case is now in the ...
# Original title:  12 Angry Men
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 29 Similarity Score: 1.0
# Title: 12 Angry Men
# ----------------------------------------
# Movie num: 68 Similarity Score: 0.04
# Title: A Place in the Sun
# ----------------------------------------
# Movie num: 60 Similarity Score: 0.033
# Title: Goodfellas
# ----------------------------------------
#
#
#
# Synopsis 30 : At the Burpelson U.S. Air Force Base somewhere in the continental USA, the eccentric Brigadier Gener ...
# Original title:  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 30 Similarity Score: 1.0
# Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# ----------------------------------------
# Movie num: 100 Similarity Score: 0.067
# Title: Yankee Doodle Dandy
# ----------------------------------------
# Movie num: 37 Similarity Score: 0.053
# Title: Saving Private Ryan
# ----------------------------------------
#
#
#
# Synopsis 31 : The story begins in 1823 as the elderly Salieri attempts suicide by slitting his throat while loudly ...
# Original title:  Amadeus
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 31 Similarity Score: 1.0
# Title: Amadeus
# ----------------------------------------
# Movie num: 2 Similarity Score: 0.031
# Title: The Shawshank Redemption
# ----------------------------------------
# Movie num: 100 Similarity Score: 0.025
# Title: Yankee Doodle Dandy
# ----------------------------------------
#
#
#
# Synopsis 32 : U.S. Army Captain and special operations veteran Benjamin L. Willard (Martin Sheen), returned to Sai ...
# Original title:  Apocalypse Now
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 32 Similarity Score: 1.0
# Title: Apocalypse Now
# ----------------------------------------
# Movie num: 98 Similarity Score: 0.066
# Title: The Third Man
# ----------------------------------------
# Movie num: 25 Similarity Score: 0.059
# Title: The Bridge on the River Kwai
# ----------------------------------------
#
#
#
# Synopsis 33 : The story begins with the assassination of Mohandas K. "Mahatma" Gandhi in India in 1948. The follow ...
# Original title:  Gandhi
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 33 Similarity Score: 1.0
# Title: Gandhi
# ----------------------------------------
# Movie num: 25 Similarity Score: 0.076
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 11 Similarity Score: 0.06
# Title: Lawrence of Arabia
# ----------------------------------------
#
#
#
# Synopsis 34 : In the opening scene, a flashback, two hobbits, Smeagol (Andy Serkis) and his friend Deagol (Thomas  ...
# Original title:  The Lord of the Rings: The Return of the King
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 34 Similarity Score: 1.0
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
# Movie num: 13 Similarity Score: 0.078
# Title: Psycho
# ----------------------------------------
# Movie num: 9 Similarity Score: 0.049
# Title: The Wizard of Oz
# ----------------------------------------
#
#
#
# Synopsis 35 : Shouting "Roma Invicta!" as his forces attack, General Maximus Decimus Meridius leads the Roman Army ...
# Original title:  Gladiator
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 35 Similarity Score: 1.0
# Title: Gladiator
# ----------------------------------------
# Movie num: 1 Similarity Score: 0.027
# Title: The Godfather
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.024
# Title: The Grapes of Wrath
# ----------------------------------------
#
#
#
# Synopsis 36 : In 1941 Hawaii, Private Robert E. Lee Prewitt (Montgomery Clift) is transferred from the Bugle Corps ...
# Original title:  From Here to Eternity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 36 Similarity Score: 1.0
# Title: From Here to Eternity
# ----------------------------------------
# Movie num: 25 Similarity Score: 0.083
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 2 Similarity Score: 0.081
# Title: The Shawshank Redemption
# ----------------------------------------
#
#
#
# Synopsis 37 : An American flag back-lighted by the afternoon sun gently flaps in the breeze. The camera pulls back ...
# Original title:  Saving Private Ryan
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 37 Similarity Score: 1.0
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 57 Similarity Score: 0.339
# Title: High Noon
# ----------------------------------------
# Movie num: 49 Similarity Score: 0.111
# Title: Patton
# ----------------------------------------
#
#
#
# Synopsis 38 : William Munny (Clint Eastwood) is a widower with two young children. He was once a very vicious gunf ...
# Original title:  Unforgiven
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 38 Similarity Score: 1.0
# Title: Unforgiven
# ----------------------------------------
# Movie num: 62 Similarity Score: 0.109
# Title: The Deer Hunter
# ----------------------------------------
# Movie num: 23 Similarity Score: 0.061
# Title: The Silence of the Lambs
# ----------------------------------------
#
#
#
# Synopsis 39 : In the spring of 1936 an exploration party penetrates thick jungle on the South American continent.  ...
# Original title:  Raiders of the Lost Ark
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 39 Similarity Score: 1.0
# Title: Raiders of the Lost Ark
# ----------------------------------------
# Movie num: 13 Similarity Score: 0.124
# Title: Psycho
# ----------------------------------------
# Movie num: 3 Similarity Score: 0.059
# Title: Schindler's List
# ----------------------------------------
#
#
#
# Synopsis 40 : Philadelphia Pennsylvania, home to the number one underdog fighter, Rocky Balboa (Sylvester Stalone) ...
# Original title:  Rocky
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 40 Similarity Score: 1.0
# Title: Rocky
# ----------------------------------------
# Movie num: 1 Similarity Score: 0.029
# Title: The Godfather
# ----------------------------------------
# Movie num: 19 Similarity Score: 0.026
# Title: West Side Story
# ----------------------------------------
#
#
#
# Synopsis 41 : Elia Kazan,who directed the Broadway play on which the black and white film is based, invited Marlon ...
# Original title:  A Streetcar Named Desire
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 41 Similarity Score: 1.0
# Title: A Streetcar Named Desire
# ----------------------------------------
# Movie num: 97 Similarity Score: 0.069
# Title: Rear Window
# ----------------------------------------
# Movie num: 73 Similarity Score: 0.042
# Title: Out of Africa
# ----------------------------------------
#
#
#
# Synopsis 42 : Tracy Samantha Lord Haven (Katharine Hepburn) is a wealthy Main Line Philadelphia socialite who had  ...
# Original title:  The Philadelphia Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 42 Similarity Score: 1.0
# Title: The Philadelphia Story
# ----------------------------------------
# Movie num: 62 Similarity Score: 0.136
# Title: The Deer Hunter
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.056
# Title: It's a Wonderful Life
# ----------------------------------------
#
#
#
# Synopsis 43 : The movie is based on a novel by Harper Lee, who interestingly enough was the assistant to Truman Ca ...
# Original title:  To Kill a Mockingbird
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 43 Similarity Score: 1.0
# Title: To Kill a Mockingbird
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.204
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 84 Similarity Score: 0.094
# Title: Nashville
# ----------------------------------------
#
#
#
# Synopsis 44 : Jerry Mulligan (Gene Kelly) is an exuberant American expatriate in Paris trying to make a reputation ...
# Original title:  An American in Paris
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 44 Similarity Score: 1.0
# Title: An American in Paris
# ----------------------------------------
# Movie num: 28 Similarity Score: 0.282
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.275
# Title: Fargo
# ----------------------------------------
# Synopsis 45 : At the end of World War II, Fred Derry (Dana Andrews), Al Stevenson (Fredric March) and Homer Parris ...
# Original title:  The Best Years of Our Lives
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 45 Similarity Score: 1.0
# Title: The Best Years of Our Lives
# ----------------------------------------
# Movie num: 53 Similarity Score: 0.066
# Title: Butch Cassidy and the Sundance Kid
# ----------------------------------------
# Movie num: 18 Similarity Score: 0.053
# Title: The Sound of Music
# ----------------------------------------
#
#
#
# Synopsis 46 : Henry Higgins (Rex Harrison), an arrogant, irascible professor of phonetics, boasts to a new acquain ...
# Original title:  My Fair Lady
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 46 Similarity Score: 1.0
# Title: My Fair Lady
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.04
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 41 Similarity Score: 0.036
# Title: A Streetcar Named Desire
# ----------------------------------------
#
#
#
# Synopsis 47 : Judah Ben-Hur (Charlton Heston) is a wealthy merchant living in Judea at the time of Christ. Under t ...
# Original title:  Ben-Hur
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 47 Similarity Score: 1.0
# Title: Ben-Hur
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.031
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 49 Similarity Score: 0.029
# Title: Patton
# ----------------------------------------
#
#
#
# Synopsis 48 : A high ranking Russian General has arrived at an industrial project office. It is night and this man ...
# Original title:  Doctor Zhivago
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 48 Similarity Score: 1.0
# Title: Doctor Zhivago
# ----------------------------------------
# Movie num: 59 Similarity Score: 0.047
# Title: The Pianist
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.04
# Title: The Grapes of Wrath
# ----------------------------------------
#
#
#
# Synopsis 49 : Against a backdrop of the Stars and Stripes, General George S. Patton (George C. Scott) addresses hi ...
# Original title:  Patton
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 49 Similarity Score: 1.0
# Title: Patton
# ----------------------------------------
# Movie num: 37 Similarity Score: 0.111
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 59 Similarity Score: 0.081
# Title: The Pianist
# ----------------------------------------
#
#
#
# Synopsis 50 : Late one night, on one of the many beaches of Amity Island off the coast of New England, local teena ...
# Original title:  Jaws
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 50 Similarity Score: 1.0
# Title: Jaws
# ----------------------------------------
# Movie num: 19 Similarity Score: 0.13
# Title: West Side Story
# ----------------------------------------
# Movie num: 12 Similarity Score: 0.053
# Title: The Godfather: Part II
# ----------------------------------------
#
#
#
# Synopsis 51 : In the 13th Century England, after several years of political unrest in Scotland, the land is open t ...
# Original title:  Braveheart
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 51 Similarity Score: 1.0
# Title: Braveheart
# ----------------------------------------
# Movie num: 66 Similarity Score: 0.098
# Title: The King's Speech
# ----------------------------------------
# Movie num: 87 Similarity Score: 0.081
# Title: Pulp Fiction
# ----------------------------------------
#
#
#
# Synopsis 52 : The film tells the story of three men who pursue, often at the expense of others, information about  ...
# Original title:  The Good, the Bad and the Ugly
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 52 Similarity Score: 1.0
# Title: The Good, the Bad and the Ugly
# ----------------------------------------
# Movie num: 51 Similarity Score: 0.044
# Title: Braveheart
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.043
# Title: It's a Wonderful Life
# ----------------------------------------
#
#
#
# Synopsis 53 : Wyoming, c. 1900s. Butch Cassidy (Paul Newman) and the Sundance Kid (Robert Redford), the leaders of ...
# Original title:  Butch Cassidy and the Sundance Kid
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 53 Similarity Score: 1.0
# Title: Butch Cassidy and the Sundance Kid
# ----------------------------------------
# Movie num: 87 Similarity Score: 0.327
# Title: Pulp Fiction
# ----------------------------------------
# Movie num: 45 Similarity Score: 0.066
# Title: The Best Years of Our Lives
# ----------------------------------------
#
#
#
# Synopsis 54 : Fred Dobbs (Humphrey Bogart) and Bob Curtin (Tim Holt) are down on their luck in Mexico and are both ...
# Original title:  The Treasure of the Sierra Madre
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 54 Similarity Score: 1.0
# Title: The Treasure of the Sierra Madre
# ----------------------------------------
# Movie num: 100 Similarity Score: 0.057
# Title: Yankee Doodle Dandy
# ----------------------------------------
# Movie num: 45 Similarity Score: 0.042
# Title: The Best Years of Our Lives
# ----------------------------------------
#
#
#
# Synopsis 55 : C. C. Baxter (Jack Lemmon) is a lonely office drone for an insurance company in New York City. Four  ...
# Original title:  The Apartment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 55 Similarity Score: 1.0
# Title: The Apartment
# ----------------------------------------
# Movie num: 14 Similarity Score: 0.037
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.032
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 56 : Chris Taylor (Charlie Sheen) is a young American who has abandoned a privileged life at a university ...
# Original title:  Platoon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 56 Similarity Score: 1.0
# Title: Platoon
# ----------------------------------------
# Movie num: 70 Similarity Score: 0.138
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.091
# Title: All Quiet on the Western Front
# ----------------------------------------
#
#
#
# Synopsis 57 : In Hadleyville, a small town in New Mexico Territory, Marshal Will Kane (Cooper), newly married to A ...
# Original title:  High Noon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 57 Similarity Score: 1.0
# Title: High Noon
# ----------------------------------------
# Movie num: 8 Similarity Score: 0.441
# Title: Citizen Kane
# ----------------------------------------
# Movie num: 37 Similarity Score: 0.339
# Title: Saving Private Ryan
# ----------------------------------------
#
#
#
# Synopsis 58 : During a US Civil War battle, Union Army Officer Lieutenant John J. Dunbar (Kevin Costner) learns th ...
# Original title:  Dances with Wolves
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 58 Similarity Score: 1.0
# Title: Dances with Wolves
# ----------------------------------------
# Movie num: 73 Similarity Score: 0.055
# Title: Out of Africa
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.038
# Title: All Quiet on the Western Front
# ----------------------------------------
#
#
#
# Synopsis 59 : "The Pianist" begins in Warsaw, Poland in September, 1939, at the outbreak of the Second World War,  ...
# Original title:  The Pianist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 59 Similarity Score: 1.0
# Title: The Pianist
# ----------------------------------------
# Movie num: 3 Similarity Score: 0.192
# Title: Schindler's List
# ----------------------------------------
# Movie num: 37 Similarity Score: 0.095
# Title: Saving Private Ryan
# ----------------------------------------
#
#
#
# Synopsis 60 : The film opens with three men driving in their car late at night on a highway. In the car are Henry  ...
# Original title:  Goodfellas
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 60 Similarity Score: 1.0
# Title: Goodfellas
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.075
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 4 Similarity Score: 0.074
# Title: Raging Bull
# ----------------------------------------
#
#
#
# Synopsis 61 : Father Lancaster Merrin (Max Von Sydow) is an elderly Catholic priest on an archeological dig in Ira ...
# Original title:  The Exorcist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 61 Similarity Score: 1.0
# Title: The Exorcist
# ----------------------------------------
# Movie num: 82 Similarity Score: 0.036
# Title: Close Encounters of the Third Kind
# ----------------------------------------
# Movie num: 33 Similarity Score: 0.034
# Title: Gandhi
# ----------------------------------------
#
#
#
# Synopsis 62 : In the Western Pennsylvania foundry town of Clairton, during the late 1960s, Russian-American steel  ...
# Original title:  The Deer Hunter
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 62 Similarity Score: 1.0
# Title: The Deer Hunter
# ----------------------------------------
# Movie num: 42 Similarity Score: 0.136
# Title: The Philadelphia Story
# ----------------------------------------
# Movie num: 38 Similarity Score: 0.109
# Title: Unforgiven
# ----------------------------------------
#
#
#
# Synopsis 63 : Professor Kantorek gives an impassioned speech about the glory of serving in the Army and "saving th ...
# Original title:  All Quiet on the Western Front
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 63 Similarity Score: 1.0
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 81 Similarity Score: 0.21
# Title: The Green Mile
# ----------------------------------------
# Movie num: 37 Similarity Score: 0.098
# Title: Saving Private Ryan
# ----------------------------------------
#
#
#
# Synopsis 64 : In December 1970 in Marseilles, France, a plainclothes policeman is observing former longshoreman tu ...
# Original title:  The French Connection
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 64 Similarity Score: 1.0
# Title: The French Connection
# ----------------------------------------
# Movie num: 60 Similarity Score: 0.045
# Title: Goodfellas
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.041
# Title: Fargo
# ----------------------------------------
#
#
#
# Synopsis 65 : Chaplin City Lights The Little Tramp first meets the Flower Girl, and discovers she is blind when sh ...
# Original title:  City Lights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 65 Similarity Score: 1.0
# Title: City Lights
# ----------------------------------------
# Movie num: 14 Similarity Score: 0.043
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 28 Similarity Score: 0.043
# Title: Some Like It Hot
# ----------------------------------------
#
#
#
# Synopsis 66 : The film opens with Prince Albert, Duke of York (later King George VI), known to his wife and family ...
# Original title:  The King's Speech
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 66 Similarity Score: 1.0
# Title: The King's Speech
# ----------------------------------------
# Movie num: 51 Similarity Score: 0.098
# Title: Braveheart
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.094
# Title: It's a Wonderful Life
# ----------------------------------------
#
#
#
# Synopsis 67 : It Happened One Night begins with a rich heiress named Ellie Andrews sequestered by her father on hi ...
# Original title:  It Happened One Night
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 67 Similarity Score: 1.0
# Title: It Happened One Night
# ----------------------------------------
# Movie num: 17 Similarity Score: 0.049
# Title: Forrest Gump
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.044
# Title: Fargo
# ----------------------------------------
#
#
#
# Synopsis 68 : George Eastman (Montgomery Clift), is the poor nephew of rich industrialist Charles Eastman (Herbert ...
# Original title:  A Place in the Sun
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 68 Similarity Score: 1.0
# Title: A Place in the Sun
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.383
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 66 Similarity Score: 0.073
# Title: The King's Speech
# ----------------------------------------
#
#
#
# Synopsis 69 : Joe Buck (Jon Voight) leaves his job as a dishwasher in a small town in Texas, and gets on the bus h ...
# Original title:  Midnight Cowboy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 69 Similarity Score: 1.0
# Title: Midnight Cowboy
# ----------------------------------------
# Movie num: 28 Similarity Score: 0.135
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 14 Similarity Score: 0.114
# Title: Sunset Blvd.
# ----------------------------------------
#
#
#
# Synopsis 70 : The governor of an unnamed western state, Hubert "Happy" Hopper (Guy Kibbee), has to pick a replacem ...
# Original title:  Mr. Smith Goes to Washington
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 70 Similarity Score: 1.0
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
# Movie num: 56 Similarity Score: 0.138
# Title: Platoon
# ----------------------------------------
# Movie num: 98 Similarity Score: 0.049
# Title: The Third Man
# ----------------------------------------
#
#
#
# Synopsis 71 : Charlie Babbitt (Tom Cruise), a Los Angeles car dealer in his mid-twenties, is in the middle of impo ...
# Original title:  Rain Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 71 Similarity Score: 1.0
# Title: Rain Man
# ----------------------------------------
# Movie num: 8 Similarity Score: 0.083
# Title: Citizen Kane
# ----------------------------------------
# Movie num: 16 Similarity Score: 0.081
# Title: On the Waterfront
# ----------------------------------------
#
#
#
# Synopsis 72 : Annie Hall is a film about a comedian, Alvy Singer (Woody Allen), who falls in love with Annie Hall  ...
# Original title:  Annie Hall
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 72 Similarity Score: 1.0
# Title: Annie Hall
# ----------------------------------------
# Movie num: 74 Similarity Score: 0.066
# Title: Good Will Hunting
# ----------------------------------------
# Movie num: 8 Similarity Score: 0.037
# Title: Citizen Kane
# ----------------------------------------
#
#
#
# Synopsis 73 : [Out Of Africa]A well-heeled Danish lady goes to an English colony in Africa and buys 1000 acres. He ...
# Original title:  Out of Africa
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 73 Similarity Score: 1.0
# Title: Out of Africa
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.143
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 51 Similarity Score: 0.062
# Title: Braveheart
# ----------------------------------------
#
#
#
# Synopsis 74 : Though Will Hunting (Matt Damon) has genius-level intelligence (such as a talent for memorizing fact ...
# Original title:  Good Will Hunting
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 74 Similarity Score: 1.0
# Title: Good Will Hunting
# ----------------------------------------
# Movie num: 72 Similarity Score: 0.066
# Title: Annie Hall
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.037
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 75 : Aurora Greenway and her daughter Emma are both searching for deep romantic love. Beginning with Emma ...
# Original title:  Terms of Endearment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 75 Similarity Score: 1.0
# Title: Terms of Endearment
# ----------------------------------------
# Movie num: 60 Similarity Score: 0.049
# Title: Goodfellas
# ----------------------------------------
# Movie num: 73 Similarity Score: 0.039
# Title: Out of Africa
# ----------------------------------------
#
#
#
# Synopsis 76 : Michael Dorsey is an actor living and working in New York City. Most of his work seems to be on the  ...
# Original title:  Tootsie
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 76 Similarity Score: 1.0
# Title: Tootsie
# ----------------------------------------
# Movie num: 9 Similarity Score: 0.397
# Title: The Wizard of Oz
# ----------------------------------------
# Movie num: 12 Similarity Score: 0.354
# Title: The Godfather: Part II
# ----------------------------------------
#
#
#
# Synopsis 77 : The movie opens with a car towing a new tan Oldsmobile Cutlass Ciera through a sub-freezing blizzard ...
# Original title:  Fargo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 77 Similarity Score: 1.0
# Title: Fargo
# ----------------------------------------
# Movie num: 28 Similarity Score: 0.343
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 44 Similarity Score: 0.275
# Title: An American in Paris
# ----------------------------------------
#
#
#
# Synopsis 78 : In the early 1920s, Jordan "Bick" Benedict (Rock Hudson), the head of the rich Benedict ranching fam ...
# Original title:  Giant
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 78 Similarity Score: 1.0
# Title: Giant
# ----------------------------------------
# Movie num: 73 Similarity Score: 0.044
# Title: Out of Africa
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.042
# Title: The Grapes of Wrath
# ----------------------------------------
#
#
#
# Synopsis 79 : After serving four years in prison for killing a man, hotheaded Tom Joad (Henry Fonda) heads back to ...
# Original title:  The Grapes of Wrath
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 79 Similarity Score: 1.0
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 43 Similarity Score: 0.204
# Title: To Kill a Mockingbird
# ----------------------------------------
# Movie num: 73 Similarity Score: 0.143
# Title: Out of Africa
# ----------------------------------------
#
#
#
# Synopsis 80 : Shane (Alan Ladd), a skilled, laconic gunfighter with a mysterious past, rides into an isolated vall ...
# Original title:  Shane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 80 Similarity Score: 1.0
# Title: Shane
# ----------------------------------------
# Movie num: 4 Similarity Score: 0.091
# Title: Raging Bull
# ----------------------------------------
# Movie num: 38 Similarity Score: 0.048
# Title: Unforgiven
# ----------------------------------------
#
#
#
# Synopsis 81 : The movie begins with an old man named Paul Edgecomb (Dabbs Greer) in a retirement center. He takes  ...
# Original title:  The Green Mile
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 81 Similarity Score: 1.0
# Title: The Green Mile
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.21
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 86 Similarity Score: 0.069
# Title: American Graffiti
# ----------------------------------------
#
#
#
# Synopsis 82 : In what appers to be the Sonoran Desert; in or near Mexico, a cartographer named David Laughlin (Bob ...
# Original title:  Close Encounters of the Third Kind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 82 Similarity Score: 1.0
# Title: Close Encounters of the Third Kind
# ----------------------------------------
# Movie num: 16 Similarity Score: 0.065
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 21 Similarity Score: 0.058
# Title: E.T. the Extra-Terrestrial
# ----------------------------------------
#
#
#
# Synopsis 83 : A television network cynically exploits a deranged former anchor's ravings and revelations about the ...
# Original title:  Network
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 83 Similarity Score: 1.0
# Title: Network
# ----------------------------------------
# Movie num: 14 Similarity Score: 0.044
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 30 Similarity Score: 0.03
# Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# ----------------------------------------
#
#
#
# Synopsis 84 : The overarching plot takes place over five days leading up to a political rally for Replacement Part ...
# Original title:  Nashville
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 84 Similarity Score: 1.0
# Title: Nashville
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.095
# Title: Fargo
# ----------------------------------------
# Movie num: 43 Similarity Score: 0.094
# Title: To Kill a Mockingbird
# ----------------------------------------
#
#
#
# Synopsis 85 : The film explores the life of 21-year-old Ben Braddock (Dustin Hoffman) shortly after earning his ba ...
# Original title:  The Graduate
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 85 Similarity Score: 1.0
# Title: The Graduate
# ----------------------------------------
# Movie num: 81 Similarity Score: 0.062
# Title: The Green Mile
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.056
# Title: Fargo
# ----------------------------------------
#
#
#
# Synopsis 86 : It's the last night of the summer in 1962, and a number of friends are meeting at Burger City for on ...
# Original title:  American Graffiti
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 86 Similarity Score: 1.0
# Title: American Graffiti
# ----------------------------------------
# Movie num: 16 Similarity Score: 0.318
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 81 Similarity Score: 0.069
# Title: The Green Mile
# ----------------------------------------
#
#
#
# Synopsis 87 : Late one morning in the Hawthorne Grill, a restaurant on Sunset Boulevard in Los Angeles, a couple o ...
# Original title:  Pulp Fiction
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 87 Similarity Score: 1.0
# Title: Pulp Fiction
# ----------------------------------------
# Movie num: 53 Similarity Score: 0.327
# Title: Butch Cassidy and the Sundance Kid
# ----------------------------------------
# Movie num: 51 Similarity Score: 0.081
# Title: Braveheart
# ----------------------------------------
#
#
#
# Synopsis 88 : An English spinster, Rose (Katharine Hepburn), is the sister of a missionary, Rev. Samuel Sayer (Rob ...
# Original title:  The African Queen
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 88 Similarity Score: 1.0
# Title: The African Queen
# ----------------------------------------
# Movie num: 10 Similarity Score: 0.238
# Title: Titanic
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.069
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 89 : A group of people traveling on a stagecoach find their journey complicated by the threat of Geronimo ...
# Original title:  Stagecoach
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 89 Similarity Score: 1.0
# Title: Stagecoach
# ----------------------------------------
# Movie num: 20 Similarity Score: 0.056
# Title: Star Wars
# ----------------------------------------
# Movie num: 79 Similarity Score: 0.046
# Title: The Grapes of Wrath
# ----------------------------------------
#
#
#
# Synopsis 90 : In 1787, British ship Bounty leaves Portsmouth to bring a cargo of bread-fruit from Tahiti but the s ...
# Original title:  Mutiny on the Bounty
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 90 Similarity Score: 1.0
# Title: Mutiny on the Bounty
# ----------------------------------------
# Movie num: 18 Similarity Score: 0.042
# Title: The Sound of Music
# ----------------------------------------
# Movie num: 25 Similarity Score: 0.038
# Title: The Bridge on the River Kwai
# ----------------------------------------
#
#
#
# Synopsis 91 : Private eye Sam Spade and his partner Miles Archer are approached by Miss Wonderly to follow a man,  ...
# Original title:  The Maltese Falcon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 91 Similarity Score: 1.0
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 20 Similarity Score: 0.025
# Title: Star Wars
# ----------------------------------------
# Movie num: 13 Similarity Score: 0.025
# Title: Psycho
# ----------------------------------------
#
#
#
# Synopsis 92 : "A bit of the old ultra-violence".London, England in the foreseeable future. "Our humble narrator" A ...
# Original title:  A Clockwork Orange
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 92 Similarity Score: 1.0
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 1 Similarity Score: 0.046
# Title: The Godfather
# ----------------------------------------
# Movie num: 56 Similarity Score: 0.039
# Title: Platoon
# ----------------------------------------
# Synopsis 93 : Travis Bickle (Robert De Niro) goes to a New York City taxi depot where he applies for a job as a dr ...
# Original title:  Taxi Driver
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 93 Similarity Score: 1.0
# Title: Taxi Driver
# ----------------------------------------
# Movie num: 70 Similarity Score: 0.033
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
# Movie num: 63 Similarity Score: 0.026
# Title: All Quiet on the Western Front
# ----------------------------------------
#
#
#
# Synopsis 94 : A servant in the house of Wuthering Heights tells a traveler the unfortunate tale of lovers Cathy an ...
# Original title:  Wuthering Heights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 94 Similarity Score: 1.0
# Title: Wuthering Heights
# ----------------------------------------
# Movie num: 26 Similarity Score: 0.032
# Title: Singin' in the Rain
# ----------------------------------------
# Movie num: 45 Similarity Score: 0.029
# Title: The Best Years of Our Lives
# ----------------------------------------
#
#
#
# Synopsis 95 : Walter Neff (MacMurray) is a successful insurance salesman for Pacific All-Risk returning to his off ...
# Original title:  Double Indemnity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 95 Similarity Score: 1.0
# Title: Double Indemnity
# ----------------------------------------
# Movie num: 85 Similarity Score: 0.034
# Title: The Graduate
# ----------------------------------------
# Movie num: 13 Similarity Score: 0.031
# Title: Psycho
# ----------------------------------------
#
#
#
# Synopsis 96 : Shortly after moving to Los Angeles with his parents, 17-year-old Jim Stark (James Dean) enrolls at  ...
# Original title:  Rebel Without a Cause
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 96 Similarity Score: 1.0
# Title: Rebel Without a Cause
# ----------------------------------------
# Movie num: 15 Similarity Score: 0.046
# Title: Vertigo
# ----------------------------------------
# Movie num: 71 Similarity Score: 0.044
# Title: Rain Man
# ----------------------------------------
#
#
#
# Synopsis 97 : L.B. "Jeff" Jeffries (James Stewart) recuperates from a broken leg during a sweltering New York summ ...
# Original title:  Rear Window
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 97 Similarity Score: 1.0
# Title: Rear Window
# ----------------------------------------
# Movie num: 41 Similarity Score: 0.069
# Title: A Streetcar Named Desire
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.042
# Title: Fargo
# ----------------------------------------
#
#
#
# Synopsis 98 : Sights of Vienna, Austria, flash across the screen as an Englishman's voice (Carol Reed) describes t ...
# Original title:  The Third Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 98 Similarity Score: 1.0
# Title: The Third Man
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.07
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 32 Similarity Score: 0.066
# Title: Apocalypse Now
# ----------------------------------------
#
#
#
# Synopsis 99 : At the end of an ordinary work day, advertising executive Roger O. Thornhill (Cary Grant) hurries fr ...
# Original title:  North by Northwest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 99 Similarity Score: 1.0
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 Similarity Score: 0.045
# Title: Fargo
# ----------------------------------------
# Movie num: 13 Similarity Score: 0.045
# Title: Psycho
# ----------------------------------------
#
#
#
# Synopsis 100 : A film of the life of the renowned musical composer, playwright, actor, dancer, and singer George M. ...
# Original title:  Yankee Doodle Dandy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 100 Similarity Score: 1.0
# Title: Yankee Doodle Dandy
# ----------------------------------------
# Movie num: 84 Similarity Score: 0.09
# Title: Nashville
# ----------------------------------------
# Movie num: 27 Similarity Score: 0.083
# Title: It's a Wonderful Life
# ----------------------------------------

# %% [markdown]
# ### Similarity Analysis Using Hellinger-Bhattacharya Distance

# %%
def compute_hellinger_bhattacharya_distance(doc_features, corpus_features,
                                            top_n=3):
    # Get document vectors                                            
    doc_features = doc_features.toarray()[0]
    corpus_features = corpus_features.toarray()
    # Compute HB distances
    distance = np.hstack(
                    np.sqrt(0.5 *
                            np.sum(
                                np.square(np.sqrt(doc_features) - 
                                          np.sqrt(corpus_features)), 
                                axis=1)))
    # Get docs with lowest distance scores                            
    top_docs = distance.argsort()[:top_n]
    top_docs_with_score = [(index, round(distance[index], 3))
                            for index in top_docs]
    return top_docs_with_score 

print('Similarity Analysis using Hellinger-Bhattacharya distance')
print('='*60)
for index, synopsis in enumerate(movie_data["Synopsis"]):
    
    tfidf = movie_tfidfs[index]
    top_similar_titles = compute_hellinger_bhattacharya_distance(tfidf,
                                             tfidf_features,
                                             top_n=3)
    print('Synopsis',index+1 ,':', synopsis[:100],"...")
    original_title = getMovieTitle(movie_data,synopsis)
    print('Original title: ', original_title,'\n')
    print('Top', len(top_similar_titles), 'similar titles:')
    print('-'*40)
    for movie_index, sim_score in top_similar_titles:
        sim_title = movie_data.iloc[movie_index]["Title"]
        print('Movie num: {} Distance Score: {}\nTitle: {}'.format(movie_index+1,
                                                                 sim_score,
                                                                 sim_title))
        print('-'*40)
    print()
# Out:
# Similarity Analysis using Hellinger-Bhattacharya distance
# ============================================================
# Synopsis 1 : In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter C ...
# Original title:  The Godfather
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 1 Distance Score: 0.0
# Title: The Godfather
# ----------------------------------------
# Movie num: 12 Distance Score: 2.815
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 40 Distance Score: 3.029
# Title: Rocky
# ----------------------------------------
#
# Synopsis 2 : In 1947, Andy Dufresne (Tim Robbins), a banker in Maine, is convicted of murdering his wife and her  ...
# Original title:  The Shawshank Redemption
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 2 Distance Score: 0.0
# Title: The Shawshank Redemption
# ----------------------------------------
# Movie num: 40 Distance Score: 2.661
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.705
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 3 : The relocation of Polish Jews from surrounding areas to Krakow begins in late 1939, shortly after th ...
# Original title:  Schindler's List
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 3 Distance Score: 0.0
# Title: Schindler's List
# ----------------------------------------
# Movie num: 40 Distance Score: 2.827
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.846
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 4 : The film opens in 1964, where an older and fatter Jake LaMotta (Robert De Niro) practices his stand- ...
# Original title:  Raging Bull
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 4 Distance Score: 0.0
# Title: Raging Bull
# ----------------------------------------
# Movie num: 40 Distance Score: 2.676
# Title: Rocky
# ----------------------------------------
# Movie num: 65 Distance Score: 2.765
# Title: City Lights
# ----------------------------------------
#
# Synopsis 5 : In the early years of World War II, December 1941, the Moroccan coastal city of Casablanca attracts  ...
# Original title:  Casablanca
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 5 Distance Score: 0.0
# Title: Casablanca
# ----------------------------------------
# Movie num: 91 Distance Score: 2.55
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.562
# Title: Rocky
# ----------------------------------------
#
# Synopsis 6 : In 1963 Oregon, Randle Patrick McMurphy (Nicholson), a criminal who has been sentenced to a fairly s ...
# Original title:  One Flew Over the Cuckoo's Nest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 6 Distance Score: 0.0
# Title: One Flew Over the Cuckoo's Nest
# ----------------------------------------
# Movie num: 40 Distance Score: 2.66
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.7
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 7 : The film opens in Tara, a cotton plantation owned by the proud Gerald O'Hara (Thomas Mitchell), a se ...
# Original title:  Gone with the Wind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 7 Distance Score: 0.0
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 40 Distance Score: 2.597
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.624
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 8 : It's 1941, and newspaper tycoon Charles Foster Kane (Orson Welles, who also directed and co-wrote th ...
# Original title:  Citizen Kane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 8 Distance Score: 0.0
# Title: Citizen Kane
# ----------------------------------------
# Movie num: 40 Distance Score: 2.784
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.808
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 9 : Dorothy Gale (Judy Garland) is an orphaned teenager who lives with her Auntie Em (Clara Blandick) an ...
# Original title:  The Wizard of Oz
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 9 Distance Score: 0.0
# Title: The Wizard of Oz
# ----------------------------------------
# Movie num: 40 Distance Score: 2.601
# Title: Rocky
# ----------------------------------------
# Movie num: 76 Distance Score: 2.652
# Title: Tootsie
# ----------------------------------------
#
# Synopsis 10 : In 1996, treasure hunter Brock Lovett and his team aboard the research vessel Keldysh search the wre ...
# Original title:  Titanic
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 10 Distance Score: 0.0
# Title: Titanic
# ----------------------------------------
# Movie num: 40 Distance Score: 2.541
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.557
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 11 : In 1935, T. E. Lawrence (Peter O'Toole) is killed in a motorcycle accident. At his memorial service  ...
# Original title:  Lawrence of Arabia
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 11 Distance Score: 0.0
# Title: Lawrence of Arabia
# ----------------------------------------
# Movie num: 40 Distance Score: 2.786
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.801
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 12 : The Godfather Part II presents two parallel storylines. One involves Mafia chief Michael Corleone in ...
# Original title:  The Godfather: Part II
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 12 Distance Score: 0.0
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 40 Distance Score: 2.792
# Title: Rocky
# ----------------------------------------
# Movie num: 1 Distance Score: 2.815
# Title: The Godfather
# ----------------------------------------
#
# Synopsis 13 : In a Phoenix hotel room on a Friday afternoon, Marion Crane (Janet Leigh) and her out-of-town lover  ...
# Original title:  Psycho
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 13 Distance Score: 0.0
# Title: Psycho
# ----------------------------------------
# Movie num: 40 Distance Score: 2.65
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.669
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 14 : The film opens with the camera tracking down Sunset Boulevard in Los Angeles, California as police c ...
# Original title:  Sunset Blvd.
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 14 Distance Score: 0.0
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 91 Distance Score: 2.676
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.678
# Title: Rocky
# ----------------------------------------
#
# Synopsis 15 : A woman's face gives way to a kaleidoscope of credits, signalling the start of Alfred Hitchcock's Ve ...
# Original title:  Vertigo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 15 Distance Score: 0.0
# Title: Vertigo
# ----------------------------------------
# Movie num: 40 Distance Score: 2.444
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.511
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 16 : Terry Malloy (Marlon Brando) once dreamt of being a great prize fighter, but now works at the docks  ...
# Original title:  On the Waterfront
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 16 Distance Score: 0.0
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 40 Distance Score: 2.341
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.419
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 17 : The film begins with a feather falling to the feet of Forrest Gump who is sitting at a bus stop in S ...
# Original title:  Forrest Gump
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 17 Distance Score: 0.0
# Title: Forrest Gump
# ----------------------------------------
# Movie num: 40 Distance Score: 2.606
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.614
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 18 : The widowed, retired Austrian naval officer, Captain Von Trapp (Christopher Plummer) has made his Au ...
# Original title:  The Sound of Music
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 18 Distance Score: 0.0
# Title: The Sound of Music
# ----------------------------------------
# Movie num: 91 Distance Score: 2.616
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.623
# Title: Rocky
# ----------------------------------------
#
# Synopsis 19 : A fight set to music between an American gang, the Jets, and a rival gang, the Sharks, who have move ...
# Original title:  West Side Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 19 Distance Score: 0.0
# Title: West Side Story
# ----------------------------------------
# Movie num: 40 Distance Score: 2.465
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.549
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 20 : Note: Italicized paragraphs denote scenes added for the film's 1997 special edition and updated for  ...
# Original title:  Star Wars
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 20 Distance Score: 0.0
# Title: Star Wars
# ----------------------------------------
# Movie num: 91 Distance Score: 2.911
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.923
# Title: Rocky
# ----------------------------------------
# Synopsis 21 : In a forested area overlooking a sprawling suburban neighborhood, an alien spacecraft has landed. Th ...
# Original title:  E.T. the Extra-Terrestrial
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 21 Distance Score: 0.0
# Title: E.T. the Extra-Terrestrial
# ----------------------------------------
# Movie num: 40 Distance Score: 2.424
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.464
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 22 : To Richard Strauss' tone poem "Thus Spake Zarathustra," the title sequence shows the sun rising behi ...
# Original title:  2001: A Space Odyssey
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 22 Distance Score: 0.0
# Title: 2001: A Space Odyssey
# ----------------------------------------
# Movie num: 40 Distance Score: 3.007
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 3.038
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 23 : Promising FBI Academy student Clarice Starling is pulled from her training at the FBI Training Facil ...
# Original title:  The Silence of the Lambs
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 23 Distance Score: 0.0
# Title: The Silence of the Lambs
# ----------------------------------------
# Movie num: 91 Distance Score: 2.649
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.655
# Title: Rocky
# ----------------------------------------
#
# Synopsis 24 : Set in 1937 Los Angeles, a private investigator named Jake "J.J." Gittes (Nicholson) is hired to spy ...
# Original title:  Chinatown
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 24 Distance Score: 0.0
# Title: Chinatown
# ----------------------------------------
# Movie num: 91 Distance Score: 2.637
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.651
# Title: Rocky
# ----------------------------------------
#
# Synopsis 25 : [this synopsis is primarily from the wikipedia article The_Bridge_on_the_River_Kwai]Two prisoners of ...
# Original title:  The Bridge on the River Kwai
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 25 Distance Score: 0.0
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 40 Distance Score: 2.824
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.837
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 26 : Don Lockwood (Gene Kelly) is a popular silent film star with humble roots as a singer, dancer and st ...
# Original title:  Singin' in the Rain
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 26 Distance Score: 0.0
# Title: Singin' in the Rain
# ----------------------------------------
# Movie num: 40 Distance Score: 2.626
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.651
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 27 : This movie is about a divine intervention by a guardian angel, to help a man in distress. It opens w ...
# Original title:  It's a Wonderful Life
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 27 Distance Score: 0.0
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 40 Distance Score: 2.709
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.763
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 28 : Joe and Jerry, a saxophonist and bassist, respectively, are two working-class musicians, working in  ...
# Original title:  Some Like It Hot
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 28 Distance Score: 0.0
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 40 Distance Score: 2.57
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.612
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 29 : A teenaged Hispanic boy has just been tried for the murder of his father, and the case is now in the ...
# Original title:  12 Angry Men
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 29 Distance Score: 0.0
# Title: 12 Angry Men
# ----------------------------------------
# Movie num: 40 Distance Score: 2.57
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.615
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 30 : At the Burpelson U.S. Air Force Base somewhere in the continental USA, the eccentric Brigadier Gener ...
# Original title:  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 30 Distance Score: 0.0
# Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# ----------------------------------------
# Movie num: 40 Distance Score: 3.013
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 3.025
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 31 : The story begins in 1823 as the elderly Salieri attempts suicide by slitting his throat while loudly ...
# Original title:  Amadeus
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 31 Distance Score: 0.0
# Title: Amadeus
# ----------------------------------------
# Movie num: 44 Distance Score: 2.624
# Title: An American in Paris
# ----------------------------------------
# Movie num: 91 Distance Score: 2.633
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 32 : U.S. Army Captain and special operations veteran Benjamin L. Willard (Martin Sheen), returned to Sai ...
# Original title:  Apocalypse Now
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 32 Distance Score: 0.0
# Title: Apocalypse Now
# ----------------------------------------
# Movie num: 91 Distance Score: 2.697
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.712
# Title: Rocky
# ----------------------------------------
#
# Synopsis 33 : The story begins with the assassination of Mohandas K. "Mahatma" Gandhi in India in 1948. The follow ...
# Original title:  Gandhi
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 33 Distance Score: 0.0
# Title: Gandhi
# ----------------------------------------
# Movie num: 40 Distance Score: 2.694
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.708
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 34 : In the opening scene, a flashback, two hobbits, Smeagol (Andy Serkis) and his friend Deagol (Thomas  ...
# Original title:  The Lord of the Rings: The Return of the King
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 34 Distance Score: 0.0
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
# Movie num: 40 Distance Score: 3.017
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 3.036
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 35 : Shouting "Roma Invicta!" as his forces attack, General Maximus Decimus Meridius leads the Roman Army ...
# Original title:  Gladiator
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 35 Distance Score: 0.0
# Title: Gladiator
# ----------------------------------------
# Movie num: 40 Distance Score: 2.457
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.485
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 36 : In 1941 Hawaii, Private Robert E. Lee Prewitt (Montgomery Clift) is transferred from the Bugle Corps ...
# Original title:  From Here to Eternity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 36 Distance Score: 0.0
# Title: From Here to Eternity
# ----------------------------------------
# Movie num: 40 Distance Score: 2.639
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.655
# Title: The Maltese Falcon
# ----------------------------------------
# Synopsis 37 : An American flag back-lighted by the afternoon sun gently flaps in the breeze. The camera pulls back ...
# Original title:  Saving Private Ryan
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 37 Distance Score: 0.0
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 40 Distance Score: 2.758
# Title: Rocky
# ----------------------------------------
# Movie num: 98 Distance Score: 2.809
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 38 : William Munny (Clint Eastwood) is a widower with two young children. He was once a very vicious gunf ...
# Original title:  Unforgiven
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 38 Distance Score: 0.0
# Title: Unforgiven
# ----------------------------------------
# Movie num: 40 Distance Score: 2.62
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.644
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 39 : In the spring of 1936 an exploration party penetrates thick jungle on the South American continent.  ...
# Original title:  Raiders of the Lost Ark
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 39 Distance Score: 0.0
# Title: Raiders of the Lost Ark
# ----------------------------------------
# Movie num: 91 Distance Score: 2.763
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.764
# Title: Rocky
# ----------------------------------------
#
# Synopsis 40 : Philadelphia Pennsylvania, home to the number one underdog fighter, Rocky Balboa (Sylvester Stalone) ...
# Original title:  Rocky
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 40 Distance Score: 0.0
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.316
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 16 Distance Score: 2.341
# Title: On the Waterfront
# ----------------------------------------
#
# Synopsis 41 : Elia Kazan,who directed the Broadway play on which the black and white film is based, invited Marlon ...
# Original title:  A Streetcar Named Desire
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 41 Distance Score: 0.0
# Title: A Streetcar Named Desire
# ----------------------------------------
# Movie num: 40 Distance Score: 2.766
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.798
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 42 : Tracy Samantha Lord Haven (Katharine Hepburn) is a wealthy Main Line Philadelphia socialite who had  ...
# Original title:  The Philadelphia Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 42 Distance Score: 0.0
# Title: The Philadelphia Story
# ----------------------------------------
# Movie num: 40 Distance Score: 2.465
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.507
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 43 : The movie is based on a novel by Harper Lee, who interestingly enough was the assistant to Truman Ca ...
# Original title:  To Kill a Mockingbird
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 43 Distance Score: 0.0
# Title: To Kill a Mockingbird
# ----------------------------------------
# Movie num: 40 Distance Score: 2.594
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.631
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 44 : Jerry Mulligan (Gene Kelly) is an exuberant American expatriate in Paris trying to make a reputation ...
# Original title:  An American in Paris
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 44 Distance Score: 0.0
# Title: An American in Paris
# ----------------------------------------
# Movie num: 40 Distance Score: 2.415
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.452
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 45 : At the end of World War II, Fred Derry (Dana Andrews), Al Stevenson (Fredric March) and Homer Parris ...
# Original title:  The Best Years of Our Lives
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 45 Distance Score: 0.0
# Title: The Best Years of Our Lives
# ----------------------------------------
# Movie num: 40 Distance Score: 2.541
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.593
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 46 : Henry Higgins (Rex Harrison), an arrogant, irascible professor of phonetics, boasts to a new acquain ...
# Original title:  My Fair Lady
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 46 Distance Score: 0.0
# Title: My Fair Lady
# ----------------------------------------
# Movie num: 40 Distance Score: 2.676
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.689
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 47 : Judah Ben-Hur (Charlton Heston) is a wealthy merchant living in Judea at the time of Christ. Under t ...
# Original title:  Ben-Hur
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 47 Distance Score: 0.0
# Title: Ben-Hur
# ----------------------------------------
# Movie num: 40 Distance Score: 2.487
# Title: Rocky
# ----------------------------------------
# Movie num: 35 Distance Score: 2.528
# Title: Gladiator
# ----------------------------------------
#
# Synopsis 48 : A high ranking Russian General has arrived at an industrial project office. It is night and this man ...
# Original title:  Doctor Zhivago
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 48 Distance Score: 0.0
# Title: Doctor Zhivago
# ----------------------------------------
# Movie num: 40 Distance Score: 2.575
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.587
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 49 : Against a backdrop of the Stars and Stripes, General George S. Patton (George C. Scott) addresses hi ...
# Original title:  Patton
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 49 Distance Score: 0.0
# Title: Patton
# ----------------------------------------
# Movie num: 40 Distance Score: 2.916
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.97
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 50 : Late one night, on one of the many beaches of Amity Island off the coast of New England, local teena ...
# Original title:  Jaws
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 50 Distance Score: 0.0
# Title: Jaws
# ----------------------------------------
# Movie num: 40 Distance Score: 2.779
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.81
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 51 : In the 13th Century England, after several years of political unrest in Scotland, the land is open t ...
# Original title:  Braveheart
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 51 Distance Score: 0.0
# Title: Braveheart
# ----------------------------------------
# Movie num: 40 Distance Score: 2.707
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.721
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 52 : The film tells the story of three men who pursue, often at the expense of others, information about  ...
# Original title:  The Good, the Bad and the Ugly
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 52 Distance Score: 0.0
# Title: The Good, the Bad and the Ugly
# ----------------------------------------
# Movie num: 40 Distance Score: 2.434
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.435
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 53 : Wyoming, c. 1900s. Butch Cassidy (Paul Newman) and the Sundance Kid (Robert Redford), the leaders of ...
# Original title:  Butch Cassidy and the Sundance Kid
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 53 Distance Score: 0.0
# Title: Butch Cassidy and the Sundance Kid
# ----------------------------------------
# Movie num: 91 Distance Score: 2.694
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.699
# Title: Rocky
# ----------------------------------------
# Synopsis 54 : Fred Dobbs (Humphrey Bogart) and Bob Curtin (Tim Holt) are down on their luck in Mexico and are both ...
# Original title:  The Treasure of the Sierra Madre
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 54 Distance Score: 0.0
# Title: The Treasure of the Sierra Madre
# ----------------------------------------
# Movie num: 91 Distance Score: 2.553
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.562
# Title: Rocky
# ----------------------------------------
#
# Synopsis 55 : C. C. Baxter (Jack Lemmon) is a lonely office drone for an insurance company in New York City. Four  ...
# Original title:  The Apartment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 55 Distance Score: 0.0
# Title: The Apartment
# ----------------------------------------
# Movie num: 40 Distance Score: 2.436
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.479
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 56 : Chris Taylor (Charlie Sheen) is a young American who has abandoned a privileged life at a university ...
# Original title:  Platoon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 56 Distance Score: 0.0
# Title: Platoon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.811
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.831
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 57 : In Hadleyville, a small town in New Mexico Territory, Marshal Will Kane (Cooper), newly married to A ...
# Original title:  High Noon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 57 Distance Score: 0.0
# Title: High Noon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.582
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.622
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 58 : During a US Civil War battle, Union Army Officer Lieutenant John J. Dunbar (Kevin Costner) learns th ...
# Original title:  Dances with Wolves
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 58 Distance Score: 0.0
# Title: Dances with Wolves
# ----------------------------------------
# Movie num: 91 Distance Score: 2.597
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.633
# Title: Rocky
# ----------------------------------------
#
# Synopsis 59 : "The Pianist" begins in Warsaw, Poland in September, 1939, at the outbreak of the Second World War,  ...
# Original title:  The Pianist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 59 Distance Score: 0.0
# Title: The Pianist
# ----------------------------------------
# Movie num: 40 Distance Score: 2.789
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.812
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 60 : The film opens with three men driving in their car late at night on a highway. In the car are Henry  ...
# Original title:  Goodfellas
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 60 Distance Score: 0.0
# Title: Goodfellas
# ----------------------------------------
# Movie num: 40 Distance Score: 2.864
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.906
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 61 : Father Lancaster Merrin (Max Von Sydow) is an elderly Catholic priest on an archeological dig in Ira ...
# Original title:  The Exorcist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 61 Distance Score: 0.0
# Title: The Exorcist
# ----------------------------------------
# Movie num: 40 Distance Score: 2.638
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.675
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 62 : In the Western Pennsylvania foundry town of Clairton, during the late 1960s, Russian-American steel  ...
# Original title:  The Deer Hunter
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 62 Distance Score: 0.0
# Title: The Deer Hunter
# ----------------------------------------
# Movie num: 40 Distance Score: 2.639
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.712
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 63 : Professor Kantorek gives an impassioned speech about the glory of serving in the Army and "saving th ...
# Original title:  All Quiet on the Western Front
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 63 Distance Score: 0.0
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 40 Distance Score: 2.919
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.961
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 64 : In December 1970 in Marseilles, France, a plainclothes policeman is observing former longshoreman tu ...
# Original title:  The French Connection
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 64 Distance Score: 0.0
# Title: The French Connection
# ----------------------------------------
# Movie num: 40 Distance Score: 2.763
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.778
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 65 : Chaplin City Lights The Little Tramp first meets the Flower Girl, and discovers she is blind when sh ...
# Original title:  City Lights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 65 Distance Score: 0.0
# Title: City Lights
# ----------------------------------------
# Movie num: 40 Distance Score: 2.365
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.4
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 66 : The film opens with Prince Albert, Duke of York (later King George VI), known to his wife and family ...
# Original title:  The King's Speech
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 66 Distance Score: 0.0
# Title: The King's Speech
# ----------------------------------------
# Movie num: 40 Distance Score: 2.718
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.73
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 67 : It Happened One Night begins with a rich heiress named Ellie Andrews sequestered by her father on hi ...
# Original title:  It Happened One Night
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 67 Distance Score: 0.0
# Title: It Happened One Night
# ----------------------------------------
# Movie num: 91 Distance Score: 2.405
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.435
# Title: Rocky
# ----------------------------------------
#
# Synopsis 68 : George Eastman (Montgomery Clift), is the poor nephew of rich industrialist Charles Eastman (Herbert ...
# Original title:  A Place in the Sun
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 68 Distance Score: 0.0
# Title: A Place in the Sun
# ----------------------------------------
# Movie num: 44 Distance Score: 2.649
# Title: An American in Paris
# ----------------------------------------
# Movie num: 40 Distance Score: 2.655
# Title: Rocky
# ----------------------------------------
#
# Synopsis 69 : Joe Buck (Jon Voight) leaves his job as a dishwasher in a small town in Texas, and gets on the bus h ...
# Original title:  Midnight Cowboy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 69 Distance Score: 0.0
# Title: Midnight Cowboy
# ----------------------------------------
# Movie num: 40 Distance Score: 2.576
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.609
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 70 : The governor of an unnamed western state, Hubert "Happy" Hopper (Guy Kibbee), has to pick a replacem ...
# Original title:  Mr. Smith Goes to Washington
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 70 Distance Score: 0.0
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
# Movie num: 40 Distance Score: 2.632
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.647
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 71 : Charlie Babbitt (Tom Cruise), a Los Angeles car dealer in his mid-twenties, is in the middle of impo ...
# Original title:  Rain Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 71 Distance Score: 0.0
# Title: Rain Man
# ----------------------------------------
# Movie num: 91 Distance Score: 2.688
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.693
# Title: Rocky
# ----------------------------------------
# Synopsis 72 : Annie Hall is a film about a comedian, Alvy Singer (Woody Allen), who falls in love with Annie Hall  ...
# Original title:  Annie Hall
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 72 Distance Score: 0.0
# Title: Annie Hall
# ----------------------------------------
# Movie num: 40 Distance Score: 2.517
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.524
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 73 : [Out Of Africa]A well-heeled Danish lady goes to an English colony in Africa and buys 1000 acres. He ...
# Original title:  Out of Africa
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 73 Distance Score: 0.0
# Title: Out of Africa
# ----------------------------------------
# Movie num: 40 Distance Score: 2.885
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.895
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 74 : Though Will Hunting (Matt Damon) has genius-level intelligence (such as a talent for memorizing fact ...
# Original title:  Good Will Hunting
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 74 Distance Score: 0.0
# Title: Good Will Hunting
# ----------------------------------------
# Movie num: 40 Distance Score: 2.86
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.921
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 75 : Aurora Greenway and her daughter Emma are both searching for deep romantic love. Beginning with Emma ...
# Original title:  Terms of Endearment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 75 Distance Score: 0.0
# Title: Terms of Endearment
# ----------------------------------------
# Movie num: 40 Distance Score: 2.513
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.529
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 76 : Michael Dorsey is an actor living and working in New York City. Most of his work seems to be on the  ...
# Original title:  Tootsie
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 76 Distance Score: 0.0
# Title: Tootsie
# ----------------------------------------
# Movie num: 40 Distance Score: 2.447
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.487
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 77 : The movie opens with a car towing a new tan Oldsmobile Cutlass Ciera through a sub-freezing blizzard ...
# Original title:  Fargo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 77 Distance Score: 0.0
# Title: Fargo
# ----------------------------------------
# Movie num: 40 Distance Score: 2.721
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.791
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 78 : In the early 1920s, Jordan "Bick" Benedict (Rock Hudson), the head of the rich Benedict ranching fam ...
# Original title:  Giant
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 78 Distance Score: 0.0
# Title: Giant
# ----------------------------------------
# Movie num: 40 Distance Score: 2.609
# Title: Rocky
# ----------------------------------------
# Movie num: 44 Distance Score: 2.648
# Title: An American in Paris
# ----------------------------------------
#
# Synopsis 79 : After serving four years in prison for killing a man, hotheaded Tom Joad (Henry Fonda) heads back to ...
# Original title:  The Grapes of Wrath
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 79 Distance Score: 0.0
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 40 Distance Score: 2.575
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.611
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 80 : Shane (Alan Ladd), a skilled, laconic gunfighter with a mysterious past, rides into an isolated vall ...
# Original title:  Shane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 80 Distance Score: 0.0
# Title: Shane
# ----------------------------------------
# Movie num: 40 Distance Score: 2.552
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.584
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 81 : The movie begins with an old man named Paul Edgecomb (Dabbs Greer) in a retirement center. He takes  ...
# Original title:  The Green Mile
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 81 Distance Score: 0.0
# Title: The Green Mile
# ----------------------------------------
# Movie num: 40 Distance Score: 2.664
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.703
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 82 : In what appers to be the Sonoran Desert; in or near Mexico, a cartographer named David Laughlin (Bob ...
# Original title:  Close Encounters of the Third Kind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 82 Distance Score: 0.0
# Title: Close Encounters of the Third Kind
# ----------------------------------------
# Movie num: 21 Distance Score: 2.893
# Title: E.T. the Extra-Terrestrial
# ----------------------------------------
# Movie num: 40 Distance Score: 2.913
# Title: Rocky
# ----------------------------------------
#
# Synopsis 83 : A television network cynically exploits a deranged former anchor's ravings and revelations about the ...
# Original title:  Network
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 83 Distance Score: 0.0
# Title: Network
# ----------------------------------------
# Movie num: 40 Distance Score: 2.769
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.801
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 84 : The overarching plot takes place over five days leading up to a political rally for Replacement Part ...
# Original title:  Nashville
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 84 Distance Score: 0.0
# Title: Nashville
# ----------------------------------------
# Movie num: 40 Distance Score: 2.93
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.986
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 85 : The film explores the life of 21-year-old Ben Braddock (Dustin Hoffman) shortly after earning his ba ...
# Original title:  The Graduate
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 85 Distance Score: 0.0
# Title: The Graduate
# ----------------------------------------
# Movie num: 40 Distance Score: 2.455
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.482
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 86 : It's the last night of the summer in 1962, and a number of friends are meeting at Burger City for on ...
# Original title:  American Graffiti
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 86 Distance Score: 0.0
# Title: American Graffiti
# ----------------------------------------
# Movie num: 16 Distance Score: 2.618
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 40 Distance Score: 2.626
# Title: Rocky
# ----------------------------------------
#
# Synopsis 87 : Late one morning in the Hawthorne Grill, a restaurant on Sunset Boulevard in Los Angeles, a couple o ...
# Original title:  Pulp Fiction
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 87 Distance Score: 0.0
# Title: Pulp Fiction
# ----------------------------------------
# Movie num: 40 Distance Score: 2.737
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.798
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 88 : An English spinster, Rose (Katharine Hepburn), is the sister of a missionary, Rev. Samuel Sayer (Rob ...
# Original title:  The African Queen
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 88 Distance Score: 0.0
# Title: The African Queen
# ----------------------------------------
# Movie num: 40 Distance Score: 2.655
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.673
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 89 : A group of people traveling on a stagecoach find their journey complicated by the threat of Geronimo ...
# Original title:  Stagecoach
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 89 Distance Score: 0.0
# Title: Stagecoach
# ----------------------------------------
# Movie num: 40 Distance Score: 2.735
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.736
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 90 : In 1787, British ship Bounty leaves Portsmouth to bring a cargo of bread-fruit from Tahiti but the s ...
# Original title:  Mutiny on the Bounty
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 90 Distance Score: 0.0
# Title: Mutiny on the Bounty
# ----------------------------------------
# Movie num: 40 Distance Score: 2.619
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.633
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 91 : Private eye Sam Spade and his partner Miles Archer are approached by Miss Wonderly to follow a man,  ...
# Original title:  The Maltese Falcon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 91 Distance Score: 0.0
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.316
# Title: Rocky
# ----------------------------------------
# Movie num: 98 Distance Score: 2.393
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 92 : "A bit of the old ultra-violence".London, England in the foreseeable future. "Our humble narrator" A ...
# Original title:  A Clockwork Orange
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 92 Distance Score: 0.0
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 40 Distance Score: 2.634
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.709
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 93 : Travis Bickle (Robert De Niro) goes to a New York City taxi depot where he applies for a job as a dr ...
# Original title:  Taxi Driver
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 93 Distance Score: 0.0
# Title: Taxi Driver
# ----------------------------------------
# Movie num: 40 Distance Score: 2.511
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.585
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 94 : A servant in the house of Wuthering Heights tells a traveler the unfortunate tale of lovers Cathy an ...
# Original title:  Wuthering Heights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 94 Distance Score: 0.0
# Title: Wuthering Heights
# ----------------------------------------
# Movie num: 40 Distance Score: 2.457
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.5
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 95 : Walter Neff (MacMurray) is a successful insurance salesman for Pacific All-Risk returning to his off ...
# Original title:  Double Indemnity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 95 Distance Score: 0.0
# Title: Double Indemnity
# ----------------------------------------
# Movie num: 91 Distance Score: 2.447
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 40 Distance Score: 2.468
# Title: Rocky
# ----------------------------------------
#
# Synopsis 96 : Shortly after moving to Los Angeles with his parents, 17-year-old Jim Stark (James Dean) enrolls at  ...
# Original title:  Rebel Without a Cause
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 96 Distance Score: 0.0
# Title: Rebel Without a Cause
# ----------------------------------------
# Movie num: 40 Distance Score: 2.56
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.567
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 97 : L.B. "Jeff" Jeffries (James Stewart) recuperates from a broken leg during a sweltering New York summ ...
# Original title:  Rear Window
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 97 Distance Score: 0.0
# Title: Rear Window
# ----------------------------------------
# Movie num: 40 Distance Score: 2.552
# Title: Rocky
# ----------------------------------------
# Movie num: 98 Distance Score: 2.611
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 98 : Sights of Vienna, Austria, flash across the screen as an Englishman's voice (Carol Reed) describes t ...
# Original title:  The Third Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 98 Distance Score: 0.0
# Title: The Third Man
# ----------------------------------------
# Movie num: 40 Distance Score: 2.38
# Title: Rocky
# ----------------------------------------
# Movie num: 91 Distance Score: 2.393
# Title: The Maltese Falcon
# ----------------------------------------
#
# Synopsis 99 : At the end of an ordinary work day, advertising executive Roger O. Thornhill (Cary Grant) hurries fr ...
# Original title:  North by Northwest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 99 Distance Score: 0.0
# Title: North by Northwest
# ----------------------------------------
# Movie num: 98 Distance Score: 2.581
# Title: The Third Man
# ----------------------------------------
# Movie num: 40 Distance Score: 2.607
# Title: Rocky
# ----------------------------------------
#
# Synopsis 100 : A film of the life of the renowned musical composer, playwright, actor, dancer, and singer George M. ...
# Original title:  Yankee Doodle Dandy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 100 Distance Score: 0.0
# Title: Yankee Doodle Dandy
# ----------------------------------------
# Movie num: 44 Distance Score: 2.522
# Title: An American in Paris
# ----------------------------------------
# Movie num: 40 Distance Score: 2.574
# Title: Rocky
# ----------------------------------------

# %% [markdown]
# ### Similarity Analysis Using BM25

# %%
import scipy.sparse as sp 

def compute_corpus_term_idfs(corpus_features, norm_corpus):
    
    dfs = np.diff(sp.csc_matrix(corpus_features, copy=True).indptr)
    dfs = 1 + dfs # to smoothen idf later
    total_docs = 1 + len(norm_corpus)
    idfs = 1.0 + np.log(float(total_docs) / dfs)
    return idfs


def compute_bm25_similarity(doc_features, corpus_features,
                            corpus_doc_lengths, avg_doc_length,
                            term_idfs, k1=1.5, b=0.75, top_n=3):
    # Get corpus bag of words features
    corpus_features = corpus_features.toarray()
    # convert query document features to binary features
    # this is to keep a note of which terms exist per document
    doc_features = doc_features.toarray()[0]
    doc_features[doc_features >= 1] = 1
    
    # Compute the document idf scores for present terms
    doc_idfs = doc_features * term_idfs
    # compute numerator expression in BM25 equation
    numerator_coeff = corpus_features * (k1 + 1)
    numerator = np.multiply(doc_idfs, numerator_coeff)
    # Compute denominator expression in BM25 equation
    denominator_coeff =  k1 * (1 - b + 
                                (b * (corpus_doc_lengths / 
                                        avg_doc_length)))
    denominator_coeff = np.vstack(denominator_coeff)
    denominator = corpus_features + denominator_coeff
    # Compute the BM25 score combining the above equations
    bm25_scores = np.sum(np.divide(numerator,
                                   denominator),
                         axis=1)
    # Get top n relevant docs with highest BM25 score                     
    top_docs = bm25_scores.argsort()[::-1][:top_n]
    top_docs_with_score = [(index, round(bm25_scores[index], 3))
                            for index in top_docs]
    return top_docs_with_score

# Build bag of words based features first
vectorizer, corpus_features = build_feature_matrix(corpus,
                                                   feature_type='frequency')
# We use the same vectorizer that we used to build the feature matrix for the corpus also for query doc
query_docs_features = vectorizer.transform(corpus)

# Get average document length of the corpus (avgdl)
doc_lengths = [len(doc.split()) for doc in corpus]   
avg_dl = np.average(doc_lengths) 

# Get the corpus term idfs
corpus_term_idfs = compute_corpus_term_idfs(corpus_features,
                                            corpus)

# Analyze document similarity using BM25 framework    
print('Similarity Analysis using BM25')
print('='*60)
for index, synopsis in enumerate(movie_data["Synopsis"]):
    
    doc_features = query_docs_features[index]
    top_similar_titles = compute_bm25_similarity(doc_features,
                                               corpus_features,
                                               doc_lengths,
                                               avg_dl,
                                               corpus_term_idfs,
                                               k1=1.5, b=0.75,
                                               top_n=3)
    print('Synopsis',index+1 ,':', synopsis[:100],"...")
    original_title = getMovieTitle(movie_data,synopsis)
    print('Original title: ', original_title,'\n')
    print('Top', len(top_similar_titles), 'similar titles:')
    print('-'*40)
    for movie_index, sim_score in top_similar_titles:
        sim_title = movie_data.iloc[movie_index]["Title"]
        print('Movie num: {} BM25 Score: {}\nTitle: {}'.format(movie_index+1,
                                                                 sim_score,
                                                                 sim_title)) 
        print('-'*40)
    print()
# Out:
# Similarity Analysis using BM25
# ============================================================
# Synopsis 1 : In late summer 1945, guests are gathered for the wedding reception of Don Vito Corleone's daughter C ...
# Original title:  The Godfather
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 1 BM25 Score: 2445.764
# Title: The Godfather
# ----------------------------------------
# Movie num: 12 BM25 Score: 792.182
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 77 BM25 Score: 523.034
# Title: Fargo
# ----------------------------------------
#
# Synopsis 2 : In 1947, Andy Dufresne (Tim Robbins), a banker in Maine, is convicted of murdering his wife and her  ...
# Original title:  The Shawshank Redemption
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 2 BM25 Score: 2008.344
# Title: The Shawshank Redemption
# ----------------------------------------
# Movie num: 77 BM25 Score: 450.535
# Title: Fargo
# ----------------------------------------
# Movie num: 16 BM25 Score: 444.955
# Title: On the Waterfront
# ----------------------------------------
#
# Synopsis 3 : The relocation of Polish Jews from surrounding areas to Krakow begins in late 1939, shortly after th ...
# Original title:  Schindler's List
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 3 BM25 Score: 1654.62
# Title: Schindler's List
# ----------------------------------------
# Movie num: 59 BM25 Score: 346.163
# Title: The Pianist
# ----------------------------------------
# Movie num: 20 BM25 Score: 300.061
# Title: Star Wars
# ----------------------------------------
#
# Synopsis 4 : The film opens in 1964, where an older and fatter Jake LaMotta (Robert De Niro) practices his stand- ...
# Original title:  Raging Bull
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 4 BM25 Score: 1331.413
# Title: Raging Bull
# ----------------------------------------
# Movie num: 77 BM25 Score: 231.747
# Title: Fargo
# ----------------------------------------
# Movie num: 40 BM25 Score: 230.852
# Title: Rocky
# ----------------------------------------
#
# Synopsis 5 : In the early years of World War II, December 1941, the Moroccan coastal city of Casablanca attracts  ...
# Original title:  Casablanca
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 5 BM25 Score: 1248.849
# Title: Casablanca
# ----------------------------------------
# Movie num: 7 BM25 Score: 245.726
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 98 BM25 Score: 236.538
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 6 : In 1963 Oregon, Randle Patrick McMurphy (Nicholson), a criminal who has been sentenced to a fairly s ...
# Original title:  One Flew Over the Cuckoo's Nest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 6 BM25 Score: 1491.1
# Title: One Flew Over the Cuckoo's Nest
# ----------------------------------------
# Movie num: 92 BM25 Score: 284.794
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 77 BM25 Score: 265.177
# Title: Fargo
# ----------------------------------------
#
# Synopsis 7 : The film opens in Tara, a cotton plantation owned by the proud Gerald O'Hara (Thomas Mitchell), a se ...
# Original title:  Gone with the Wind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 7 BM25 Score: 2576.042
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 20 BM25 Score: 590.842
# Title: Star Wars
# ----------------------------------------
# Movie num: 99 BM25 Score: 586.235
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 8 : It's 1941, and newspaper tycoon Charles Foster Kane (Orson Welles, who also directed and co-wrote th ...
# Original title:  Citizen Kane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 8 BM25 Score: 1695.664
# Title: Citizen Kane
# ----------------------------------------
# Movie num: 7 BM25 Score: 333.339
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 77 BM25 Score: 314.506
# Title: Fargo
# ----------------------------------------
#
# Synopsis 9 : Dorothy Gale (Judy Garland) is an orphaned teenager who lives with her Auntie Em (Clara Blandick) an ...
# Original title:  The Wizard of Oz
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 9 BM25 Score: 1380.58
# Title: The Wizard of Oz
# ----------------------------------------
# Movie num: 86 BM25 Score: 242.358
# Title: American Graffiti
# ----------------------------------------
# Movie num: 7 BM25 Score: 238.311
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 10 : In 1996, treasure hunter Brock Lovett and his team aboard the research vessel Keldysh search the wre ...
# Original title:  Titanic
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 10 BM25 Score: 1127.303
# Title: Titanic
# ----------------------------------------
# Movie num: 7 BM25 Score: 170.769
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 99 BM25 Score: 166.436
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 11 : In 1935, T. E. Lawrence (Peter O'Toole) is killed in a motorcycle accident. At his memorial service  ...
# Original title:  Lawrence of Arabia
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 11 BM25 Score: 1585.564
# Title: Lawrence of Arabia
# ----------------------------------------
# Movie num: 56 BM25 Score: 246.583
# Title: Platoon
# ----------------------------------------
# Movie num: 37 BM25 Score: 236.021
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 12 : The Godfather Part II presents two parallel storylines. One involves Mafia chief Michael Corleone in ...
# Original title:  The Godfather: Part II
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 12 BM25 Score: 2118.013
# Title: The Godfather: Part II
# ----------------------------------------
# Movie num: 1 BM25 Score: 813.83
# Title: The Godfather
# ----------------------------------------
# Movie num: 7 BM25 Score: 454.74
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 13 : In a Phoenix hotel room on a Friday afternoon, Marion Crane (Janet Leigh) and her out-of-town lover  ...
# Original title:  Psycho
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 13 BM25 Score: 2016.764
# Title: Psycho
# ----------------------------------------
# Movie num: 77 BM25 Score: 611.892
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 606.684
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 14 : The film opens with the camera tracking down Sunset Boulevard in Los Angeles, California as police c ...
# Original title:  Sunset Blvd.
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 14 BM25 Score: 1391.436
# Title: Sunset Blvd.
# ----------------------------------------
# Movie num: 7 BM25 Score: 259.286
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 77 BM25 Score: 248.312
# Title: Fargo
# ----------------------------------------
#
# Synopsis 15 : A woman's face gives way to a kaleidoscope of credits, signalling the start of Alfred Hitchcock's Ve ...
# Original title:  Vertigo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 15 BM25 Score: 1905.094
# Title: Vertigo
# ----------------------------------------
# Movie num: 99 BM25 Score: 455.366
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 422.724
# Title: Fargo
# ----------------------------------------
#
# Synopsis 16 : Terry Malloy (Marlon Brando) once dreamt of being a great prize fighter, but now works at the docks  ...
# Original title:  On the Waterfront
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 16 BM25 Score: 1838.319
# Title: On the Waterfront
# ----------------------------------------
# Movie num: 77 BM25 Score: 528.46
# Title: Fargo
# ----------------------------------------
# Movie num: 40 BM25 Score: 499.984
# Title: Rocky
# ----------------------------------------
#
# Synopsis 17 : The film begins with a feather falling to the feet of Forrest Gump who is sitting at a bus stop in S ...
# Original title:  Forrest Gump
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 17 BM25 Score: 1000.419
# Title: Forrest Gump
# ----------------------------------------
# Movie num: 7 BM25 Score: 183.927
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 37 BM25 Score: 182.125
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 18 : The widowed, retired Austrian naval officer, Captain Von Trapp (Christopher Plummer) has made his Au ...
# Original title:  The Sound of Music
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 18 BM25 Score: 732.005
# Title: The Sound of Music
# ----------------------------------------
# Movie num: 7 BM25 Score: 112.227
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 98 BM25 Score: 103.063
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 19 : A fight set to music between an American gang, the Jets, and a rival gang, the Sharks, who have move ...
# Original title:  West Side Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 19 BM25 Score: 1459.514
# Title: West Side Story
# ----------------------------------------
# Movie num: 98 BM25 Score: 314.955
# Title: The Third Man
# ----------------------------------------
# Movie num: 99 BM25 Score: 296.565
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 20 : Note: Italicized paragraphs denote scenes added for the film's 1997 special edition and updated for  ...
# Original title:  Star Wars
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 20 BM25 Score: 2868.718
# Title: Star Wars
# ----------------------------------------
# Movie num: 37 BM25 Score: 710.655
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 99 BM25 Score: 683.919
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 21 : In a forested area overlooking a sprawling suburban neighborhood, an alien spacecraft has landed. Th ...
# Original title:  E.T. the Extra-Terrestrial
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 21 BM25 Score: 1171.039
# Title: E.T. the Extra-Terrestrial
# ----------------------------------------
# Movie num: 82 BM25 Score: 302.996
# Title: Close Encounters of the Third Kind
# ----------------------------------------
# Movie num: 86 BM25 Score: 286.547
# Title: American Graffiti
# ----------------------------------------
#
# Synopsis 22 : To Richard Strauss' tone poem "Thus Spake Zarathustra," the title sequence shows the sun rising behi ...
# Original title:  2001: A Space Odyssey
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 22 BM25 Score: 2184.002
# Title: 2001: A Space Odyssey
# ----------------------------------------
# Movie num: 20 BM25 Score: 443.116
# Title: Star Wars
# ----------------------------------------
# Movie num: 77 BM25 Score: 416.625
# Title: Fargo
# ----------------------------------------
# Synopsis 23 : Promising FBI Academy student Clarice Starling is pulled from her training at the FBI Training Facil ...
# Original title:  The Silence of the Lambs
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 23 BM25 Score: 1421.007
# Title: The Silence of the Lambs
# ----------------------------------------
# Movie num: 99 BM25 Score: 247.234
# Title: North by Northwest
# ----------------------------------------
# Movie num: 20 BM25 Score: 213.077
# Title: Star Wars
# ----------------------------------------
#
# Synopsis 24 : Set in 1937 Los Angeles, a private investigator named Jake "J.J." Gittes (Nicholson) is hired to spy ...
# Original title:  Chinatown
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 24 BM25 Score: 1749.957
# Title: Chinatown
# ----------------------------------------
# Movie num: 99 BM25 Score: 417.372
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 410.513
# Title: Fargo
# ----------------------------------------
#
# Synopsis 25 : [this synopsis is primarily from the wikipedia article The_Bridge_on_the_River_Kwai]Two prisoners of ...
# Original title:  The Bridge on the River Kwai
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 25 BM25 Score: 1702.596
# Title: The Bridge on the River Kwai
# ----------------------------------------
# Movie num: 37 BM25 Score: 380.908
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 56 BM25 Score: 359.989
# Title: Platoon
# ----------------------------------------
#
# Synopsis 26 : Don Lockwood (Gene Kelly) is a popular silent film star with humble roots as a singer, dancer and st ...
# Original title:  Singin' in the Rain
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 26 BM25 Score: 937.775
# Title: Singin' in the Rain
# ----------------------------------------
# Movie num: 84 BM25 Score: 185.802
# Title: Nashville
# ----------------------------------------
# Movie num: 76 BM25 Score: 135.691
# Title: Tootsie
# ----------------------------------------
#
# Synopsis 27 : This movie is about a divine intervention by a guardian angel, to help a man in distress. It opens w ...
# Original title:  It's a Wonderful Life
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 27 BM25 Score: 1947.764
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 77 BM25 Score: 442.582
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 441.787
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 28 : Joe and Jerry, a saxophonist and bassist, respectively, are two working-class musicians, working in  ...
# Original title:  Some Like It Hot
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 28 BM25 Score: 1794.299
# Title: Some Like It Hot
# ----------------------------------------
# Movie num: 99 BM25 Score: 461.089
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 440.017
# Title: Fargo
# ----------------------------------------
#
# Synopsis 29 : A teenaged Hispanic boy has just been tried for the murder of his father, and the case is now in the ...
# Original title:  12 Angry Men
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 29 BM25 Score: 808.648
# Title: 12 Angry Men
# ----------------------------------------
# Movie num: 98 BM25 Score: 127.471
# Title: The Third Man
# ----------------------------------------
# Movie num: 16 BM25 Score: 122.772
# Title: On the Waterfront
# ----------------------------------------
#
# Synopsis 30 : At the Burpelson U.S. Air Force Base somewhere in the continental USA, the eccentric Brigadier Gener ...
# Original title:  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 30 BM25 Score: 1883.258
# Title: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# ----------------------------------------
# Movie num: 20 BM25 Score: 360.291
# Title: Star Wars
# ----------------------------------------
# Movie num: 37 BM25 Score: 331.165
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 31 : The story begins in 1823 as the elderly Salieri attempts suicide by slitting his throat while loudly ...
# Original title:  Amadeus
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 31 BM25 Score: 1409.295
# Title: Amadeus
# ----------------------------------------
# Movie num: 7 BM25 Score: 200.162
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 2 BM25 Score: 188.427
# Title: The Shawshank Redemption
# ----------------------------------------
#
# Synopsis 32 : U.S. Army Captain and special operations veteran Benjamin L. Willard (Martin Sheen), returned to Sai ...
# Original title:  Apocalypse Now
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 32 BM25 Score: 1395.234
# Title: Apocalypse Now
# ----------------------------------------
# Movie num: 56 BM25 Score: 291.103
# Title: Platoon
# ----------------------------------------
# Movie num: 37 BM25 Score: 245.787
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 33 : The story begins with the assassination of Mohandas K. "Mahatma" Gandhi in India in 1948. The follow ...
# Original title:  Gandhi
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 33 BM25 Score: 1029.928
# Title: Gandhi
# ----------------------------------------
# Movie num: 37 BM25 Score: 215.299
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 7 BM25 Score: 207.99
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 34 : In the opening scene, a flashback, two hobbits, Smeagol (Andy Serkis) and his friend Deagol (Thomas  ...
# Original title:  The Lord of the Rings: The Return of the King
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 34 BM25 Score: 2421.671
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
# Movie num: 20 BM25 Score: 447.558
# Title: Star Wars
# ----------------------------------------
# Movie num: 7 BM25 Score: 435.344
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 35 : Shouting "Roma Invicta!" as his forces attack, General Maximus Decimus Meridius leads the Roman Army ...
# Original title:  Gladiator
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 35 BM25 Score: 1329.952
# Title: Gladiator
# ----------------------------------------
# Movie num: 20 BM25 Score: 212.357
# Title: Star Wars
# ----------------------------------------
# Movie num: 1 BM25 Score: 188.745
# Title: The Godfather
# ----------------------------------------
#
# Synopsis 36 : In 1941 Hawaii, Private Robert E. Lee Prewitt (Montgomery Clift) is transferred from the Bugle Corps ...
# Original title:  From Here to Eternity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 36 BM25 Score: 1659.057
# Title: From Here to Eternity
# ----------------------------------------
# Movie num: 56 BM25 Score: 345.913
# Title: Platoon
# ----------------------------------------
# Movie num: 37 BM25 Score: 343.07
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 37 : An American flag back-lighted by the afternoon sun gently flaps in the breeze. The camera pulls back ...
# Original title:  Saving Private Ryan
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 37 BM25 Score: 2278.794
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 20 BM25 Score: 601.548
# Title: Star Wars
# ----------------------------------------
# Movie num: 56 BM25 Score: 598.357
# Title: Platoon
# ----------------------------------------
#
# Synopsis 38 : William Munny (Clint Eastwood) is a widower with two young children. He was once a very vicious gunf ...
# Original title:  Unforgiven
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 38 BM25 Score: 1510.364
# Title: Unforgiven
# ----------------------------------------
# Movie num: 7 BM25 Score: 351.397
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 99 BM25 Score: 345.761
# Title: North by Northwest
# ----------------------------------------
# Synopsis 39 : In the spring of 1936 an exploration party penetrates thick jungle on the South American continent.  ...
# Original title:  Raiders of the Lost Ark
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 39 BM25 Score: 2004.933
# Title: Raiders of the Lost Ark
# ----------------------------------------
# Movie num: 20 BM25 Score: 418.306
# Title: Star Wars
# ----------------------------------------
# Movie num: 37 BM25 Score: 374.287
# Title: Saving Private Ryan
# ----------------------------------------
#
# Synopsis 40 : Philadelphia Pennsylvania, home to the number one underdog fighter, Rocky Balboa (Sylvester Stalone) ...
# Original title:  Rocky
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 40 BM25 Score: 1860.821
# Title: Rocky
# ----------------------------------------
# Movie num: 77 BM25 Score: 541.731
# Title: Fargo
# ----------------------------------------
# Movie num: 16 BM25 Score: 489.157
# Title: On the Waterfront
# ----------------------------------------
#
# Synopsis 41 : Elia Kazan,who directed the Broadway play on which the black and white film is based, invited Marlon ...
# Original title:  A Streetcar Named Desire
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 41 BM25 Score: 1247.306
# Title: A Streetcar Named Desire
# ----------------------------------------
# Movie num: 92 BM25 Score: 196.905
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 7 BM25 Score: 190.085
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 42 : Tracy Samantha Lord Haven (Katharine Hepburn) is a wealthy Main Line Philadelphia socialite who had  ...
# Original title:  The Philadelphia Story
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 42 BM25 Score: 774.235
# Title: The Philadelphia Story
# ----------------------------------------
# Movie num: 7 BM25 Score: 115.781
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 99 BM25 Score: 108.41
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 43 : The movie is based on a novel by Harper Lee, who interestingly enough was the assistant to Truman Ca ...
# Original title:  To Kill a Mockingbird
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 43 BM25 Score: 1236.442
# Title: To Kill a Mockingbird
# ----------------------------------------
# Movie num: 77 BM25 Score: 270.501
# Title: Fargo
# ----------------------------------------
# Movie num: 98 BM25 Score: 258.733
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 44 : Jerry Mulligan (Gene Kelly) is an exuberant American expatriate in Paris trying to make a reputation ...
# Original title:  An American in Paris
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 44 BM25 Score: 434.2
# Title: An American in Paris
# ----------------------------------------
# Movie num: 78 BM25 Score: 69.632
# Title: Giant
# ----------------------------------------
# Movie num: 7 BM25 Score: 68.909
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 45 : At the end of World War II, Fred Derry (Dana Andrews), Al Stevenson (Fredric March) and Homer Parris ...
# Original title:  The Best Years of Our Lives
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 45 BM25 Score: 1065.685
# Title: The Best Years of Our Lives
# ----------------------------------------
# Movie num: 27 BM25 Score: 246.916
# Title: It's a Wonderful Life
# ----------------------------------------
# Movie num: 7 BM25 Score: 241.418
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 46 : Henry Higgins (Rex Harrison), an arrogant, irascible professor of phonetics, boasts to a new acquain ...
# Original title:  My Fair Lady
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 46 BM25 Score: 1124.895
# Title: My Fair Lady
# ----------------------------------------
# Movie num: 7 BM25 Score: 187.1
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 76 BM25 Score: 152.053
# Title: Tootsie
# ----------------------------------------
#
# Synopsis 47 : Judah Ben-Hur (Charlton Heston) is a wealthy merchant living in Judea at the time of Christ. Under t ...
# Original title:  Ben-Hur
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 47 BM25 Score: 1424.323
# Title: Ben-Hur
# ----------------------------------------
# Movie num: 34 BM25 Score: 249.052
# Title: The Lord of the Rings: The Return of the King
# ----------------------------------------
# Movie num: 7 BM25 Score: 243.88
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 48 : A high ranking Russian General has arrived at an industrial project office. It is night and this man ...
# Original title:  Doctor Zhivago
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 48 BM25 Score: 1509.575
# Title: Doctor Zhivago
# ----------------------------------------
# Movie num: 7 BM25 Score: 349.869
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 98 BM25 Score: 326.818
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 49 : Against a backdrop of the Stars and Stripes, General George S. Patton (George C. Scott) addresses hi ...
# Original title:  Patton
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 49 BM25 Score: 1664.271
# Title: Patton
# ----------------------------------------
# Movie num: 37 BM25 Score: 278.394
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 99 BM25 Score: 250.982
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 50 : Late one night, on one of the many beaches of Amity Island off the coast of New England, local teena ...
# Original title:  Jaws
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 50 BM25 Score: 2589.287
# Title: Jaws
# ----------------------------------------
# Movie num: 20 BM25 Score: 570.209
# Title: Star Wars
# ----------------------------------------
# Movie num: 77 BM25 Score: 563.789
# Title: Fargo
# ----------------------------------------
#
# Synopsis 51 : In the 13th Century England, after several years of political unrest in Scotland, the land is open t ...
# Original title:  Braveheart
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 51 BM25 Score: 1795.525
# Title: Braveheart
# ----------------------------------------
# Movie num: 7 BM25 Score: 397.716
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 1 BM25 Score: 326.094
# Title: The Godfather
# ----------------------------------------
#
# Synopsis 52 : The film tells the story of three men who pursue, often at the expense of others, information about  ...
# Original title:  The Good, the Bad and the Ugly
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 52 BM25 Score: 1062.995
# Title: The Good, the Bad and the Ugly
# ----------------------------------------
# Movie num: 37 BM25 Score: 242.213
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 20 BM25 Score: 239.651
# Title: Star Wars
# ----------------------------------------
#
# Synopsis 53 : Wyoming, c. 1900s. Butch Cassidy (Paul Newman) and the Sundance Kid (Robert Redford), the leaders of ...
# Original title:  Butch Cassidy and the Sundance Kid
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 53 BM25 Score: 1310.275
# Title: Butch Cassidy and the Sundance Kid
# ----------------------------------------
# Movie num: 99 BM25 Score: 252.885
# Title: North by Northwest
# ----------------------------------------
# Movie num: 82 BM25 Score: 243.737
# Title: Close Encounters of the Third Kind
# ----------------------------------------
#
# Synopsis 54 : Fred Dobbs (Humphrey Bogart) and Bob Curtin (Tim Holt) are down on their luck in Mexico and are both ...
# Original title:  The Treasure of the Sierra Madre
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 54 BM25 Score: 797.36
# Title: The Treasure of the Sierra Madre
# ----------------------------------------
# Movie num: 7 BM25 Score: 156.423
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 20 BM25 Score: 148.606
# Title: Star Wars
# ----------------------------------------
#
# Synopsis 55 : C. C. Baxter (Jack Lemmon) is a lonely office drone for an insurance company in New York City. Four  ...
# Original title:  The Apartment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 55 BM25 Score: 1103.849
# Title: The Apartment
# ----------------------------------------
# Movie num: 99 BM25 Score: 222.175
# Title: North by Northwest
# ----------------------------------------
# Movie num: 1 BM25 Score: 206.396
# Title: The Godfather
# ----------------------------------------
#
# Synopsis 56 : Chris Taylor (Charlie Sheen) is a young American who has abandoned a privileged life at a university ...
# Original title:  Platoon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 56 BM25 Score: 2119.059
# Title: Platoon
# ----------------------------------------
# Movie num: 37 BM25 Score: 531.986
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 20 BM25 Score: 448.517
# Title: Star Wars
# ----------------------------------------
#
# Synopsis 57 : In Hadleyville, a small town in New Mexico Territory, Marshal Will Kane (Cooper), newly married to A ...
# Original title:  High Noon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 57 BM25 Score: 1062.725
# Title: High Noon
# ----------------------------------------
# Movie num: 7 BM25 Score: 183.199
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 98 BM25 Score: 158.474
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 58 : During a US Civil War battle, Union Army Officer Lieutenant John J. Dunbar (Kevin Costner) learns th ...
# Original title:  Dances with Wolves
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 58 BM25 Score: 1436.953
# Title: Dances with Wolves
# ----------------------------------------
# Movie num: 37 BM25 Score: 269.079
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 7 BM25 Score: 266.808
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 59 : "The Pianist" begins in Warsaw, Poland in September, 1939, at the outbreak of the Second World War,  ...
# Original title:  The Pianist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 59 BM25 Score: 1466.359
# Title: The Pianist
# ----------------------------------------
# Movie num: 3 BM25 Score: 335.205
# Title: Schindler's List
# ----------------------------------------
# Movie num: 7 BM25 Score: 320.141
# Title: Gone with the Wind
# ----------------------------------------
# Synopsis 60 : The film opens with three men driving in their car late at night on a highway. In the car are Henry  ...
# Original title:  Goodfellas
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 60 BM25 Score: 1835.518
# Title: Goodfellas
# ----------------------------------------
# Movie num: 77 BM25 Score: 343.347
# Title: Fargo
# ----------------------------------------
# Movie num: 12 BM25 Score: 332.819
# Title: The Godfather: Part II
# ----------------------------------------
#
# Synopsis 61 : Father Lancaster Merrin (Max Von Sydow) is an elderly Catholic priest on an archeological dig in Ira ...
# Original title:  The Exorcist
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 61 BM25 Score: 1956.002
# Title: The Exorcist
# ----------------------------------------
# Movie num: 99 BM25 Score: 380.046
# Title: North by Northwest
# ----------------------------------------
# Movie num: 92 BM25 Score: 377.965
# Title: A Clockwork Orange
# ----------------------------------------
#
# Synopsis 62 : In the Western Pennsylvania foundry town of Clairton, during the late 1960s, Russian-American steel  ...
# Original title:  The Deer Hunter
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 62 BM25 Score: 1658.86
# Title: The Deer Hunter
# ----------------------------------------
# Movie num: 37 BM25 Score: 342.91
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 7 BM25 Score: 333.844
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 63 : Professor Kantorek gives an impassioned speech about the glory of serving in the Army and "saving th ...
# Original title:  All Quiet on the Western Front
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 63 BM25 Score: 1167.13
# Title: All Quiet on the Western Front
# ----------------------------------------
# Movie num: 37 BM25 Score: 243.524
# Title: Saving Private Ryan
# ----------------------------------------
# Movie num: 56 BM25 Score: 224.566
# Title: Platoon
# ----------------------------------------
#
# Synopsis 64 : In December 1970 in Marseilles, France, a plainclothes policeman is observing former longshoreman tu ...
# Original title:  The French Connection
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 64 BM25 Score: 2186.732
# Title: The French Connection
# ----------------------------------------
# Movie num: 99 BM25 Score: 468.625
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 455.058
# Title: Fargo
# ----------------------------------------
#
# Synopsis 65 : Chaplin City Lights The Little Tramp first meets the Flower Girl, and discovers she is blind when sh ...
# Original title:  City Lights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 65 BM25 Score: 861.17
# Title: City Lights
# ----------------------------------------
# Movie num: 7 BM25 Score: 175.577
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 77 BM25 Score: 171.485
# Title: Fargo
# ----------------------------------------
#
# Synopsis 66 : The film opens with Prince Albert, Duke of York (later King George VI), known to his wife and family ...
# Original title:  The King's Speech
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 66 BM25 Score: 1569.749
# Title: The King's Speech
# ----------------------------------------
# Movie num: 92 BM25 Score: 213.463
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 7 BM25 Score: 208.501
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 67 : It Happened One Night begins with a rich heiress named Ellie Andrews sequestered by her father on hi ...
# Original title:  It Happened One Night
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 67 BM25 Score: 733.261
# Title: It Happened One Night
# ----------------------------------------
# Movie num: 77 BM25 Score: 188.784
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 182.68
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 68 : George Eastman (Montgomery Clift), is the poor nephew of rich industrialist Charles Eastman (Herbert ...
# Original title:  A Place in the Sun
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 68 BM25 Score: 1179.226
# Title: A Place in the Sun
# ----------------------------------------
# Movie num: 7 BM25 Score: 204.643
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 27 BM25 Score: 196.564
# Title: It's a Wonderful Life
# ----------------------------------------
#
# Synopsis 69 : Joe Buck (Jon Voight) leaves his job as a dishwasher in a small town in Texas, and gets on the bus h ...
# Original title:  Midnight Cowboy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 69 BM25 Score: 547.45
# Title: Midnight Cowboy
# ----------------------------------------
# Movie num: 92 BM25 Score: 74.681
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 93 BM25 Score: 73.134
# Title: Taxi Driver
# ----------------------------------------
#
# Synopsis 70 : The governor of an unnamed western state, Hubert "Happy" Hopper (Guy Kibbee), has to pick a replacem ...
# Original title:  Mr. Smith Goes to Washington
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 70 BM25 Score: 1072.571
# Title: Mr. Smith Goes to Washington
# ----------------------------------------
# Movie num: 13 BM25 Score: 161.012
# Title: Psycho
# ----------------------------------------
# Movie num: 7 BM25 Score: 159.004
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 71 : Charlie Babbitt (Tom Cruise), a Los Angeles car dealer in his mid-twenties, is in the middle of impo ...
# Original title:  Rain Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 71 BM25 Score: 1273.44
# Title: Rain Man
# ----------------------------------------
# Movie num: 1 BM25 Score: 242.78
# Title: The Godfather
# ----------------------------------------
# Movie num: 77 BM25 Score: 239.972
# Title: Fargo
# ----------------------------------------
#
# Synopsis 72 : Annie Hall is a film about a comedian, Alvy Singer (Woody Allen), who falls in love with Annie Hall  ...
# Original title:  Annie Hall
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 72 BM25 Score: 628.699
# Title: Annie Hall
# ----------------------------------------
# Movie num: 76 BM25 Score: 130.241
# Title: Tootsie
# ----------------------------------------
# Movie num: 74 BM25 Score: 113.542
# Title: Good Will Hunting
# ----------------------------------------
#
# Synopsis 73 : [Out Of Africa]A well-heeled Danish lady goes to an English colony in Africa and buys 1000 acres. He ...
# Original title:  Out of Africa
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 73 BM25 Score: 859.211
# Title: Out of Africa
# ----------------------------------------
# Movie num: 7 BM25 Score: 170.188
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 2 BM25 Score: 144.891
# Title: The Shawshank Redemption
# ----------------------------------------
#
# Synopsis 74 : Though Will Hunting (Matt Damon) has genius-level intelligence (such as a talent for memorizing fact ...
# Original title:  Good Will Hunting
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 74 BM25 Score: 1630.784
# Title: Good Will Hunting
# ----------------------------------------
# Movie num: 92 BM25 Score: 253.389
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 7 BM25 Score: 252.379
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 75 : Aurora Greenway and her daughter Emma are both searching for deep romantic love. Beginning with Emma ...
# Original title:  Terms of Endearment
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 75 BM25 Score: 1128.579
# Title: Terms of Endearment
# ----------------------------------------
# Movie num: 7 BM25 Score: 262.356
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 76 BM25 Score: 214.32
# Title: Tootsie
# ----------------------------------------
#
# Synopsis 76 : Michael Dorsey is an actor living and working in New York City. Most of his work seems to be on the  ...
# Original title:  Tootsie
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 76 BM25 Score: 1710.426
# Title: Tootsie
# ----------------------------------------
# Movie num: 77 BM25 Score: 443.879
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 426.785
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 77 : The movie opens with a car towing a new tan Oldsmobile Cutlass Ciera through a sub-freezing blizzard ...
# Original title:  Fargo
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 77 BM25 Score: 2514.177
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 746.989
# Title: North by Northwest
# ----------------------------------------
# Movie num: 13 BM25 Score: 736.438
# Title: Psycho
# ----------------------------------------
#
# Synopsis 78 : In the early 1920s, Jordan "Bick" Benedict (Rock Hudson), the head of the rich Benedict ranching fam ...
# Original title:  Giant
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 78 BM25 Score: 1322.528
# Title: Giant
# ----------------------------------------
# Movie num: 7 BM25 Score: 257.567
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 1 BM25 Score: 234.075
# Title: The Godfather
# ----------------------------------------
#
# Synopsis 79 : After serving four years in prison for killing a man, hotheaded Tom Joad (Henry Fonda) heads back to ...
# Original title:  The Grapes of Wrath
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 79 BM25 Score: 736.22
# Title: The Grapes of Wrath
# ----------------------------------------
# Movie num: 99 BM25 Score: 150.661
# Title: North by Northwest
# ----------------------------------------
# Movie num: 16 BM25 Score: 146.244
# Title: On the Waterfront
# ----------------------------------------
#
# Synopsis 80 : Shane (Alan Ladd), a skilled, laconic gunfighter with a mysterious past, rides into an isolated vall ...
# Original title:  Shane
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 80 BM25 Score: 1153.515
# Title: Shane
# ----------------------------------------
# Movie num: 7 BM25 Score: 213.754
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 38 BM25 Score: 201.141
# Title: Unforgiven
# ----------------------------------------
# Synopsis 81 : The movie begins with an old man named Paul Edgecomb (Dabbs Greer) in a retirement center. He takes  ...
# Original title:  The Green Mile
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 81 BM25 Score: 1777.464
# Title: The Green Mile
# ----------------------------------------
# Movie num: 98 BM25 Score: 388.364
# Title: The Third Man
# ----------------------------------------
# Movie num: 2 BM25 Score: 385.653
# Title: The Shawshank Redemption
# ----------------------------------------
#
# Synopsis 82 : In what appers to be the Sonoran Desert; in or near Mexico, a cartographer named David Laughlin (Bob ...
# Original title:  Close Encounters of the Third Kind
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 82 BM25 Score: 2109.857
# Title: Close Encounters of the Third Kind
# ----------------------------------------
# Movie num: 86 BM25 Score: 458.036
# Title: American Graffiti
# ----------------------------------------
# Movie num: 99 BM25 Score: 455.149
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 83 : A television network cynically exploits a deranged former anchor's ravings and revelations about the ...
# Original title:  Network
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 83 BM25 Score: 1323.512
# Title: Network
# ----------------------------------------
# Movie num: 7 BM25 Score: 162.085
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 77 BM25 Score: 157.77
# Title: Fargo
# ----------------------------------------
#
# Synopsis 84 : The overarching plot takes place over five days leading up to a political rally for Replacement Part ...
# Original title:  Nashville
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 84 BM25 Score: 2086.942
# Title: Nashville
# ----------------------------------------
# Movie num: 77 BM25 Score: 423.096
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 387.465
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 85 : The film explores the life of 21-year-old Ben Braddock (Dustin Hoffman) shortly after earning his ba ...
# Original title:  The Graduate
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 85 BM25 Score: 1450.614
# Title: The Graduate
# ----------------------------------------
# Movie num: 77 BM25 Score: 344.763
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 340.178
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 86 : It's the last night of the summer in 1962, and a number of friends are meeting at Burger City for on ...
# Original title:  American Graffiti
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 86 BM25 Score: 2126.959
# Title: American Graffiti
# ----------------------------------------
# Movie num: 77 BM25 Score: 589.829
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 586.283
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 87 : Late one morning in the Hawthorne Grill, a restaurant on Sunset Boulevard in Los Angeles, a couple o ...
# Original title:  Pulp Fiction
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 87 BM25 Score: 1909.764
# Title: Pulp Fiction
# ----------------------------------------
# Movie num: 77 BM25 Score: 375.564
# Title: Fargo
# ----------------------------------------
# Movie num: 7 BM25 Score: 363.592
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 88 : An English spinster, Rose (Katharine Hepburn), is the sister of a missionary, Rev. Samuel Sayer (Rob ...
# Original title:  The African Queen
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 88 BM25 Score: 1702.287
# Title: The African Queen
# ----------------------------------------
# Movie num: 50 BM25 Score: 364.912
# Title: Jaws
# ----------------------------------------
# Movie num: 7 BM25 Score: 353.138
# Title: Gone with the Wind
# ----------------------------------------
#
# Synopsis 89 : A group of people traveling on a stagecoach find their journey complicated by the threat of Geronimo ...
# Original title:  Stagecoach
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 89 BM25 Score: 1320.797
# Title: Stagecoach
# ----------------------------------------
# Movie num: 7 BM25 Score: 258.467
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 99 BM25 Score: 224.493
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 90 : In 1787, British ship Bounty leaves Portsmouth to bring a cargo of bread-fruit from Tahiti but the s ...
# Original title:  Mutiny on the Bounty
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 90 BM25 Score: 1154.747
# Title: Mutiny on the Bounty
# ----------------------------------------
# Movie num: 20 BM25 Score: 151.548
# Title: Star Wars
# ----------------------------------------
# Movie num: 56 BM25 Score: 147.495
# Title: Platoon
# ----------------------------------------
#
# Synopsis 91 : Private eye Sam Spade and his partner Miles Archer are approached by Miss Wonderly to follow a man,  ...
# Original title:  The Maltese Falcon
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 91 BM25 Score: 1395.844
# Title: The Maltese Falcon
# ----------------------------------------
# Movie num: 99 BM25 Score: 395.578
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 383.425
# Title: Fargo
# ----------------------------------------
#
# Synopsis 92 : "A bit of the old ultra-violence".London, England in the foreseeable future. "Our humble narrator" A ...
# Original title:  A Clockwork Orange
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 92 BM25 Score: 2464.471
# Title: A Clockwork Orange
# ----------------------------------------
# Movie num: 77 BM25 Score: 582.378
# Title: Fargo
# ----------------------------------------
# Movie num: 98 BM25 Score: 483.628
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 93 : Travis Bickle (Robert De Niro) goes to a New York City taxi depot where he applies for a job as a dr ...
# Original title:  Taxi Driver
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 93 BM25 Score: 1867.862
# Title: Taxi Driver
# ----------------------------------------
# Movie num: 77 BM25 Score: 360.391
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 344.721
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 94 : A servant in the house of Wuthering Heights tells a traveler the unfortunate tale of lovers Cathy an ...
# Original title:  Wuthering Heights
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 94 BM25 Score: 1070.454
# Title: Wuthering Heights
# ----------------------------------------
# Movie num: 7 BM25 Score: 197.684
# Title: Gone with the Wind
# ----------------------------------------
# Movie num: 98 BM25 Score: 193.102
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 95 : Walter Neff (MacMurray) is a successful insurance salesman for Pacific All-Risk returning to his off ...
# Original title:  Double Indemnity
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 95 BM25 Score: 905.836
# Title: Double Indemnity
# ----------------------------------------
# Movie num: 77 BM25 Score: 216.39
# Title: Fargo
# ----------------------------------------
# Movie num: 99 BM25 Score: 200.666
# Title: North by Northwest
# ----------------------------------------
#
# Synopsis 96 : Shortly after moving to Los Angeles with his parents, 17-year-old Jim Stark (James Dean) enrolls at  ...
# Original title:  Rebel Without a Cause
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 96 BM25 Score: 1244.026
# Title: Rebel Without a Cause
# ----------------------------------------
# Movie num: 99 BM25 Score: 250.139
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 245.158
# Title: Fargo
# ----------------------------------------
#
# Synopsis 97 : L.B. "Jeff" Jeffries (James Stewart) recuperates from a broken leg during a sweltering New York summ ...
# Original title:  Rear Window
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 97 BM25 Score: 1482.193
# Title: Rear Window
# ----------------------------------------
# Movie num: 77 BM25 Score: 400.443
# Title: Fargo
# ----------------------------------------
# Movie num: 98 BM25 Score: 381.362
# Title: The Third Man
# ----------------------------------------
#
# Synopsis 98 : Sights of Vienna, Austria, flash across the screen as an Englishman's voice (Carol Reed) describes t ...
# Original title:  The Third Man
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 98 BM25 Score: 2038.936
# Title: The Third Man
# ----------------------------------------
# Movie num: 99 BM25 Score: 676.01
# Title: North by Northwest
# ----------------------------------------
# Movie num: 77 BM25 Score: 626.778
# Title: Fargo
# ----------------------------------------
#
# Synopsis 99 : At the end of an ordinary work day, advertising executive Roger O. Thornhill (Cary Grant) hurries fr ...
# Original title:  North by Northwest
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 99 BM25 Score: 2421.983
# Title: North by Northwest
# ----------------------------------------
# Movie num: 98 BM25 Score: 711.082
# Title: The Third Man
# ----------------------------------------
# Movie num: 77 BM25 Score: 705.474
# Title: Fargo
# ----------------------------------------
#
# Synopsis 100 : A film of the life of the renowned musical composer, playwright, actor, dancer, and singer George M. ...
# Original title:  Yankee Doodle Dandy
#
# Top 3 similar titles:
# ----------------------------------------
# Movie num: 100 BM25 Score: 579.432
# Title: Yankee Doodle Dandy
# ----------------------------------------
# Movie num: 84 BM25 Score: 117.398
# Title: Nashville
# ----------------------------------------
# Movie num: 76 BM25 Score: 108.735
# Title: Tootsie
# ----------------------------------------

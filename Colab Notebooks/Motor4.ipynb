# %%
import tensorflow as tf
from tensorflow import keras
import librosa
import numpy as np

# %%
data = ['/content/drive/MyDrive/ashandata/sound data set/training']

# %%
train_ratio = 0.8
train_samples = int(len(data) * train_ratio)
train_data = data='/content/drive/MyDrive/ashandata/sound data set/training'
valid_data = data='/content/drive/MyDrive/ashandata/sound data set/testing'

# %%
# Define a function to load and preprocess audio files
def preprocess_audio(file_path):
    audio, sr = librosa.load('/content/drive/MyDrive/ashandata/sound data set/training', sr=None)  # Load the audio file
    # Perform any necessary preprocessing steps like converting to spectrogram, MFCC extraction, etc.
    # Return the preprocessed audio data
    return preprocessed_audio

# %%
batch_size = 32
train_dataset = tf.data.Dataset.from_tensor_slices((train_data['/content/drive/MyDrive/ashandata/sound data set/training'], train_data['mp3']))
train_dataset = train_dataset.map(lambda x, y: (preprocess_audio(x), y))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7423622041e4> in <cell line: 2>()
#       1 batch_size = 32
# ----> 2 train_dataset = tf.data.Dataset.from_tensor_slices((train_data['/content/drive/MyDrive/ashandata/sound data set/training'], train_data['mp3']))
#       3 train_dataset = train_dataset.map(lambda x, y: (preprocess_audio(x), y))
#       4 train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)
#
# TypeError: string indices must be integers
